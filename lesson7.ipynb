# %% [raw]
# # Fisheries competition

# %% [markdown]
# In this notebook we're going to investigate a range of different architectures for the [Kaggle fisheries competition](https://www.kaggle.com/c/the-nature-conservancy-fisheries-monitoring/).  The video states that vgg.py and ``vgg_ft()`` from utils.py have been updated to include VGG with batch normalization, but this is not the case.  We've instead created a new file [vgg_bn.py](https://github.com/fastai/courses/blob/master/deeplearning1/nbs/vgg16bn.py) and an additional method ``vgg_ft_bn()`` (which is already in utils.py) which we use in this notebook.

# %%
from theano.sandbox import cuda
# Out:
# Using gpu device 0: Tesla K80 (CNMeM is disabled, cuDNN 5103)
# /home/ubuntu/anaconda2/lib/python2.7/site-packages/theano/sandbox/cuda/__init__.py:600: UserWarning: Your cuDNN version is more recent than the one Theano officially supports. If you see any problems, try updating Theano or downgrading cuDNN to version 5.
#   warnings.warn(warn)

# %%
# %matplotlib inline
import utils; reload(utils)
from utils import *
from __future__ import division, print_function
# Out:
# Using Theano backend.

# %%
#path = "data/fish/sample/"
path = "/home/ubuntu/data/fisheries/"
batch_size=64

# %%
batches = get_batches(path+'train', batch_size=batch_size, shuffle=False)
val_batches = get_batches(path+'valid', batch_size=batch_size*2, shuffle=False)
test_batches = get_batches(path+'test', batch_size=batch_size*2, shuffle=False)

(val_classes, trn_classes, val_labels, trn_labels, 
    val_filenames, filenames, test_filenames) = get_classes(path)
# Out:
# Found 3277 images belonging to 8 classes.
# Found 500 images belonging to 8 classes.
# Found 1000 images belonging to 1 classes.
# Found 3277 images belonging to 8 classes.
# Found 500 images belonging to 8 classes.
# Found 1000 images belonging to 1 classes.

# %% [markdown]
# Sometimes it's helpful to have just the filenames, without the path.

# %%
raw_filenames = [f.split('/')[-1] for f in filenames]
raw_test_filenames = [f.split('/')[-1] for f in test_filenames]
raw_val_filenames = [f.split('/')[-1] for f in val_filenames]

# %% [markdown]
# ## Setup dirs

# %% [markdown]
# We create the validation and sample sets in the usual way.

# %%
# %cd /home/ubuntu/data/fisheries
# %cd train
# %mkdir ../valid
# Out:
# /home/ubuntu/data/fisheries
# /home/ubuntu/data/fisheries/train

# %%
g = glob('*')
for d in g: os.mkdir('../valid/'+d)

g = glob('*/*.jpg')
shuf = np.random.permutation(g)
for i in range(500): os.rename(shuf[i], '../valid/' + shuf[i])

# %%
# %mkdir ../sample
# %mkdir ../sample/train
# %mkdir ../sample/valid

# %%
from shutil import copyfile

g = glob('*')
for d in g: 
    os.mkdir('../sample/train/'+d)
    os.mkdir('../sample/valid/'+d)

# %%
g = glob('*/*.jpg')
shuf = np.random.permutation(g)
for i in range(400): copyfile(shuf[i], '../sample/train/' + shuf[i])

# %cd ../valid

g = glob('*/*.jpg')
shuf = np.random.permutation(g)
for i in range(200): copyfile(shuf[i], '../sample/valid/' + shuf[i])

# %cd ..
# Out:
# /home/ubuntu/data/fisheries/valid
# /home/ubuntu/data/fisheries

# %%
# %mkdir results
# %mkdir sample/results
# Out:
# mkdir: cannot create directory ‘sample/results’: No such file or directory
# /home/ubuntu/git/courses/deeplearning1/nbs

# %%
# %cd /home/ubuntu/git/courses/deeplearning1/nbs
# Out:
# /home/ubuntu/git/courses/deeplearning1/nbs

# %% [markdown]
# ## Basic VGG

# %% [markdown]
# We start with our usual VGG approach.  We will be using VGG with batch normalization.  We explained how to add batch normalization to VGG in the [imagenet_batchnorm notebook](https://github.com/fastai/courses/blob/master/deeplearning1/nbs/imagenet_batchnorm.ipynb).  VGG with batch normalization is implemented in [vgg_bn.py](https://github.com/fastai/courses/blob/master/deeplearning1/nbs/vgg16bn.py), and there is a version of ``vgg_ft`` (our fine tuning function) with batch norm called ``vgg_ft_bn`` in [utils.py](https://github.com/fastai/courses/blob/master/deeplearning1/nbs/utils.py).

# %% [markdown]
# ### Initial model

# %% [markdown]
# First we create a simple fine-tuned VGG model to be our starting point.

# %%
from vgg16bn import Vgg16BN
model = vgg_ft_bn(8)

# %%
trn = get_data(path+'train')
val = get_data(path+'valid')
# Out:
# Found 3277 images belonging to 8 classes.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-64-b0afbfb481fe> in <module>()
# ----> 1 trn = get_data(path+'train')
#       2 val = get_data(path+'valid')
#
# /home/ubuntu/git/courses/deeplearning1/nbs/utils.pyc in get_data(path, target_size)
#     134 def get_data(path, target_size=(224,224)):
#     135     batches = get_batches(path, shuffle=False, batch_size=1, class_mode=None, target_size=target_size)
# --> 136     return np.concatenate([batches.next() for i in range(batches.nb_sample)])
#     137
#     138
#
# /home/ubuntu/anaconda2/lib/python2.7/site-packages/keras/preprocessing/image.pyc in next(self)
#     598         for i, j in enumerate(index_array):
#     599             fname = self.filenames[j]
# --> 600             img = load_img(os.path.join(self.directory, fname), grayscale=grayscale, target_size=self.target_size)
#     601             x = img_to_array(img, dim_ordering=self.dim_ordering)
#     602             x = self.image_data_generator.random_transform(x)
#
# /home/ubuntu/anaconda2/lib/python2.7/site-packages/keras/preprocessing/image.pyc in load_img(path, grayscale, target_size)
#     175         img = img.convert('L')
#     176     else:  # Ensure 3 channel even when loaded image is grayscale
# --> 177         img = img.convert('RGB')
#     178     if target_size:
#     179         img = img.resize((target_size[1], target_size[0]))
#
# /home/ubuntu/anaconda2/lib/python2.7/site-packages/PIL/Image.pyc in convert(self, mode, matrix, dither, palette, colors)
#     839                 return self.copy()
#     840
# --> 841         self.load()
#     842
#     843         if matrix:
#
# /home/ubuntu/anaconda2/lib/python2.7/site-packages/PIL/ImageFile.pyc in load(self)
#     137         # look for read/seek overrides
#     138         try:
# --> 139             read = self.load_read
#     140             # don't use mmap if there are custom read/seek functions
#     141             use_mmap = False
#
# KeyboardInterrupt:

# %%
test = get_data(path+'test')
# Out:
# Found 1000 images belonging to 1 classes.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-65-b51888be05df> in <module>()
# ----> 1 test = get_data(path+'test')
#
# /home/ubuntu/git/courses/deeplearning1/nbs/utils.pyc in get_data(path, target_size)
#     134 def get_data(path, target_size=(224,224)):
#     135     batches = get_batches(path, shuffle=False, batch_size=1, class_mode=None, target_size=target_size)
# --> 136     return np.concatenate([batches.next() for i in range(batches.nb_sample)])
#     137
#     138
#
# /home/ubuntu/anaconda2/lib/python2.7/site-packages/keras/preprocessing/image.pyc in next(self)
#     600             img = load_img(os.path.join(self.directory, fname), grayscale=grayscale, target_size=self.target_size)
#     601             x = img_to_array(img, dim_ordering=self.dim_ordering)
# --> 602             x = self.image_data_generator.random_transform(x)
#     603             x = self.image_data_generator.standardize(x)
#     604             batch_x[i] = x
#
# /home/ubuntu/anaconda2/lib/python2.7/site-packages/keras/preprocessing/image.pyc in random_transform(self, x)
#     360         transform_matrix = transform_matrix_offset_center(transform_matrix, h, w)
#     361         x = apply_transform(x, transform_matrix, img_channel_index,
# --> 362                             fill_mode=self.fill_mode, cval=self.cval)
#     363         if self.channel_shift_range != 0:
#     364             x = random_channel_shift(x, self.channel_shift_range, img_channel_index)
#
# /home/ubuntu/anaconda2/lib/python2.7/site-packages/keras/preprocessing/image.pyc in apply_transform(x, transform_matrix, channel_index, fill_mode, cval)
#     106     final_offset = transform_matrix[:2, 2]
#     107     channel_images = [ndi.interpolation.affine_transform(x_channel, final_affine_matrix,
# --> 108                       final_offset, order=0, mode=fill_mode, cval=cval) for x_channel in x]
#     109     x = np.stack(channel_images, axis=0)
#     110     x = np.rollaxis(x, 0, channel_index+1)
#
# /home/ubuntu/anaconda2/lib/python2.7/site-packages/scipy/ndimage/interpolation.pyc in affine_transform(input, matrix, offset, output_shape, output, order, mode, cval, prefilter)
#     436     else:
#     437         _geometric_transform(filtered, None, None, matrix, offset,
# --> 438                              output, order, mode, cval, None, None)
#     439     return return_value
#     440
#
# /home/ubuntu/anaconda2/lib/python2.7/site-packages/scipy/ndimage/interpolation.pyc in _geometric_transform(input, mapping, coordinates, matrix, offset, output, order, mode, cval, extra_arguments, extra_keywords)
#     130     _nd_image.geometric_transform(
#     131         input, mapping, coordinates, matrix, offset, output,
# --> 132         order, mode, cval, extra_arguments, extra_keywords)
#     133
#     134     if output is not None and not output.dtype.isnative:
#
# KeyboardInterrupt:

# %%
save_array(path+'results/trn.dat', trn)
save_array(path+'results/val.dat', val)

# %%
save_array(path+'results/test.dat', test)

# %%
trn = load_array(path+'results/trn.dat')
val = load_array(path+'results/val.dat')

# %%
test = load_array(path+'results/test.dat')

# %%
gen = image.ImageDataGenerator()

# %%
model.compile(optimizer=Adam(1e-3),
       loss='categorical_crossentropy', metrics=['accuracy'])

# %%
model.fit(trn, trn_labels, batch_size=batch_size, nb_epoch=3, validation_data=(val, val_labels))
# Out:
# Train on 3277 samples, validate on 500 samples
# Epoch 1/3
# 3277/3277 [==============================] - 178s - loss: 2.8913 - acc: 0.4709 - val_loss: 1.2240 - val_acc: 0.6760
# Epoch 2/3
# 3277/3277 [==============================] - 178s - loss: 1.5545 - acc: 0.6439 - val_loss: 0.7772 - val_acc: 0.7900
# Epoch 3/3
# 3277/3277 [==============================] - 178s - loss: 1.1826 - acc: 0.7196 - val_loss: 0.7010 - val_acc: 0.8180

# %%
model.save_weights(path+'results/vgg1.h5')

# %% [markdown]
# ### Precompute convolutional output

# %% [markdown]
# We pre-compute the output of the last convolution layer of VGG, since we're unlikely to need to fine-tune those layers. (All following analysis will be done on just the pre-computed convolutional features.)

# %%
model.load_weights(path+'results/ft1.h5')

# %%
conv_layers,fc_layers = split_at(model, Convolution2D)

# %%
conv_model = Sequential(conv_layers)

# %%
conv_feat = conv_model.predict(trn)
conv_val_feat = conv_model.predict(val)

# %%
conv_test_feat = conv_model.predict(test)

# %%
save_array(path+'results/conv_val_feat.dat', conv_val_feat)
save_array(path+'results/conv_feat.dat', conv_feat)

# %%
save_array(path+'results/conv_test_feat.dat', conv_test_feat)

# %%
conv_feat = load_array(path+'results/conv_feat.dat')
conv_val_feat = load_array(path+'results/conv_val_feat.dat')

# %%
conv_test_feat = load_array(path+'results/conv_test_feat.dat')

# %%
conv_val_feat.shape
# Out:
# (500, 512, 14, 14)

# %% [markdown]
# ### Train model

# %% [markdown]
# We can now create our first baseline model - a simple 3-layer FC net.

# %%
def get_bn_layers(p):
    return [
        MaxPooling2D(input_shape=conv_layers[-1].output_shape[1:]),
        BatchNormalization(axis=1),
        Dropout(p/4),
        Flatten(),
        Dense(512, activation='relu'),
        BatchNormalization(),
        Dropout(p),
        Dense(512, activation='relu'),
        BatchNormalization(),
        Dropout(p/2),
        Dense(8, activation='softmax')
    ]

# %%
p=0.6

# %%
bn_model = Sequential(get_bn_layers(p))
bn_model.compile(Adam(lr=0.001), loss='categorical_crossentropy', metrics=['accuracy'])

# %%
bn_model.fit(conv_feat, trn_labels, batch_size=batch_size, nb_epoch=3, 
             validation_data=(conv_val_feat, val_labels))
# Out:
# Train on 3277 samples, validate on 500 samples
# Epoch 1/3
# 3277/3277 [==============================] - 9s - loss: 1.1113 - acc: 0.6741 - val_loss: 0.9704 - val_acc: 0.8280
# Epoch 2/3
# 3277/3277 [==============================] - 9s - loss: 0.3003 - acc: 0.9103 - val_loss: 0.2819 - val_acc: 0.9580
# Epoch 3/3
# 3277/3277 [==============================] - 9s - loss: 0.1725 - acc: 0.9478 - val_loss: 0.2151 - val_acc: 0.9560

# %%
bn_model.optimizer.lr = 1e-4

# %%
bn_model.fit(conv_feat, trn_labels, batch_size=batch_size, nb_epoch=7, 
             validation_data=(conv_val_feat, val_labels))
# Out:
# Train on 3277 samples, validate on 500 samples
# Epoch 1/7
# 3277/3277 [==============================] - 9s - loss: 0.1060 - acc: 0.9704 - val_loss: 0.2143 - val_acc: 0.9520
# Epoch 2/7
# 3277/3277 [==============================] - 9s - loss: 0.0683 - acc: 0.9823 - val_loss: 0.1961 - val_acc: 0.9540
# Epoch 3/7
# 3277/3277 [==============================] - 9s - loss: 0.0590 - acc: 0.9847 - val_loss: 0.2216 - val_acc: 0.9500
# Epoch 4/7
# 3277/3277 [==============================] - 9s - loss: 0.0489 - acc: 0.9847 - val_loss: 0.1579 - val_acc: 0.9760
# Epoch 5/7
# 3277/3277 [==============================] - 9s - loss: 0.0323 - acc: 0.9893 - val_loss: 0.1729 - val_acc: 0.9700
# Epoch 6/7
# 3277/3277 [==============================] - 9s - loss: 0.0300 - acc: 0.9930 - val_loss: 0.2192 - val_acc: 0.9680
# Epoch 7/7
# 3277/3277 [==============================] - 9s - loss: 0.0241 - acc: 0.9936 - val_loss: 0.2367 - val_acc: 0.9620

# %%
bn_model.save_weights(path+'results/vgg2_9620.h5')

# %%
bn_model.evaluate(conv_val_feat, val_labels)
# Out:
# 500/500 [==============================] - 0s
# [0.23669385994598269, 0.96199999999999997]

# %%
bn_model.load_weights(path+'results/vgg2_9620.h5')

# %%
preds = bn_model.predict(conv_test_feat)

# %%
preds[:5]
# Out:
# array([[  9.6853e-01,   1.4112e-02,   1.6608e-03,   1.6136e-03,   2.6789e-04,   9.9496e-03,
#           8.0711e-04,   3.0584e-03],
#        [  4.9321e-01,   3.4661e-02,   4.7434e-02,   8.5076e-03,   2.6046e-03,   3.8383e-01,
#           1.6055e-02,   1.3698e-02],
#        [  1.1632e-01,   2.1974e-03,   1.9341e-03,   4.2466e-03,   8.3049e-01,   3.9783e-04,
#           4.4250e-02,   1.6097e-04],
#        [  9.9840e-01,   8.2113e-06,   1.8617e-05,   2.2809e-05,   2.8022e-06,   6.7546e-05,
#           7.5561e-06,   1.4722e-03],
#        [  9.9996e-01,   2.4622e-06,   6.2845e-06,   1.1048e-05,   8.4056e-06,   3.2725e-06,
#           1.0072e-05,   3.1372e-06]], dtype=float32)

# %% [markdown]
# ## Multi-input

# %% [markdown]
# The images are of different sizes, which are likely to represent the boat they came from (since different boats will use different cameras). Perhaps this creates some data leakage that we can take advantage of to get a better Kaggle leaderboard position? To find out, first we create arrays of the file sizes for each image:

# %%
sizes = [PIL.Image.open(path+'train/'+f).size for f in filenames]
id2size = list(set(sizes))
size2id = {o:i for i,o in enumerate(id2size)}

# %%
import collections
collections.Counter(sizes)
# Out:
# Counter({(1192, 670): 175,
#          (1244, 700): 23,
#          (1276, 718): 185,
#          (1280, 720): 1896,
#          (1280, 750): 522,
#          (1280, 924): 49,
#          (1280, 974): 340,
#          (1334, 750): 21,
#          (1518, 854): 34,
#          (1732, 974): 32})

# %% [markdown]
# Then we one-hot encode them (since we want to treat them as categorical) and normalize the data.

# %%
trn_sizes_orig = to_categorical([size2id[o] for o in sizes], len(id2size))

# %%
raw_val_sizes = [PIL.Image.open(path+'valid/'+f).size for f in val_filenames]
val_sizes = to_categorical([size2id[o] for o in raw_val_sizes], len(id2size))

# %%
trn_sizes = trn_sizes_orig-trn_sizes_orig.mean(axis=0)/trn_sizes_orig.std(axis=0)
val_sizes = val_sizes-trn_sizes_orig.mean(axis=0)/trn_sizes_orig.std(axis=0)

# %% [markdown]
# To use this additional "meta-data", we create a model with multiple input layers - `sz_inp` will be our input for the size information.

# %%
p=0.6

# %%
inp = Input(conv_layers[-1].output_shape[1:])
sz_inp = Input((len(id2size),))
bn_inp = BatchNormalization()(sz_inp)

x = MaxPooling2D()(inp)
x = BatchNormalization(axis=1)(x)
x = Dropout(p/4)(x)
x = Flatten()(x)
x = Dense(512, activation='relu')(x)
x = BatchNormalization()(x)
x = Dropout(p)(x)
x = Dense(512, activation='relu')(x)
x = BatchNormalization()(x)
x = Dropout(p/2)(x)
x = merge([x,bn_inp], 'concat')
x = Dense(8, activation='softmax')(x)

# %% [markdown]
# When we compile the model, we have to specify all the input layers in an array.

# %%
model = Model([inp, sz_inp], x)
model.compile(Adam(lr=0.001), loss='categorical_crossentropy', metrics=['accuracy'])

# %% [markdown]
# And when we train the model, we have to provide all the input layers' data in an array.

# %%
model.fit([conv_feat, trn_sizes], trn_labels, batch_size=batch_size, nb_epoch=3, 
             validation_data=([conv_val_feat, val_sizes], val_labels))
# Out:
# Train on 3277 samples, validate on 500 samples
# Epoch 1/3
# 3277/3277 [==============================] - 2s - loss: 1.1189 - acc: 0.6655 - val_loss: 0.9451 - val_acc: 0.8240
# Epoch 2/3
# 3277/3277 [==============================] - 1s - loss: 0.3387 - acc: 0.9017 - val_loss: 0.2830 - val_acc: 0.9400
# Epoch 3/3
# 3277/3277 [==============================] - 1s - loss: 0.1476 - acc: 0.9612 - val_loss: 0.1882 - val_acc: 0.9620

# %%
bn_model.optimizer.lr = 1e-4

# %%
bn_model.fit(conv_feat, trn_labels, batch_size=batch_size, nb_epoch=8, 
             validation_data=(conv_val_feat, val_labels))
# Out:
# Train on 3277 samples, validate on 500 samples
# Epoch 1/8
# 3277/3277 [==============================] - 1s - loss: 0.0173 - acc: 0.9963 - val_loss: 0.2270 - val_acc: 0.9640
# Epoch 2/8
# 3277/3277 [==============================] - 1s - loss: 0.0112 - acc: 0.9966 - val_loss: 0.2353 - val_acc: 0.9620
# Epoch 3/8
# 3277/3277 [==============================] - 1s - loss: 0.0124 - acc: 0.9963 - val_loss: 0.2242 - val_acc: 0.9680
# Epoch 4/8
# 3277/3277 [==============================] - 1s - loss: 0.0069 - acc: 0.9976 - val_loss: 0.2281 - val_acc: 0.9680
# Epoch 5/8
# 3277/3277 [==============================] - 1s - loss: 0.0114 - acc: 0.9973 - val_loss: 0.1958 - val_acc: 0.9680
# Epoch 6/8
# 3277/3277 [==============================] - 1s - loss: 0.0066 - acc: 0.9979 - val_loss: 0.1925 - val_acc: 0.9680
# Epoch 7/8
# 3277/3277 [==============================] - 1s - loss: 0.0094 - acc: 0.9973 - val_loss: 0.1978 - val_acc: 0.9660
# Epoch 8/8
# 3277/3277 [==============================] - 1s - loss: 0.0144 - acc: 0.9951 - val_loss: 0.1836 - val_acc: 0.9680

# %% [markdown]
# The model did not show an improvement by using the leakage, other than in the early epochs. This is most likely because the information about what boat the picture came from is readily identified from the image itself, so the meta-data turned out not to add any additional information.

# %% [markdown]
# ## Bounding boxes & multi output

# %% [markdown]
# ### Import / view bounding boxes

# %% [markdown]
# A kaggle user has created bounding box annotations for each fish in each training set image. You can download them [from here](https://www.kaggle.com/c/the-nature-conservancy-fisheries-monitoring/forums/t/25902/complete-bounding-box-annotation). We will see if we can utilize this additional information. First, we'll load in the data, and keep just the largest bounding box for each image.

# %%
import ujson as json

# %%
anno_classes = ['alb', 'bet', 'dol', 'lag', 'other', 'shark', 'yft']

# %%
bb_json = {}
for c in anno_classes:
    j = json.load(open('{}anno/{}_labels.json'.format(path, c), 'r'))
    for l in j:
        if 'annotations' in l.keys() and len(l['annotations'])>0:
            bb_json[l['filename'].split('/')[-1]] = sorted(
                l['annotations'], key=lambda x: x['height']*x['width'])[-1]

# %%
bb_json['img_04908.jpg']
# Out:
# {u'class': u'rect',
#  u'height': 246.75000000000074,
#  u'width': 432.8700000000013,
#  u'x': 465.3000000000014,
#  u'y': 496.32000000000147}

# %%
file2idx = {o:i for i,o in enumerate(raw_filenames)}
val_file2idx = {o:i for i,o in enumerate(raw_val_filenames)}

# %% [markdown]
# For any images that have no annotations, we'll create an empty bounding box.

# %%
empty_bbox = {'height': 0., 'width': 0., 'x': 0., 'y': 0.}

# %%
for f in raw_filenames:
    if not f in bb_json.keys(): bb_json[f] = empty_bbox
for f in raw_val_filenames:
    if not f in bb_json.keys(): bb_json[f] = empty_bbox

# %% [markdown]
# Finally, we convert the dictionary into an array, and convert the coordinates to our resized 224x224 images.

# %%
bb_params = ['height', 'width', 'x', 'y']
def convert_bb(bb, size):
    bb = [bb[p] for p in bb_params]
    conv_x = (224. / size[0])
    conv_y = (224. / size[1])
    bb[0] = bb[0]*conv_y
    bb[1] = bb[1]*conv_x
    bb[2] = max(bb[2]*conv_x, 0)
    bb[3] = max(bb[3]*conv_y, 0)
    return bb

# %%
trn_bbox = np.stack([convert_bb(bb_json[f], s) for f,s in zip(raw_filenames, sizes)], 
                   ).astype(np.float32)
val_bbox = np.stack([convert_bb(bb_json[f], s) 
                   for f,s in zip(raw_val_filenames, raw_val_sizes)]).astype(np.float32)

# %% [markdown]
# Now we can check our work by drawing one of the annotations.

# %%
def create_rect(bb, color='red'):
    return plt.Rectangle((bb[2], bb[3]), bb[1], bb[0], color=color, fill=False, lw=3)

def show_bb(i):
    bb = val_bbox[i]
    plot(val[i])
    plt.gca().add_patch(create_rect(bb))

# %%
show_bb(0)

# %% [markdown]
# ### Create & train model

# %% [markdown]
# Since we're not allowed (by the kaggle rules) to manually annotate the test set, we'll need to create a model that predicts the locations of the bounding box on each image. To do so, we create a model with multiple outputs: it will predict both the type of fish (the 'class'), and the 4 bounding box coordinates. We prefer this approach to only predicting the bounding box coordinates, since we hope that giving the model more context about what it's looking for will help it with both tasks.

# %%
p=0.6

# %%
inp = Input(conv_layers[-1].output_shape[1:])
x = MaxPooling2D()(inp)
x = BatchNormalization(axis=1)(x)
x = Dropout(p/4)(x)
x = Flatten()(x)
x = Dense(512, activation='relu')(x)
x = BatchNormalization()(x)
x = Dropout(p)(x)
x = Dense(512, activation='relu')(x)
x = BatchNormalization()(x)
x = Dropout(p/2)(x)
x_bb = Dense(4, name='bb')(x)
x_class = Dense(8, activation='softmax', name='class')(x)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-eb98f8e0a49f> in <module>()
# ----> 1 inp = Input(conv_layers[-1].output_shape[1:])
#       2 x = MaxPooling2D()(inp)
#       3 x = BatchNormalization(axis=1)(x)
#       4 x = Dropout(p/4)(x)
#       5 x = Flatten()(x)
#
# NameError: name 'conv_layers' is not defined

# %% [markdown]
# Since we have multiple outputs, we need to provide them to the model constructor in an array, and we also need to say what loss function to use for each. We also weight the bounding box loss function down by 1000x since the scale of the cross-entropy loss and the MSE is very different.

# %%
model = Model([inp], [x_bb, x_class])
model.compile(Adam(lr=0.001), loss=['mse', 'categorical_crossentropy'], metrics=['accuracy'],
             loss_weights=[.001, 1.])

# %%
model.fit(conv_feat, [trn_bbox, trn_labels], batch_size=batch_size, nb_epoch=3, 
             validation_data=(conv_val_feat, [val_bbox, val_labels]))
# Out:
# Train on 3277 samples, validate on 500 samples
# Epoch 1/3
# 3277/3277 [==============================] - 1s - loss: 6.1534 - bb_loss: 5027.6558 - class_loss: 1.1258 - bb_acc: 0.3970 - class_acc: 0.6732 - val_loss: 5.0149 - val_bb_loss: 4098.7061 - val_class_loss: 0.9162 - val_bb_acc: 0.4540 - val_class_acc: 0.8400
# Epoch 2/3
# 3277/3277 [==============================] - 1s - loss: 5.0483 - bb_loss: 4723.7241 - class_loss: 0.3245 - bb_acc: 0.4791 - class_acc: 0.8962 - val_loss: 4.1905 - val_bb_loss: 3876.8253 - val_class_loss: 0.3136 - val_bb_acc: 0.5340 - val_class_acc: 0.9380
# Epoch 3/3
# 3277/3277 [==============================] - 1s - loss: 4.4175 - bb_loss: 4249.6727 - class_loss: 0.1678 - bb_acc: 0.5349 - class_acc: 0.9509 - val_loss: 3.6945 - val_bb_loss: 3406.7987 - val_class_loss: 0.2877 - val_bb_acc: 0.5720 - val_class_acc: 0.9460

# %%
model.optimizer.lr = 1e-5

# %%
model.fit(conv_feat, [trn_bbox, trn_labels], batch_size=batch_size, nb_epoch=10, 
             validation_data=(conv_val_feat, [val_bbox, val_labels]))
# Out:
# Train on 3277 samples, validate on 500 samples
# Epoch 1/10
# 3277/3277 [==============================] - 1s - loss: 3.6777 - bb_loss: 3586.1524 - class_loss: 0.0915 - bb_acc: 0.5886 - class_acc: 0.9704 - val_loss: 3.2501 - val_bb_loss: 3014.3022 - val_class_loss: 0.2358 - val_bb_acc: 0.6260 - val_class_acc: 0.9600
# Epoch 2/10
# 3277/3277 [==============================] - 1s - loss: 2.9034 - bb_loss: 2832.7123 - class_loss: 0.0707 - bb_acc: 0.6298 - class_acc: 0.9805 - val_loss: 2.6480 - val_bb_loss: 2405.0350 - val_class_loss: 0.2430 - val_bb_acc: 0.6600 - val_class_acc: 0.9600
# Epoch 3/10
# 3277/3277 [==============================] - 1s - loss: 2.0618 - bb_loss: 2002.3679 - class_loss: 0.0594 - bb_acc: 0.6530 - class_acc: 0.9835 - val_loss: 1.9974 - val_bb_loss: 1741.0997 - val_class_loss: 0.2563 - val_bb_acc: 0.6880 - val_class_acc: 0.9560
# Epoch 4/10
# 3277/3277 [==============================] - 1s - loss: 1.2993 - bb_loss: 1247.6213 - class_loss: 0.0517 - bb_acc: 0.7052 - class_acc: 0.9854 - val_loss: 1.2805 - val_bb_loss: 1009.0002 - val_class_loss: 0.2715 - val_bb_acc: 0.7140 - val_class_acc: 0.9620
# Epoch 5/10
# 3277/3277 [==============================] - 1s - loss: 0.7623 - bb_loss: 721.6705 - class_loss: 0.0406 - bb_acc: 0.7516 - class_acc: 0.9915 - val_loss: 0.9202 - val_bb_loss: 651.4378 - val_class_loss: 0.2688 - val_bb_acc: 0.7840 - val_class_acc: 0.9620
# Epoch 6/10
# 3277/3277 [==============================] - 1s - loss: 0.4735 - bb_loss: 435.1895 - class_loss: 0.0383 - bb_acc: 0.7931 - class_acc: 0.9884 - val_loss: 0.7056 - val_bb_loss: 460.7778 - val_class_loss: 0.2448 - val_bb_acc: 0.8160 - val_class_acc: 0.9620
# Epoch 7/10
# 3277/3277 [==============================] - 1s - loss: 0.3467 - bb_loss: 315.7393 - class_loss: 0.0309 - bb_acc: 0.8142 - class_acc: 0.9890 - val_loss: 0.6454 - val_bb_loss: 400.6352 - val_class_loss: 0.2448 - val_bb_acc: 0.8220 - val_class_acc: 0.9620
# Epoch 8/10
# 3277/3277 [==============================] - 1s - loss: 0.2948 - bb_loss: 264.1701 - class_loss: 0.0307 - bb_acc: 0.8135 - class_acc: 0.9908 - val_loss: 0.6252 - val_bb_loss: 379.5603 - val_class_loss: 0.2457 - val_bb_acc: 0.8100 - val_class_acc: 0.9660
# Epoch 9/10
# 3277/3277 [==============================] - 1s - loss: 0.2806 - bb_loss: 253.2426 - class_loss: 0.0274 - bb_acc: 0.8010 - class_acc: 0.9933 - val_loss: 0.6164 - val_bb_loss: 364.6892 - val_class_loss: 0.2517 - val_bb_acc: 0.8260 - val_class_acc: 0.9640
# Epoch 10/10
# 3277/3277 [==============================] - 1s - loss: 0.2670 - bb_loss: 234.3816 - class_loss: 0.0326 - bb_acc: 0.8026 - class_acc: 0.9902 - val_loss: 0.6327 - val_bb_loss: 358.6986 - val_class_loss: 0.2740 - val_bb_acc: 0.8120 - val_class_acc: 0.9600

# %% [markdown]
# Excitingly, it turned out that the classification model is much improved by giving it this additional task. Let's see how well the bounding box model did by taking a look at its output.

# %%
pred = model.predict(conv_val_feat[0:10])

# %%
def show_bb_pred(i):
    bb = val_bbox[i]
    bb_pred = pred[0][i]
    plt.figure(figsize=(6,6))
    plot(val[i])
    ax=plt.gca()
    ax.add_patch(create_rect(bb_pred, 'yellow'))
    ax.add_patch(create_rect(bb))

# %% [markdown]
# The image shows that it can find fish that are tricky for us to see!

# %%
show_bb_pred(6)

# %%
model.evaluate(conv_val_feat, [val_bbox, val_labels])
# Out:
# 500/500 [==============================] - 0s
# [0.63268272674083714,
#  358.69855560302733,
#  0.27398415758460759,
#  0.81199999904632569,
#  0.95999999999999996]

# %%
model.save_weights(path+'results/bn_anno.h5')

# %%
model.load_weights(path+'results/bn_anno.h5')

# %% [markdown]
# ## Larger size

# %% [markdown]
# ### Set up data

# %% [markdown]
# Let's see if we get better results if we use larger images. We'll use 640x360, since it's the same shape as the most common size we saw earlier (1280x720), without being too big.

# %%
trn = get_data(path+'train', (360,640))
val = get_data(path+'valid', (360,640))
# Out:
# Found 3277 images belonging to 8 classes.
# Found 500 images belonging to 8 classes.

# %% [markdown]
# The image shows that things are much clearer at this size.

# %%
plot(trn[0])

# %%
test = get_data(path+'test', (360,640))
# Out:
# Found 1000 images belonging to 1 classes.

# %%
save_array(path+'results/trn_640.dat', trn)
save_array(path+'results/val_640.dat', val)

# %%
save_array(path+'results/test_640.dat', test)

# %%
trn = load_array(path+'results/trn_640.dat')
val = load_array(path+'results/val_640.dat')

# %% [markdown]
# We can now create our VGG model - we'll need to tell it we're not using the normal 224x224 images, which also means it won't include the fully connected layers (since they don't make sense for non-default sizes). We will also remove the last max pooling layer, since we don't want to throw away information yet.

# %%
vgg640 = Vgg16BN((360, 640)).model
vgg640.pop()
vgg640.input_shape, vgg640.output_shape
vgg640.compile(Adam(), 'categorical_crossentropy', metrics=['accuracy'])

# %% [markdown]
# We can now pre-compute the output of the convolutional part of VGG.

# %%
conv_val_feat = vgg640.predict(val, batch_size=32, verbose=1)
conv_trn_feat = vgg640.predict(trn, batch_size=32, verbose=1)
# Out:
# 500/500 [==============================] - 64s
# 3277/3277 [==============================] - 427s

# %%
save_array(path+'results/conv_val_640.dat', conv_val_feat)
save_array(path+'results/conv_trn_640.dat', conv_trn_feat)

# %%
conv_test_feat = vgg640.predict(test, batch_size=32, verbose=1)
# Out:
# 1000/1000 [==============================] - 130s

# %%
save_array(path+'results/conv_test_640.dat', conv_test_feat)

# %%
conv_val_feat = load_array(path+'results/conv_val_640.dat')
conv_trn_feat = load_array(path+'results/conv_trn_640.dat')

# %%
conv_test_feat = load_array(path+'results/conv_test_640.dat')

# %% [markdown]
# ### Fully convolutional net (FCN)

# %% [markdown]
# Since we're using a larger input, the output of the final convolutional layer is also larger. So we probably don't want to put a dense layer there - that would be a *lot* of parameters! Instead, let's use a fully convolutional net (FCN); this also has the benefit that they tend to generalize well, and also seems like a good fit for our problem (since the fish are a small part of the image).

# %%
conv_layers,_ = split_at(vgg640, Convolution2D)

# %% [markdown]
# I'm not using any dropout, since I found I got better results without it.

# %%
nf=128; p=0.

# %%
def get_lrg_layers():
    return [
        BatchNormalization(axis=1, input_shape=conv_layers[-1].output_shape[1:]),
        Convolution2D(nf,3,3, activation='relu', border_mode='same'),
        BatchNormalization(axis=1),
        MaxPooling2D(),
        Convolution2D(nf,3,3, activation='relu', border_mode='same'),
        BatchNormalization(axis=1),
        MaxPooling2D(),
        Convolution2D(nf,3,3, activation='relu', border_mode='same'),
        BatchNormalization(axis=1),
        MaxPooling2D((1,2)),
        Convolution2D(8,3,3, border_mode='same'),
        Dropout(p),
        GlobalAveragePooling2D(),
        Activation('softmax')
    ]

# %%
lrg_model = Sequential(get_lrg_layers())
# Out:
# th

# %%
lrg_model.summary()
# Out:
# INFO (theano.gof.compilelock): Refreshing lock /home/ubuntu/.theano/compiledir_Linux-4.4--generic-x86_64-with-debian-stretch-sid-x86_64-2.7.12-64/lock_dir/lock
# Problem occurred during compilation with the command line below:
# /usr/bin/g++ -shared -g -O3 -fno-math-errno -Wno-unused-label -Wno-unused-variable -Wno-write-strings -march=broadwell -mmmx -mno-3dnow -msse -msse2 -msse3 -mssse3 -mno-sse4a -mcx16 -msahf -mmovbe -maes -mno-sha -mpclmul -mpopcnt -mabm -mno-lwp -mfma -mno-fma4 -mno-xop -mbmi -mbmi2 -mno-tbm -mavx -mavx2 -msse4.2 -msse4.1 -mlzcnt -mrtm -mhle -mrdrnd -mf16c -mfsgsbase -mno-rdseed -mno-prfchw -mno-adx -mfxsr -mxsave -mxsaveopt -mno-avx512f -mno-avx512er -mno-avx512cd -mno-avx512pf -mno-prefetchwt1 -mno-clflushopt -mno-xsavec -mno-xsaves -mno-avx512dq -mno-avx512bw -mno-avx512vl -mno-avx512ifma -mno-avx512vbmi -mno-clwb -mno-pcommit -mno-mwaitx --param l1-cache-size=32 --param l1-cache-line-size=64 --param l2-cache-size=46080 -mtune=broadwell -DNPY_NO_DEPRECATED_API=NPY_1_7_API_VERSION -m64 -fPIC -I/home/ubuntu/anaconda2/lib/python2.7/site-packages/numpy/core/include -I/home/ubuntu/anaconda2/include/python2.7 -I/home/ubuntu/anaconda2/lib/python2.7/site-packages/theano/gof -fvisibility=hidden -o /home/ubuntu/.theano/compiledir_Linux-4.4--generic-x86_64-with-debian-stretch-sid-x86_64-2.7.12-64/tmpn03GzC/a48f4668d98d8c16519ad508b2f7c269.so /home/ubuntu/.theano/compiledir_Linux-4.4--generic-x86_64-with-debian-stretch-sid-x86_64-2.7.12-64/tmpn03GzC/mod.cpp -L/home/ubuntu/anaconda2/lib -lpython2.7
# ERROR (theano.gof.cmodule): [Errno 12] Cannot allocate memory
# ____________________________________________________________________________________________________
# Layer (type)                     Output Shape          Param #     Connected to
# ====================================================================================================
# batchnormalization_22 (BatchNorma(None, 512, 22, 40)   1024        batchnormalization_input_2[0][0]
# ____________________________________________________________________________________________________
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-138-ab33a73b08b3> in <module>()
# ----> 1 lrg_model.summary()
#
# /home/ubuntu/anaconda2/lib/python2.7/site-packages/keras/engine/topology.pyc in summary(self, line_length, positions)
#    2689             flattened_layers = self.layers
#    2690
# -> 2691         print_summary(flattened_layers, getattr(self, 'container_nodes', None), line_length=line_length, positions=positions)
#    2692
#    2693
#
# /home/ubuntu/anaconda2/lib/python2.7/site-packages/keras/utils/layer_utils.pyc in print_summary(layers, relevant_nodes, line_length, positions)
#      90     total_params = 0
#      91     for i in range(len(layers)):
# ---> 92         print_layer_summary(layers[i])
#      93         if i == len(layers) - 1:
#      94             print('=' * line_length)
#
# /home/ubuntu/anaconda2/lib/python2.7/site-packages/keras/utils/layer_utils.pyc in print_layer_summary(layer)
#      81         else:
#      82             first_connection = connections[0]
# ---> 83         fields = [name + ' (' + cls_name + ')', output_shape, layer.count_params(), first_connection]
#      84         print_row(fields, positions)
#      85         if len(connections) > 1:
#
# /home/ubuntu/anaconda2/lib/python2.7/site-packages/keras/engine/topology.pyc in count_params(self)
#     941                                 'You can build it manually via: `' +
#     942                                 self.name + '.build(batch_input_shape)`.')
# --> 943         return sum([K.count_params(p) for p in self.trainable_weights])
#     944
#     945
#
# /home/ubuntu/anaconda2/lib/python2.7/site-packages/keras/backend/theano_backend.pyc in count_params(x)
#     152     Return: numpy integer.
#     153     '''
# --> 154     return np.prod(x.shape.eval())
#     155
#     156
#
# /home/ubuntu/anaconda2/lib/python2.7/site-packages/theano/gof/graph.pyc in eval(self, inputs_to_values)
#     518         inputs = tuple(sorted(inputs_to_values.keys(), key=id))
#     519         if inputs not in self._fn_cache:
# --> 520             self._fn_cache[inputs] = theano.function(inputs, self)
#     521         args = [inputs_to_values[param] for param in inputs]
#     522
#
# /home/ubuntu/anaconda2/lib/python2.7/site-packages/theano/compile/function.pyc in function(inputs, outputs, mode, updates, givens, no_default_updates, accept_inplace, name, rebuild_strict, allow_input_downcast, profile, on_unused_input)
#     318                    on_unused_input=on_unused_input,
#     319                    profile=profile,
# --> 320                    output_keys=output_keys)
#     321     # We need to add the flag check_aliased inputs if we have any mutable or
#     322     # borrowed used defined inputs
#
# /home/ubuntu/anaconda2/lib/python2.7/site-packages/theano/compile/pfunc.pyc in pfunc(params, outputs, mode, updates, givens, no_default_updates, accept_inplace, name, rebuild_strict, allow_input_downcast, profile, on_unused_input, output_keys)
#     477                          accept_inplace=accept_inplace, name=name,
#     478                          profile=profile, on_unused_input=on_unused_input,
# --> 479                          output_keys=output_keys)
#     480
#     481
#
# /home/ubuntu/anaconda2/lib/python2.7/site-packages/theano/compile/function_module.pyc in orig_function(inputs, outputs, mode, accept_inplace, name, profile, on_unused_input, output_keys)
#    1775                    on_unused_input=on_unused_input,
#    1776                    output_keys=output_keys).create(
# -> 1777             defaults)
#    1778
#    1779     t2 = time.time()
#
# /home/ubuntu/anaconda2/lib/python2.7/site-packages/theano/compile/function_module.pyc in create(self, input_storage, trustme, storage_map)
#    1639             theano.config.traceback.limit = 0
#    1640             _fn, _i, _o = self.linker.make_thunk(
# -> 1641                 input_storage=input_storage_lists, storage_map=storage_map)
#    1642         finally:
#    1643             theano.config.traceback.limit = limit_orig
#
# /home/ubuntu/anaconda2/lib/python2.7/site-packages/theano/gof/link.pyc in make_thunk(self, input_storage, output_storage, storage_map)
#     688         return self.make_all(input_storage=input_storage,
#     689                              output_storage=output_storage,
# --> 690                              storage_map=storage_map)[:3]
#     691
#     692     def make_all(self, input_storage, output_storage):
#
# /home/ubuntu/anaconda2/lib/python2.7/site-packages/theano/gof/vm.pyc in make_all(self, profiler, input_storage, output_storage, storage_map)
#    1001                                                  storage_map,
#    1002                                                  compute_map,
# -> 1003                                                  no_recycling))
#    1004                 if not hasattr(thunks[-1], 'lazy'):
#    1005                     # We don't want all ops maker to think about lazy Ops.
#
# /home/ubuntu/anaconda2/lib/python2.7/site-packages/theano/gof/op.pyc in make_thunk(self, node, storage_map, compute_map, no_recycling)
#     968             try:
#     969                 return self.make_c_thunk(node, storage_map, compute_map,
# --> 970                                          no_recycling)
#     971             except (NotImplementedError, utils.MethodNotDefined):
#     972                 logger.debug('Falling back on perform')
#
# /home/ubuntu/anaconda2/lib/python2.7/site-packages/theano/gof/op.pyc in make_c_thunk(self, node, storage_map, compute_map, no_recycling)
#     877         logger.debug('Trying CLinker.make_thunk')
#     878         outputs = cl.make_thunk(input_storage=node_input_storage,
# --> 879                                 output_storage=node_output_storage)
#     880         fill_storage, node_input_filters, node_output_filters = outputs
#     881
#
# /home/ubuntu/anaconda2/lib/python2.7/site-packages/theano/gof/cc.pyc in make_thunk(self, input_storage, output_storage, storage_map, keep_lock)
#    1198         cthunk, in_storage, out_storage, error_storage = self.__compile__(
#    1199             input_storage, output_storage, storage_map,
# -> 1200             keep_lock=keep_lock)
#    1201
#    1202         res = _CThunk(cthunk, init_tasks, tasks, error_storage)
#
# /home/ubuntu/anaconda2/lib/python2.7/site-packages/theano/gof/cc.pyc in __compile__(self, input_storage, output_storage, storage_map, keep_lock)
#    1141                                     output_storage,
#    1142                                     storage_map,
# -> 1143                                     keep_lock=keep_lock)
#    1144         return (thunk,
#    1145                 [link.Container(input, storage) for input, storage in
#
# /home/ubuntu/anaconda2/lib/python2.7/site-packages/theano/gof/cc.pyc in cthunk_factory(self, error_storage, in_storage, out_storage, storage_map, keep_lock)
#    1593         else:
#    1594             module = get_module_cache().module_from_key(
# -> 1595                 key=key, lnk=self, keep_lock=keep_lock)
#    1596
#    1597         vars = self.inputs + self.outputs + self.orphans
#
# /home/ubuntu/anaconda2/lib/python2.7/site-packages/theano/gof/cmodule.pyc in module_from_key(self, key, lnk, keep_lock)
#    1140             try:
#    1141                 location = dlimport_workdir(self.dirname)
# -> 1142                 module = lnk.compile_cmodule(location)
#    1143                 name = module.__file__
#    1144                 assert name.startswith(location)
#
# /home/ubuntu/anaconda2/lib/python2.7/site-packages/theano/gof/cc.pyc in compile_cmodule(self, location)
#    1504                 lib_dirs=self.lib_dirs(),
#    1505                 libs=libs,
# -> 1506                 preargs=preargs)
#    1507         except Exception as e:
#    1508             e.args += (str(self.fgraph),)
#
# /home/ubuntu/anaconda2/lib/python2.7/site-packages/theano/gof/cmodule.pyc in compile_str(module_name, src_code, location, include_dirs, lib_dirs, libs, preargs, py_module, hide_symbols)
#    2180
#    2181         try:
# -> 2182             p_out = output_subprocess_Popen(cmd)
#    2183             compile_stderr = decode(p_out[1])
#    2184         except Exception:
#
# /home/ubuntu/anaconda2/lib/python2.7/site-packages/theano/misc/windows.pyc in output_subprocess_Popen(command, **params)
#      73     params['stdout'] = subprocess.PIPE
#      74     params['stderr'] = subprocess.PIPE
# ---> 75     p = subprocess_Popen(command, **params)
#      76     # we need to use communicate to make sure we don't deadlock around
#      77     # the stdour/stderr pipe.
#
# /home/ubuntu/anaconda2/lib/python2.7/site-packages/theano/misc/windows.pyc in subprocess_Popen(command, **params)
#      34
#      35     try:
# ---> 36         proc = subprocess.Popen(command, startupinfo=startupinfo, **params)
#      37     finally:
#      38         if stdin is not None:
#
# /home/ubuntu/anaconda2/lib/python2.7/subprocess.pyc in __init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags)
#     709                                 p2cread, p2cwrite,
#     710                                 c2pread, c2pwrite,
# --> 711                                 errread, errwrite)
#     712         except Exception:
#     713             # Preserve original exception in case os.close raises.
#
# /home/ubuntu/anaconda2/lib/python2.7/subprocess.pyc in _execute_child(self, args, executable, preexec_fn, close_fds, cwd, env, universal_newlines, startupinfo, creationflags, shell, to_close, p2cread, p2cwrite, c2pread, c2pwrite, errread, errwrite)
#    1233                     gc.disable()
#    1234                     try:
# -> 1235                         self.pid = os.fork()
#    1236                     except:
#    1237                         if gc_was_enabled:
#
# OSError: [Errno 12] Cannot allocate memory

# %%
lrg_model.compile(Adam(lr=0.001), loss='categorical_crossentropy', metrics=['accuracy'])

# %%
lrg_model.fit(conv_trn_feat, trn_labels, batch_size=batch_size, nb_epoch=2, 
             validation_data=(conv_val_feat, val_labels))
# Out:
# Problem occurred during compilation with the command line below:
# /usr/bin/g++ -shared -g -O3 -fno-math-errno -Wno-unused-label -Wno-unused-variable -Wno-write-strings -march=broadwell -mmmx -mno-3dnow -msse -msse2 -msse3 -mssse3 -mno-sse4a -mcx16 -msahf -mmovbe -maes -mno-sha -mpclmul -mpopcnt -mabm -mno-lwp -mfma -mno-fma4 -mno-xop -mbmi -mbmi2 -mno-tbm -mavx -mavx2 -msse4.2 -msse4.1 -mlzcnt -mrtm -mhle -mrdrnd -mf16c -mfsgsbase -mno-rdseed -mno-prfchw -mno-adx -mfxsr -mxsave -mxsaveopt -mno-avx512f -mno-avx512er -mno-avx512cd -mno-avx512pf -mno-prefetchwt1 -mno-clflushopt -mno-xsavec -mno-xsaves -mno-avx512dq -mno-avx512bw -mno-avx512vl -mno-avx512ifma -mno-avx512vbmi -mno-clwb -mno-pcommit -mno-mwaitx --param l1-cache-size=32 --param l1-cache-line-size=64 --param l2-cache-size=46080 -mtune=broadwell -DNPY_NO_DEPRECATED_API=NPY_1_7_API_VERSION -m64 -fPIC -I/home/ubuntu/anaconda2/lib/python2.7/site-packages/numpy/core/include -I/home/ubuntu/anaconda2/include/python2.7 -I/home/ubuntu/anaconda2/lib/python2.7/site-packages/theano/gof -fvisibility=hidden -o /home/ubuntu/.theano/compiledir_Linux-4.4--generic-x86_64-with-debian-stretch-sid-x86_64-2.7.12-64/tmp_dn7Zo/f60e4dbdd8c123e190603da34daaf8a0.so /home/ubuntu/.theano/compiledir_Linux-4.4--generic-x86_64-with-debian-stretch-sid-x86_64-2.7.12-64/tmp_dn7Zo/mod.cpp -L/home/ubuntu/anaconda2/lib -lpython2.7
# ERROR (theano.gof.cmodule): [Errno 12] Cannot allocate memory
# ERROR (theano.gof.opt): Optimization failure due to: constant_folding
# ERROR (theano.gof.opt): node: DimShuffle{}(TensorConstant{(1, 1, 1, 1) of 0.5})
# ERROR (theano.gof.opt): TRACEBACK:
# ERROR (theano.gof.opt): Traceback (most recent call last):
#   File "/home/ubuntu/anaconda2/lib/python2.7/site-packages/theano/gof/opt.py", line 1772, in process_node
#     replacements = lopt.transform(node)
#   File "/home/ubuntu/anaconda2/lib/python2.7/site-packages/theano/tensor/opt.py", line 5825, in constant_folding
#     no_recycling=[])
#   File "/home/ubuntu/anaconda2/lib/python2.7/site-packages/theano/gof/op.py", line 970, in make_thunk
#     no_recycling)
#   File "/home/ubuntu/anaconda2/lib/python2.7/site-packages/theano/gof/op.py", line 879, in make_c_thunk
#     output_storage=node_output_storage)
#   File "/home/ubuntu/anaconda2/lib/python2.7/site-packages/theano/gof/cc.py", line 1200, in make_thunk
#     keep_lock=keep_lock)
#   File "/home/ubuntu/anaconda2/lib/python2.7/site-packages/theano/gof/cc.py", line 1143, in __compile__
#     keep_lock=keep_lock)
#   File "/home/ubuntu/anaconda2/lib/python2.7/site-packages/theano/gof/cc.py", line 1595, in cthunk_factory
#     key=key, lnk=self, keep_lock=keep_lock)
#   File "/home/ubuntu/anaconda2/lib/python2.7/site-packages/theano/gof/cmodule.py", line 1142, in module_from_key
#     module = lnk.compile_cmodule(location)
#   File "/home/ubuntu/anaconda2/lib/python2.7/site-packages/theano/gof/cc.py", line 1506, in compile_cmodule
#     preargs=preargs)
#   File "/home/ubuntu/anaconda2/lib/python2.7/site-packages/theano/gof/cmodule.py", line 2182, in compile_str
#     p_out = output_subprocess_Popen(cmd)
#   File "/home/ubuntu/anaconda2/lib/python2.7/site-packages/theano/misc/windows.py", line 75, in output_subprocess_Popen
#     p = subprocess_Popen(command, **params)
#   File "/home/ubuntu/anaconda2/lib/python2.7/site-packages/theano/misc/windows.py", line 36, in subprocess_Popen
#     proc = subprocess.Popen(command, startupinfo=startupinfo, **params)
#   File "/home/ubuntu/anaconda2/lib/python2.7/subprocess.py", line 711, in __init__
#     errread, errwrite)
#   File "/home/ubuntu/anaconda2/lib/python2.7/subprocess.py", line 1235, in _execute_child
#     self.pid = os.fork()
# OSError: [Errno 12] Cannot allocate memory
#
# Problem occurred during compilation with the command line below:
# /usr/bin/g++ -shared -g -O3 -fno-math-errno -Wno-unused-label -Wno-unused-variable -Wno-write-strings -march=broadwell -mmmx -mno-3dnow -msse -msse2 -msse3 -mssse3 -mno-sse4a -mcx16 -msahf -mmovbe -maes -mno-sha -mpclmul -mpopcnt -mabm -mno-lwp -mfma -mno-fma4 -mno-xop -mbmi -mbmi2 -mno-tbm -mavx -mavx2 -msse4.2 -msse4.1 -mlzcnt -mrtm -mhle -mrdrnd -mf16c -mfsgsbase -mno-rdseed -mno-prfchw -mno-adx -mfxsr -mxsave -mxsaveopt -mno-avx512f -mno-avx512er -mno-avx512cd -mno-avx512pf -mno-prefetchwt1 -mno-clflushopt -mno-xsavec -mno-xsaves -mno-avx512dq -mno-avx512bw -mno-avx512vl -mno-avx512ifma -mno-avx512vbmi -mno-clwb -mno-pcommit -mno-mwaitx --param l1-cache-size=32 --param l1-cache-line-size=64 --param l2-cache-size=46080 -mtune=broadwell -DNPY_NO_DEPRECATED_API=NPY_1_7_API_VERSION -m64 -fPIC -I/home/ubuntu/anaconda2/lib/python2.7/site-packages/numpy/core/include -I/home/ubuntu/anaconda2/include/python2.7 -I/home/ubuntu/anaconda2/lib/python2.7/site-packages/theano/gof -fvisibility=hidden -o /home/ubuntu/.theano/compiledir_Linux-4.4--generic-x86_64-with-debian-stretch-sid-x86_64-2.7.12-64/tmpX8SIiS/f60e4dbdd8c123e190603da34daaf8a0.so /home/ubuntu/.theano/compiledir_Linux-4.4--generic-x86_64-with-debian-stretch-sid-x86_64-2.7.12-64/tmpX8SIiS/mod.cpp -L/home/ubuntu/anaconda2/lib -lpython2.7
# ERROR (theano.gof.cmodule): [Errno 12] Cannot allocate memory
# ERROR (theano.gof.opt): Optimization failure due to: constant_folding
# ERROR (theano.gof.opt): node: DimShuffle{}(TensorConstant{(1, 1, 1, 1) of 0.5})
# ERROR (theano.gof.opt): TRACEBACK:
# ERROR (theano.gof.opt): Traceback (most recent call last):
#   File "/home/ubuntu/anaconda2/lib/python2.7/site-packages/theano/gof/opt.py", line 1772, in process_node
#     replacements = lopt.transform(node)
#   File "/home/ubuntu/anaconda2/lib/python2.7/site-packages/theano/tensor/opt.py", line 5825, in constant_folding
#     no_recycling=[])
#   File "/home/ubuntu/anaconda2/lib/python2.7/site-packages/theano/gof/op.py", line 970, in make_thunk
#     no_recycling)
#   File "/home/ubuntu/anaconda2/lib/python2.7/site-packages/theano/gof/op.py", line 879, in make_c_thunk
#     output_storage=node_output_storage)
#   File "/home/ubuntu/anaconda2/lib/python2.7/site-packages/theano/gof/cc.py", line 1200, in make_thunk
#     keep_lock=keep_lock)
#   File "/home/ubuntu/anaconda2/lib/python2.7/site-packages/theano/gof/cc.py", line 1143, in __compile__
#     keep_lock=keep_lock)
#   File "/home/ubuntu/anaconda2/lib/python2.7/site-packages/theano/gof/cc.py", line 1595, in cthunk_factory
#     key=key, lnk=self, keep_lock=keep_lock)
#   File "/home/ubuntu/anaconda2/lib/python2.7/site-packages/theano/gof/cmodule.py", line 1142, in module_from_key
#     module = lnk.compile_cmodule(location)
#   File "/home/ubuntu/anaconda2/lib/python2.7/site-packages/theano/gof/cc.py", line 1506, in compile_cmodule
#     preargs=preargs)
#   File "/home/ubuntu/anaconda2/lib/python2.7/site-packages/theano/gof/cmodule.py", line 2182, in compile_str
#     p_out = output_subprocess_Popen(cmd)
#   File "/home/ubuntu/anaconda2/lib/python2.7/site-packages/theano/misc/windows.py", line 75, in output_subprocess_Popen
#     p = subprocess_Popen(command, **params)
#   File "/home/ubuntu/anaconda2/lib/python2.7/site-packages/theano/misc/windows.py", line 36, in subprocess_Popen
#     proc = subprocess.Popen(command, startupinfo=startupinfo, **params)
#   File "/home/ubuntu/anaconda2/lib/python2.7/subprocess.py", line 711, in __init__
#     errread, errwrite)
#   File "/home/ubuntu/anaconda2/lib/python2.7/subprocess.py", line 1235, in _execute_child
#     self.pid = os.fork()
# OSError: [Errno 12] Cannot allocate memory
#
# Problem occurred during compilation with the command line below:
# /usr/bin/g++ -shared -g -O3 -fno-math-errno -Wno-unused-label -Wno-unused-variable -Wno-write-strings -march=broadwell -mmmx -mno-3dnow -msse -msse2 -msse3 -mssse3 -mno-sse4a -mcx16 -msahf -mmovbe -maes -mno-sha -mpclmul -mpopcnt -mabm -mno-lwp -mfma -mno-fma4 -mno-xop -mbmi -mbmi2 -mno-tbm -mavx -mavx2 -msse4.2 -msse4.1 -mlzcnt -mrtm -mhle -mrdrnd -mf16c -mfsgsbase -mno-rdseed -mno-prfchw -mno-adx -mfxsr -mxsave -mxsaveopt -mno-avx512f -mno-avx512er -mno-avx512cd -mno-avx512pf -mno-prefetchwt1 -mno-clflushopt -mno-xsavec -mno-xsaves -mno-avx512dq -mno-avx512bw -mno-avx512vl -mno-avx512ifma -mno-avx512vbmi -mno-clwb -mno-pcommit -mno-mwaitx --param l1-cache-size=32 --param l1-cache-line-size=64 --param l2-cache-size=46080 -mtune=broadwell -DNPY_NO_DEPRECATED_API=NPY_1_7_API_VERSION -m64 -fPIC -I/home/ubuntu/anaconda2/lib/python2.7/site-packages/numpy/core/include -I/home/ubuntu/anaconda2/include/python2.7 -I/home/ubuntu/anaconda2/lib/python2.7/site-packages/theano/gof -fvisibility=hidden -o /home/ubuntu/.theano/compiledir_Linux-4.4--generic-x86_64-with-debian-stretch-sid-x86_64-2.7.12-64/tmpK5Xvdf/f60e4dbdd8c123e190603da34daaf8a0.so /home/ubuntu/.theano/compiledir_Linux-4.4--generic-x86_64-with-debian-stretch-sid-x86_64-2.7.12-64/tmpK5Xvdf/mod.cpp -L/home/ubuntu/anaconda2/lib -lpython2.7
# ERROR (theano.gof.cmodule): [Errno 12] Cannot allocate memory
# ERROR (theano.gof.opt): Optimization failure due to: constant_folding
# ERROR (theano.gof.opt): node: DimShuffle{}(TensorConstant{(1, 1, 1, 1) of 0.5})
# ERROR (theano.gof.opt): TRACEBACK:
# ERROR (theano.gof.opt): Traceback (most recent call last):
#   File "/home/ubuntu/anaconda2/lib/python2.7/site-packages/theano/gof/opt.py", line 1772, in process_node
#     replacements = lopt.transform(node)
#   File "/home/ubuntu/anaconda2/lib/python2.7/site-packages/theano/tensor/opt.py", line 5825, in constant_folding
#     no_recycling=[])
#   File "/home/ubuntu/anaconda2/lib/python2.7/site-packages/theano/gof/op.py", line 970, in make_thunk
#     no_recycling)
#   File "/home/ubuntu/anaconda2/lib/python2.7/site-packages/theano/gof/op.py", line 879, in make_c_thunk
#     output_storage=node_output_storage)
#   File "/home/ubuntu/anaconda2/lib/python2.7/site-packages/theano/gof/cc.py", line 1200, in make_thunk
#     keep_lock=keep_lock)
#   File "/home/ubuntu/anaconda2/lib/python2.7/site-packages/theano/gof/cc.py", line 1143, in __compile__
#     keep_lock=keep_lock)
#   File "/home/ubuntu/anaconda2/lib/python2.7/site-packages/theano/gof/cc.py", line 1595, in cthunk_factory
#     key=key, lnk=self, keep_lock=keep_lock)
#   File "/home/ubuntu/anaconda2/lib/python2.7/site-packages/theano/gof/cmodule.py", line 1142, in module_from_key
#     module = lnk.compile_cmodule(location)
#   File "/home/ubuntu/anaconda2/lib/python2.7/site-packages/theano/gof/cc.py", line 1506, in compile_cmodule
#     preargs=preargs)
#   File "/home/ubuntu/anaconda2/lib/python2.7/site-packages/theano/gof/cmodule.py", line 2182, in compile_str
#     p_out = output_subprocess_Popen(cmd)
#   File "/home/ubuntu/anaconda2/lib/python2.7/site-packages/theano/misc/windows.py", line 75, in output_subprocess_Popen
#     p = subprocess_Popen(command, **params)
#   File "/home/ubuntu/anaconda2/lib/python2.7/site-packages/theano/misc/windows.py", line 36, in subprocess_Popen
#     proc = subprocess.Popen(command, startupinfo=startupinfo, **params)
#   File "/home/ubuntu/anaconda2/lib/python2.7/subprocess.py", line 711, in __init__
#     errread, errwrite)
#   File "/home/ubuntu/anaconda2/lib/python2.7/subprocess.py", line 1235, in _execute_child
#     self.pid = os.fork()
# OSError: [Errno 12] Cannot allocate memory
#
# Problem occurred during compilation with the command line below:
# /usr/bin/g++ -shared -g -O3 -fno-math-errno -Wno-unused-label -Wno-unused-variable -Wno-write-strings -march=broadwell -mmmx -mno-3dnow -msse -msse2 -msse3 -mssse3 -mno-sse4a -mcx16 -msahf -mmovbe -maes -mno-sha -mpclmul -mpopcnt -mabm -mno-lwp -mfma -mno-fma4 -mno-xop -mbmi -mbmi2 -mno-tbm -mavx -mavx2 -msse4.2 -msse4.1 -mlzcnt -mrtm -mhle -mrdrnd -mf16c -mfsgsbase -mno-rdseed -mno-prfchw -mno-adx -mfxsr -mxsave -mxsaveopt -mno-avx512f -mno-avx512er -mno-avx512cd -mno-avx512pf -mno-prefetchwt1 -mno-clflushopt -mno-xsavec -mno-xsaves -mno-avx512dq -mno-avx512bw -mno-avx512vl -mno-avx512ifma -mno-avx512vbmi -mno-clwb -mno-pcommit -mno-mwaitx --param l1-cache-size=32 --param l1-cache-line-size=64 --param l2-cache-size=46080 -mtune=broadwell -DNPY_NO_DEPRECATED_API=NPY_1_7_API_VERSION -m64 -fPIC -I/home/ubuntu/anaconda2/lib/python2.7/site-packages/numpy/core/include -I/home/ubuntu/anaconda2/include/python2.7 -I/home/ubuntu/anaconda2/lib/python2.7/site-packages/theano/gof -fvisibility=hidden -o /home/ubuntu/.theano/compiledir_Linux-4.4--generic-x86_64-with-debian-stretch-sid-x86_64-2.7.12-64/tmpzuTRvd/423b37ed9361000aa5ee9e740468ece6.so /home/ubuntu/.theano/compiledir_Linux-4.4--generic-x86_64-with-debian-stretch-sid-x86_64-2.7.12-64/tmpzuTRvd/mod.cpp -L/home/ubuntu/anaconda2/lib -lpython2.7
# ERROR (theano.gof.cmodule): [Errno 12] Cannot allocate memory
# ERROR (theano.gof.opt): Optimization failure due to: constant_folding
# ERROR (theano.gof.opt): node: DimShuffle{x}(TensorConstant{(1, 1, 1, 1) of 0.5})
# ERROR (theano.gof.opt): TRACEBACK:
# ERROR (theano.gof.opt): Traceback (most recent call last):
#   File "/home/ubuntu/anaconda2/lib/python2.7/site-packages/theano/gof/opt.py", line 1772, in process_node
#     replacements = lopt.transform(node)
#   File "/home/ubuntu/anaconda2/lib/python2.7/site-packages/theano/tensor/opt.py", line 5825, in constant_folding
#     no_recycling=[])
#   File "/home/ubuntu/anaconda2/lib/python2.7/site-packages/theano/gof/op.py", line 970, in make_thunk
#     no_recycling)
#   File "/home/ubuntu/anaconda2/lib/python2.7/site-packages/theano/gof/op.py", line 879, in make_c_thunk
#     output_storage=node_output_storage)
#   File "/home/ubuntu/anaconda2/lib/python2.7/site-packages/theano/gof/cc.py", line 1200, in make_thunk
#     keep_lock=keep_lock)
#   File "/home/ubuntu/anaconda2/lib/python2.7/site-packages/theano/gof/cc.py", line 1143, in __compile__
#     keep_lock=keep_lock)
#   File "/home/ubuntu/anaconda2/lib/python2.7/site-packages/theano/gof/cc.py", line 1595, in cthunk_factory
#     key=key, lnk=self, keep_lock=keep_lock)
#   File "/home/ubuntu/anaconda2/lib/python2.7/site-packages/theano/gof/cmodule.py", line 1142, in module_from_key
#     module = lnk.compile_cmodule(location)
#   File "/home/ubuntu/anaconda2/lib/python2.7/site-packages/theano/gof/cc.py", line 1506, in compile_cmodule
#     preargs=preargs)
#   File "/home/ubuntu/anaconda2/lib/python2.7/site-packages/theano/gof/cmodule.py", line 2182, in compile_str
#     p_out = output_subprocess_Popen(cmd)
#   File "/home/ubuntu/anaconda2/lib/python2.7/site-packages/theano/misc/windows.py", line 75, in output_subprocess_Popen
#     p = subprocess_Popen(command, **params)
#   File "/home/ubuntu/anaconda2/lib/python2.7/site-packages/theano/misc/windows.py", line 36, in subprocess_Popen
#     proc = subprocess.Popen(command, startupinfo=startupinfo, **params)
#   File "/home/ubuntu/anaconda2/lib/python2.7/subprocess.py", line 711, in __init__
#     errread, errwrite)
#   File "/home/ubuntu/anaconda2/lib/python2.7/subprocess.py", line 1235, in _execute_child
#     self.pid = os.fork()
# OSError: [Errno 12] Cannot allocate memory
#
# Problem occurred during compilation with the command line below:
# /usr/bin/g++ -shared -g -O3 -fno-math-errno -Wno-unused-label -Wno-unused-variable -Wno-write-strings -march=broadwell -mmmx -mno-3dnow -msse -msse2 -msse3 -mssse3 -mno-sse4a -mcx16 -msahf -mmovbe -maes -mno-sha -mpclmul -mpopcnt -mabm -mno-lwp -mfma -mno-fma4 -mno-xop -mbmi -mbmi2 -mno-tbm -mavx -mavx2 -msse4.2 -msse4.1 -mlzcnt -mrtm -mhle -mrdrnd -mf16c -mfsgsbase -mno-rdseed -mno-prfchw -mno-adx -mfxsr -mxsave -mxsaveopt -mno-avx512f -mno-avx512er -mno-avx512cd -mno-avx512pf -mno-prefetchwt1 -mno-clflushopt -mno-xsavec -mno-xsaves -mno-avx512dq -mno-avx512bw -mno-avx512vl -mno-avx512ifma -mno-avx512vbmi -mno-clwb -mno-pcommit -mno-mwaitx --param l1-cache-size=32 --param l1-cache-line-size=64 --param l2-cache-size=46080 -mtune=broadwell -DNPY_NO_DEPRECATED_API=NPY_1_7_API_VERSION -m64 -fPIC -I/home/ubuntu/anaconda2/lib/python2.7/site-packages/numpy/core/include -I/home/ubuntu/anaconda2/include/python2.7 -I/home/ubuntu/anaconda2/lib/python2.7/site-packages/theano/gof -fvisibility=hidden -o /home/ubuntu/.theano/compiledir_Linux-4.4--generic-x86_64-with-debian-stretch-sid-x86_64-2.7.12-64/tmpBsyPM4/423b37ed9361000aa5ee9e740468ece6.so /home/ubuntu/.theano/compiledir_Linux-4.4--generic-x86_64-with-debian-stretch-sid-x86_64-2.7.12-64/tmpBsyPM4/mod.cpp -L/home/ubuntu/anaconda2/lib -lpython2.7
# ERROR (theano.gof.cmodule): [Errno 12] Cannot allocate memory
# ERROR (theano.gof.opt): Optimization failure due to: constant_folding
# ERROR (theano.gof.opt): node: DimShuffle{x}(TensorConstant{(1, 1, 1, 1) of 0.5})
# ERROR (theano.gof.opt): TRACEBACK:
# ERROR (theano.gof.opt): Traceback (most recent call last):
#   File "/home/ubuntu/anaconda2/lib/python2.7/site-packages/theano/gof/opt.py", line 1772, in process_node
#     replacements = lopt.transform(node)
#   File "/home/ubuntu/anaconda2/lib/python2.7/site-packages/theano/tensor/opt.py", line 5825, in constant_folding
#     no_recycling=[])
#   File "/home/ubuntu/anaconda2/lib/python2.7/site-packages/theano/gof/op.py", line 970, in make_thunk
#     no_recycling)
#   File "/home/ubuntu/anaconda2/lib/python2.7/site-packages/theano/gof/op.py", line 879, in make_c_thunk
#     output_storage=node_output_storage)
#   File "/home/ubuntu/anaconda2/lib/python2.7/site-packages/theano/gof/cc.py", line 1200, in make_thunk
#     keep_lock=keep_lock)
#   File "/home/ubuntu/anaconda2/lib/python2.7/site-packages/theano/gof/cc.py", line 1143, in __compile__
#     keep_lock=keep_lock)
#   File "/home/ubuntu/anaconda2/lib/python2.7/site-packages/theano/gof/cc.py", line 1595, in cthunk_factory
#     key=key, lnk=self, keep_lock=keep_lock)
#   File "/home/ubuntu/anaconda2/lib/python2.7/site-packages/theano/gof/cmodule.py", line 1142, in module_from_key
#     module = lnk.compile_cmodule(location)
#   File "/home/ubuntu/anaconda2/lib/python2.7/site-packages/theano/gof/cc.py", line 1506, in compile_cmodule
#     preargs=preargs)
#   File "/home/ubuntu/anaconda2/lib/python2.7/site-packages/theano/gof/cmodule.py", line 2182, in compile_str
#     p_out = output_subprocess_Popen(cmd)
#   File "/home/ubuntu/anaconda2/lib/python2.7/site-packages/theano/misc/windows.py", line 75, in output_subprocess_Popen
#     p = subprocess_Popen(command, **params)
#   File "/home/ubuntu/anaconda2/lib/python2.7/site-packages/theano/misc/windows.py", line 36, in subprocess_Popen
#     proc = subprocess.Popen(command, startupinfo=startupinfo, **params)
#   File "/home/ubuntu/anaconda2/lib/python2.7/subprocess.py", line 711, in __init__
#     errread, errwrite)
#   File "/home/ubuntu/anaconda2/lib/python2.7/subprocess.py", line 1235, in _execute_child
#     self.pid = os.fork()
# OSError: [Errno 12] Cannot allocate memory
#
# Problem occurred during compilation with the command line below:
# /usr/bin/g++ -shared -g -O3 -fno-math-errno -Wno-unused-label -Wno-unused-variable -Wno-write-strings -march=broadwell -mmmx -mno-3dnow -msse -msse2 -msse3 -mssse3 -mno-sse4a -mcx16 -msahf -mmovbe -maes -mno-sha -mpclmul -mpopcnt -mabm -mno-lwp -mfma -mno-fma4 -mno-xop -mbmi -mbmi2 -mno-tbm -mavx -mavx2 -msse4.2 -msse4.1 -mlzcnt -mrtm -mhle -mrdrnd -mf16c -mfsgsbase -mno-rdseed -mno-prfchw -mno-adx -mfxsr -mxsave -mxsaveopt -mno-avx512f -mno-avx512er -mno-avx512cd -mno-avx512pf -mno-prefetchwt1 -mno-clflushopt -mno-xsavec -mno-xsaves -mno-avx512dq -mno-avx512bw -mno-avx512vl -mno-avx512ifma -mno-avx512vbmi -mno-clwb -mno-pcommit -mno-mwaitx --param l1-cache-size=32 --param l1-cache-line-size=64 --param l2-cache-size=46080 -mtune=broadwell -DNPY_NO_DEPRECATED_API=NPY_1_7_API_VERSION -m64 -fPIC -I/home/ubuntu/anaconda2/lib/python2.7/site-packages/numpy/core/include -I/home/ubuntu/anaconda2/include/python2.7 -I/home/ubuntu/anaconda2/lib/python2.7/site-packages/theano/gof -fvisibility=hidden -o /home/ubuntu/.theano/compiledir_Linux-4.4--generic-x86_64-with-debian-stretch-sid-x86_64-2.7.12-64/tmpXZgCZt/423b37ed9361000aa5ee9e740468ece6.so /home/ubuntu/.theano/compiledir_Linux-4.4--generic-x86_64-with-debian-stretch-sid-x86_64-2.7.12-64/tmpXZgCZt/mod.cpp -L/home/ubuntu/anaconda2/lib -lpython2.7
# ERROR (theano.gof.cmodule): [Errno 12] Cannot allocate memory
# ERROR (theano.gof.opt): Optimization failure due to: constant_folding
# ERROR (theano.gof.opt): node: DimShuffle{x}(TensorConstant{(1, 1, 1, 1) of 0.5})
# ERROR (theano.gof.opt): TRACEBACK:
# ERROR (theano.gof.opt): Traceback (most recent call last):
#   File "/home/ubuntu/anaconda2/lib/python2.7/site-packages/theano/gof/opt.py", line 1772, in process_node
#     replacements = lopt.transform(node)
#   File "/home/ubuntu/anaconda2/lib/python2.7/site-packages/theano/tensor/opt.py", line 5825, in constant_folding
#     no_recycling=[])
#   File "/home/ubuntu/anaconda2/lib/python2.7/site-packages/theano/gof/op.py", line 970, in make_thunk
#     no_recycling)
#   File "/home/ubuntu/anaconda2/lib/python2.7/site-packages/theano/gof/op.py", line 879, in make_c_thunk
#     output_storage=node_output_storage)
#   File "/home/ubuntu/anaconda2/lib/python2.7/site-packages/theano/gof/cc.py", line 1200, in make_thunk
#     keep_lock=keep_lock)
#   File "/home/ubuntu/anaconda2/lib/python2.7/site-packages/theano/gof/cc.py", line 1143, in __compile__
#     keep_lock=keep_lock)
#   File "/home/ubuntu/anaconda2/lib/python2.7/site-packages/theano/gof/cc.py", line 1595, in cthunk_factory
#     key=key, lnk=self, keep_lock=keep_lock)
#   File "/home/ubuntu/anaconda2/lib/python2.7/site-packages/theano/gof/cmodule.py", line 1142, in module_from_key
#     module = lnk.compile_cmodule(location)
#   File "/home/ubuntu/anaconda2/lib/python2.7/site-packages/theano/gof/cc.py", line 1506, in compile_cmodule
#     preargs=preargs)
#   File "/home/ubuntu/anaconda2/lib/python2.7/site-packages/theano/gof/cmodule.py", line 2182, in compile_str
#     p_out = output_subprocess_Popen(cmd)
#   File "/home/ubuntu/anaconda2/lib/python2.7/site-packages/theano/misc/windows.py", line 75, in output_subprocess_Popen
#     p = subprocess_Popen(command, **params)
#   File "/home/ubuntu/anaconda2/lib/python2.7/site-packages/theano/misc/windows.py", line 36, in subprocess_Popen
#     proc = subprocess.Popen(command, startupinfo=startupinfo, **params)
#   File "/home/ubuntu/anaconda2/lib/python2.7/subprocess.py", line 711, in __init__
#     errread, errwrite)
#   File "/home/ubuntu/anaconda2/lib/python2.7/subprocess.py", line 1235, in _execute_child
#     self.pid = os.fork()
# OSError: [Errno 12] Cannot allocate memory
#
# Problem occurred during compilation with the command line below:
# /usr/bin/g++ -shared -g -O3 -fno-math-errno -Wno-unused-label -Wno-unused-variable -Wno-write-strings -march=broadwell -mmmx -mno-3dnow -msse -msse2 -msse3 -mssse3 -mno-sse4a -mcx16 -msahf -mmovbe -maes -mno-sha -mpclmul -mpopcnt -mabm -mno-lwp -mfma -mno-fma4 -mno-xop -mbmi -mbmi2 -mno-tbm -mavx -mavx2 -msse4.2 -msse4.1 -mlzcnt -mrtm -mhle -mrdrnd -mf16c -mfsgsbase -mno-rdseed -mno-prfchw -mno-adx -mfxsr -mxsave -mxsaveopt -mno-avx512f -mno-avx512er -mno-avx512cd -mno-avx512pf -mno-prefetchwt1 -mno-clflushopt -mno-xsavec -mno-xsaves -mno-avx512dq -mno-avx512bw -mno-avx512vl -mno-avx512ifma -mno-avx512vbmi -mno-clwb -mno-pcommit -mno-mwaitx --param l1-cache-size=32 --param l1-cache-line-size=64 --param l2-cache-size=46080 -mtune=broadwell -DNPY_NO_DEPRECATED_API=NPY_1_7_API_VERSION -m64 -fPIC -I/home/ubuntu/anaconda2/lib/python2.7/site-packages/numpy/core/include -I/home/ubuntu/anaconda2/include/python2.7 -I/home/ubuntu/anaconda2/lib/python2.7/site-packages/theano/gof -fvisibility=hidden -o /home/ubuntu/.theano/compiledir_Linux-4.4--generic-x86_64-with-debian-stretch-sid-x86_64-2.7.12-64/tmpDWMaJ_/423b37ed9361000aa5ee9e740468ece6.so /home/ubuntu/.theano/compiledir_Linux-4.4--generic-x86_64-with-debian-stretch-sid-x86_64-2.7.12-64/tmpDWMaJ_/mod.cpp -L/home/ubuntu/anaconda2/lib -lpython2.7
# ERROR (theano.gof.cmodule): [Errno 12] Cannot allocate memory
# ERROR (theano.gof.opt): Optimization failure due to: constant_folding
# ERROR (theano.gof.opt): node: DimShuffle{x}(TensorConstant{(1, 1, 1, 1) of 0.5})
# ERROR (theano.gof.opt): TRACEBACK:
# ERROR (theano.gof.opt): Traceback (most recent call last):
#   File "/home/ubuntu/anaconda2/lib/python2.7/site-packages/theano/gof/opt.py", line 1772, in process_node
#     replacements = lopt.transform(node)
#   File "/home/ubuntu/anaconda2/lib/python2.7/site-packages/theano/tensor/opt.py", line 5825, in constant_folding
#     no_recycling=[])
#   File "/home/ubuntu/anaconda2/lib/python2.7/site-packages/theano/gof/op.py", line 970, in make_thunk
#     no_recycling)
#   File "/home/ubuntu/anaconda2/lib/python2.7/site-packages/theano/gof/op.py", line 879, in make_c_thunk
#     output_storage=node_output_storage)
#   File "/home/ubuntu/anaconda2/lib/python2.7/site-packages/theano/gof/cc.py", line 1200, in make_thunk
#     keep_lock=keep_lock)
#   File "/home/ubuntu/anaconda2/lib/python2.7/site-packages/theano/gof/cc.py", line 1143, in __compile__
#     keep_lock=keep_lock)
#   File "/home/ubuntu/anaconda2/lib/python2.7/site-packages/theano/gof/cc.py", line 1595, in cthunk_factory
#     key=key, lnk=self, keep_lock=keep_lock)
#   File "/home/ubuntu/anaconda2/lib/python2.7/site-packages/theano/gof/cmodule.py", line 1142, in module_from_key
#     module = lnk.compile_cmodule(location)
#   File "/home/ubuntu/anaconda2/lib/python2.7/site-packages/theano/gof/cc.py", line 1506, in compile_cmodule
#     preargs=preargs)
#   File "/home/ubuntu/anaconda2/lib/python2.7/site-packages/theano/gof/cmodule.py", line 2182, in compile_str
#     p_out = output_subprocess_Popen(cmd)
#   File "/home/ubuntu/anaconda2/lib/python2.7/site-packages/theano/misc/windows.py", line 75, in output_subprocess_Popen
#     p = subprocess_Popen(command, **params)
#   File "/home/ubuntu/anaconda2/lib/python2.7/site-packages/theano/misc/windows.py", line 36, in subprocess_Popen
#     proc = subprocess.Popen(command, startupinfo=startupinfo, **params)
#   File "/home/ubuntu/anaconda2/lib/python2.7/subprocess.py", line 711, in __init__
#     errread, errwrite)
#   File "/home/ubuntu/anaconda2/lib/python2.7/subprocess.py", line 1235, in _execute_child
#     self.pid = os.fork()
# OSError: [Errno 12] Cannot allocate memory
#
# Problem occurred during compilation with the command line below:
# /usr/bin/g++ -shared -g -O3 -fno-math-errno -Wno-unused-label -Wno-unused-variable -Wno-write-strings -march=broadwell -mmmx -mno-3dnow -msse -msse2 -msse3 -mssse3 -mno-sse4a -mcx16 -msahf -mmovbe -maes -mno-sha -mpclmul -mpopcnt -mabm -mno-lwp -mfma -mno-fma4 -mno-xop -mbmi -mbmi2 -mno-tbm -mavx -mavx2 -msse4.2 -msse4.1 -mlzcnt -mrtm -mhle -mrdrnd -mf16c -mfsgsbase -mno-rdseed -mno-prfchw -mno-adx -mfxsr -mxsave -mxsaveopt -mno-avx512f -mno-avx512er -mno-avx512cd -mno-avx512pf -mno-prefetchwt1 -mno-clflushopt -mno-xsavec -mno-xsaves -mno-avx512dq -mno-avx512bw -mno-avx512vl -mno-avx512ifma -mno-avx512vbmi -mno-clwb -mno-pcommit -mno-mwaitx --param l1-cache-size=32 --param l1-cache-line-size=64 --param l2-cache-size=46080 -mtune=broadwell -DNPY_NO_DEPRECATED_API=NPY_1_7_API_VERSION -m64 -fPIC -I/home/ubuntu/anaconda2/lib/python2.7/site-packages/numpy/core/include -I/home/ubuntu/anaconda2/include/python2.7 -I/home/ubuntu/anaconda2/lib/python2.7/site-packages/theano/gof -fvisibility=hidden -o /home/ubuntu/.theano/compiledir_Linux-4.4--generic-x86_64-with-debian-stretch-sid-x86_64-2.7.12-64/tmpFbKBzX/423b37ed9361000aa5ee9e740468ece6.so /home/ubuntu/.theano/compiledir_Linux-4.4--generic-x86_64-with-debian-stretch-sid-x86_64-2.7.12-64/tmpFbKBzX/mod.cpp -L/home/ubuntu/anaconda2/lib -lpython2.7
# ERROR (theano.gof.cmodule): [Errno 12] Cannot allocate memory
# ERROR (theano.gof.opt): Optimization failure due to: constant_folding
# ERROR (theano.gof.opt): node: DimShuffle{x}(TensorConstant{(1, 1, 1, 1) of 0.5})
# ERROR (theano.gof.opt): TRACEBACK:
# ERROR (theano.gof.opt): Traceback (most recent call last):
#   File "/home/ubuntu/anaconda2/lib/python2.7/site-packages/theano/gof/opt.py", line 1772, in process_node
#     replacements = lopt.transform(node)
#   File "/home/ubuntu/anaconda2/lib/python2.7/site-packages/theano/tensor/opt.py", line 5825, in constant_folding
#     no_recycling=[])
#   File "/home/ubuntu/anaconda2/lib/python2.7/site-packages/theano/gof/op.py", line 970, in make_thunk
#     no_recycling)
#   File "/home/ubuntu/anaconda2/lib/python2.7/site-packages/theano/gof/op.py", line 879, in make_c_thunk
#     output_storage=node_output_storage)
#   File "/home/ubuntu/anaconda2/lib/python2.7/site-packages/theano/gof/cc.py", line 1200, in make_thunk
#     keep_lock=keep_lock)
#   File "/home/ubuntu/anaconda2/lib/python2.7/site-packages/theano/gof/cc.py", line 1143, in __compile__
#     keep_lock=keep_lock)
#   File "/home/ubuntu/anaconda2/lib/python2.7/site-packages/theano/gof/cc.py", line 1595, in cthunk_factory
#     key=key, lnk=self, keep_lock=keep_lock)
#   File "/home/ubuntu/anaconda2/lib/python2.7/site-packages/theano/gof/cmodule.py", line 1142, in module_from_key
#     module = lnk.compile_cmodule(location)
#   File "/home/ubuntu/anaconda2/lib/python2.7/site-packages/theano/gof/cc.py", line 1506, in compile_cmodule
#     preargs=preargs)
#   File "/home/ubuntu/anaconda2/lib/python2.7/site-packages/theano/gof/cmodule.py", line 2182, in compile_str
#     p_out = output_subprocess_Popen(cmd)
#   File "/home/ubuntu/anaconda2/lib/python2.7/site-packages/theano/misc/windows.py", line 75, in output_subprocess_Popen
#     p = subprocess_Popen(command, **params)
#   File "/home/ubuntu/anaconda2/lib/python2.7/site-packages/theano/misc/windows.py", line 36, in subprocess_Popen
#     proc = subprocess.Popen(command, startupinfo=startupinfo, **params)
#   File "/home/ubuntu/anaconda2/lib/python2.7/subprocess.py", line 711, in __init__
#     errread, errwrite)
#   File "/home/ubuntu/anaconda2/lib/python2.7/subprocess.py", line 1235, in _execute_child
#     self.pid = os.fork()
# OSError: [Errno 12] Cannot allocate memory
#
# Problem occurred during compilation with the command line below:
# /usr/bin/g++ -shared -g -O3 -fno-math-errno -Wno-unused-label -Wno-unused-variable -Wno-write-strings -march=broadwell -mmmx -mno-3dnow -msse -msse2 -msse3 -mssse3 -mno-sse4a -mcx16 -msahf -mmovbe -maes -mno-sha -mpclmul -mpopcnt -mabm -mno-lwp -mfma -mno-fma4 -mno-xop -mbmi -mbmi2 -mno-tbm -mavx -mavx2 -msse4.2 -msse4.1 -mlzcnt -mrtm -mhle -mrdrnd -mf16c -mfsgsbase -mno-rdseed -mno-prfchw -mno-adx -mfxsr -mxsave -mxsaveopt -mno-avx512f -mno-avx512er -mno-avx512cd -mno-avx512pf -mno-prefetchwt1 -mno-clflushopt -mno-xsavec -mno-xsaves -mno-avx512dq -mno-avx512bw -mno-avx512vl -mno-avx512ifma -mno-avx512vbmi -mno-clwb -mno-pcommit -mno-mwaitx --param l1-cache-size=32 --param l1-cache-line-size=64 --param l2-cache-size=46080 -mtune=broadwell -DNPY_NO_DEPRECATED_API=NPY_1_7_API_VERSION -m64 -fPIC -I/home/ubuntu/anaconda2/lib/python2.7/site-packages/numpy/core/include -I/home/ubuntu/anaconda2/include/python2.7 -I/home/ubuntu/anaconda2/lib/python2.7/site-packages/theano/gof -fvisibility=hidden -o /home/ubuntu/.theano/compiledir_Linux-4.4--generic-x86_64-with-debian-stretch-sid-x86_64-2.7.12-64/tmpVU7SIb/423b37ed9361000aa5ee9e740468ece6.so /home/ubuntu/.theano/compiledir_Linux-4.4--generic-x86_64-with-debian-stretch-sid-x86_64-2.7.12-64/tmpVU7SIb/mod.cpp -L/home/ubuntu/anaconda2/lib -lpython2.7
# ERROR (theano.gof.cmodule): [Errno 12] Cannot allocate memory
# ERROR (theano.gof.opt): Optimization failure due to: constant_folding
# ERROR (theano.gof.opt): node: DimShuffle{x}(TensorConstant{(1, 1, 1, 1) of 0.5})
# ERROR (theano.gof.opt): TRACEBACK:
# ERROR (theano.gof.opt): Traceback (most recent call last):
#   File "/home/ubuntu/anaconda2/lib/python2.7/site-packages/theano/gof/opt.py", line 1772, in process_node
#     replacements = lopt.transform(node)
#   File "/home/ubuntu/anaconda2/lib/python2.7/site-packages/theano/tensor/opt.py", line 5825, in constant_folding
#     no_recycling=[])
#   File "/home/ubuntu/anaconda2/lib/python2.7/site-packages/theano/gof/op.py", line 970, in make_thunk
#     no_recycling)
#   File "/home/ubuntu/anaconda2/lib/python2.7/site-packages/theano/gof/op.py", line 879, in make_c_thunk
#     output_storage=node_output_storage)
#   File "/home/ubuntu/anaconda2/lib/python2.7/site-packages/theano/gof/cc.py", line 1200, in make_thunk
#     keep_lock=keep_lock)
#   File "/home/ubuntu/anaconda2/lib/python2.7/site-packages/theano/gof/cc.py", line 1143, in __compile__
#     keep_lock=keep_lock)
#   File "/home/ubuntu/anaconda2/lib/python2.7/site-packages/theano/gof/cc.py", line 1595, in cthunk_factory
#     key=key, lnk=self, keep_lock=keep_lock)
#   File "/home/ubuntu/anaconda2/lib/python2.7/site-packages/theano/gof/cmodule.py", line 1142, in module_from_key
#     module = lnk.compile_cmodule(location)
#   File "/home/ubuntu/anaconda2/lib/python2.7/site-packages/theano/gof/cc.py", line 1506, in compile_cmodule
#     preargs=preargs)
#   File "/home/ubuntu/anaconda2/lib/python2.7/site-packages/theano/gof/cmodule.py", line 2182, in compile_str
#     p_out = output_subprocess_Popen(cmd)
#   File "/home/ubuntu/anaconda2/lib/python2.7/site-packages/theano/misc/windows.py", line 75, in output_subprocess_Popen
#     p = subprocess_Popen(command, **params)
#   File "/home/ubuntu/anaconda2/lib/python2.7/site-packages/theano/misc/windows.py", line 36, in subprocess_Popen
#     proc = subprocess.Popen(command, startupinfo=startupinfo, **params)
#   File "/home/ubuntu/anaconda2/lib/python2.7/subprocess.py", line 711, in __init__
#     errread, errwrite)
#   File "/home/ubuntu/anaconda2/lib/python2.7/subprocess.py", line 1235, in _execute_child
#     self.pid = os.fork()
# OSError: [Errno 12] Cannot allocate memory
#
# Problem occurred during compilation with the command line below:
# /usr/bin/g++ -shared -g -O3 -fno-math-errno -Wno-unused-label -Wno-unused-variable -Wno-write-strings -march=broadwell -mmmx -mno-3dnow -msse -msse2 -msse3 -mssse3 -mno-sse4a -mcx16 -msahf -mmovbe -maes -mno-sha -mpclmul -mpopcnt -mabm -mno-lwp -mfma -mno-fma4 -mno-xop -mbmi -mbmi2 -mno-tbm -mavx -mavx2 -msse4.2 -msse4.1 -mlzcnt -mrtm -mhle -mrdrnd -mf16c -mfsgsbase -mno-rdseed -mno-prfchw -mno-adx -mfxsr -mxsave -mxsaveopt -mno-avx512f -mno-avx512er -mno-avx512cd -mno-avx512pf -mno-prefetchwt1 -mno-clflushopt -mno-xsavec -mno-xsaves -mno-avx512dq -mno-avx512bw -mno-avx512vl -mno-avx512ifma -mno-avx512vbmi -mno-clwb -mno-pcommit -mno-mwaitx --param l1-cache-size=32 --param l1-cache-line-size=64 --param l2-cache-size=46080 -mtune=broadwell -DNPY_NO_DEPRECATED_API=NPY_1_7_API_VERSION -m64 -fPIC -I/home/ubuntu/anaconda2/lib/python2.7/site-packages/numpy/core/include -I/home/ubuntu/anaconda2/include/python2.7 -I/home/ubuntu/anaconda2/lib/python2.7/site-packages/theano/gof -fvisibility=hidden -o /home/ubuntu/.theano/compiledir_Linux-4.4--generic-x86_64-with-debian-stretch-sid-x86_64-2.7.12-64/tmpEh57Ff/423b37ed9361000aa5ee9e740468ece6.so /home/ubuntu/.theano/compiledir_Linux-4.4--generic-x86_64-with-debian-stretch-sid-x86_64-2.7.12-64/tmpEh57Ff/mod.cpp -L/home/ubuntu/anaconda2/lib -lpython2.7
# ERROR (theano.gof.cmodule): [Errno 12] Cannot allocate memory
# ERROR (theano.gof.opt): Optimization failure due to: constant_folding
# ERROR (theano.gof.opt): node: DimShuffle{x}(TensorConstant{(1, 1, 1, 1) of 0.5})
# ERROR (theano.gof.opt): TRACEBACK:
# ERROR (theano.gof.opt): Traceback (most recent call last):
#   File "/home/ubuntu/anaconda2/lib/python2.7/site-packages/theano/gof/opt.py", line 1772, in process_node
#     replacements = lopt.transform(node)
#   File "/home/ubuntu/anaconda2/lib/python2.7/site-packages/theano/tensor/opt.py", line 5825, in constant_folding
#     no_recycling=[])
#   File "/home/ubuntu/anaconda2/lib/python2.7/site-packages/theano/gof/op.py", line 970, in make_thunk
#     no_recycling)
#   File "/home/ubuntu/anaconda2/lib/python2.7/site-packages/theano/gof/op.py", line 879, in make_c_thunk
#     output_storage=node_output_storage)
#   File "/home/ubuntu/anaconda2/lib/python2.7/site-packages/theano/gof/cc.py", line 1200, in make_thunk
#     keep_lock=keep_lock)
#   File "/home/ubuntu/anaconda2/lib/python2.7/site-packages/theano/gof/cc.py", line 1143, in __compile__
#     keep_lock=keep_lock)
#   File "/home/ubuntu/anaconda2/lib/python2.7/site-packages/theano/gof/cc.py", line 1595, in cthunk_factory
#     key=key, lnk=self, keep_lock=keep_lock)
#   File "/home/ubuntu/anaconda2/lib/python2.7/site-packages/theano/gof/cmodule.py", line 1142, in module_from_key
#     module = lnk.compile_cmodule(location)
#   File "/home/ubuntu/anaconda2/lib/python2.7/site-packages/theano/gof/cc.py", line 1506, in compile_cmodule
#     preargs=preargs)
#   File "/home/ubuntu/anaconda2/lib/python2.7/site-packages/theano/gof/cmodule.py", line 2182, in compile_str
#     p_out = output_subprocess_Popen(cmd)
#   File "/home/ubuntu/anaconda2/lib/python2.7/site-packages/theano/misc/windows.py", line 75, in output_subprocess_Popen
#     p = subprocess_Popen(command, **params)
#   File "/home/ubuntu/anaconda2/lib/python2.7/site-packages/theano/misc/windows.py", line 36, in subprocess_Popen
#     proc = subprocess.Popen(command, startupinfo=startupinfo, **params)
#   File "/home/ubuntu/anaconda2/lib/python2.7/subprocess.py", line 711, in __init__
#     errread, errwrite)
#   File "/home/ubuntu/anaconda2/lib/python2.7/subprocess.py", line 1235, in _execute_child
#     self.pid = os.fork()
# OSError: [Errno 12] Cannot allocate memory
#
# Problem occurred during compilation with the command line below:
# /usr/bin/g++ -shared -g -O3 -fno-math-errno -Wno-unused-label -Wno-unused-variable -Wno-write-strings -march=broadwell -mmmx -mno-3dnow -msse -msse2 -msse3 -mssse3 -mno-sse4a -mcx16 -msahf -mmovbe -maes -mno-sha -mpclmul -mpopcnt -mabm -mno-lwp -mfma -mno-fma4 -mno-xop -mbmi -mbmi2 -mno-tbm -mavx -mavx2 -msse4.2 -msse4.1 -mlzcnt -mrtm -mhle -mrdrnd -mf16c -mfsgsbase -mno-rdseed -mno-prfchw -mno-adx -mfxsr -mxsave -mxsaveopt -mno-avx512f -mno-avx512er -mno-avx512cd -mno-avx512pf -mno-prefetchwt1 -mno-clflushopt -mno-xsavec -mno-xsaves -mno-avx512dq -mno-avx512bw -mno-avx512vl -mno-avx512ifma -mno-avx512vbmi -mno-clwb -mno-pcommit -mno-mwaitx --param l1-cache-size=32 --param l1-cache-line-size=64 --param l2-cache-size=46080 -mtune=broadwell -DNPY_NO_DEPRECATED_API=NPY_1_7_API_VERSION -m64 -fPIC -I/home/ubuntu/anaconda2/lib/python2.7/site-packages/numpy/core/include -I/home/ubuntu/anaconda2/include/python2.7 -I/home/ubuntu/anaconda2/lib/python2.7/site-packages/theano/gof -fvisibility=hidden -o /home/ubuntu/.theano/compiledir_Linux-4.4--generic-x86_64-with-debian-stretch-sid-x86_64-2.7.12-64/tmperGqnH/423b37ed9361000aa5ee9e740468ece6.so /home/ubuntu/.theano/compiledir_Linux-4.4--generic-x86_64-with-debian-stretch-sid-x86_64-2.7.12-64/tmperGqnH/mod.cpp -L/home/ubuntu/anaconda2/lib -lpython2.7
# ERROR (theano.gof.cmodule): [Errno 12] Cannot allocate memory
# ERROR (theano.gof.opt): Optimization failure due to: constant_folding
# ERROR (theano.gof.opt): node: DimShuffle{x}(TensorConstant{(1, 1, 1, 1) of 0.5})
# ERROR (theano.gof.opt): TRACEBACK:
# ERROR (theano.gof.opt): Traceback (most recent call last):
#   File "/home/ubuntu/anaconda2/lib/python2.7/site-packages/theano/gof/opt.py", line 1772, in process_node
#     replacements = lopt.transform(node)
#   File "/home/ubuntu/anaconda2/lib/python2.7/site-packages/theano/tensor/opt.py", line 5825, in constant_folding
#     no_recycling=[])
#   File "/home/ubuntu/anaconda2/lib/python2.7/site-packages/theano/gof/op.py", line 970, in make_thunk
#     no_recycling)
#   File "/home/ubuntu/anaconda2/lib/python2.7/site-packages/theano/gof/op.py", line 879, in make_c_thunk
#     output_storage=node_output_storage)
#   File "/home/ubuntu/anaconda2/lib/python2.7/site-packages/theano/gof/cc.py", line 1200, in make_thunk
#     keep_lock=keep_lock)
#   File "/home/ubuntu/anaconda2/lib/python2.7/site-packages/theano/gof/cc.py", line 1143, in __compile__
#     keep_lock=keep_lock)
#   File "/home/ubuntu/anaconda2/lib/python2.7/site-packages/theano/gof/cc.py", line 1595, in cthunk_factory
#     key=key, lnk=self, keep_lock=keep_lock)
#   File "/home/ubuntu/anaconda2/lib/python2.7/site-packages/theano/gof/cmodule.py", line 1142, in module_from_key
#     module = lnk.compile_cmodule(location)
#   File "/home/ubuntu/anaconda2/lib/python2.7/site-packages/theano/gof/cc.py", line 1506, in compile_cmodule
#     preargs=preargs)
#   File "/home/ubuntu/anaconda2/lib/python2.7/site-packages/theano/gof/cmodule.py", line 2182, in compile_str
#     p_out = output_subprocess_Popen(cmd)
#   File "/home/ubuntu/anaconda2/lib/python2.7/site-packages/theano/misc/windows.py", line 75, in output_subprocess_Popen
#     p = subprocess_Popen(command, **params)
#   File "/home/ubuntu/anaconda2/lib/python2.7/site-packages/theano/misc/windows.py", line 36, in subprocess_Popen
#     proc = subprocess.Popen(command, startupinfo=startupinfo, **params)
#   File "/home/ubuntu/anaconda2/lib/python2.7/subprocess.py", line 711, in __init__
#     errread, errwrite)
#   File "/home/ubuntu/anaconda2/lib/python2.7/subprocess.py", line 1235, in _execute_child
#     self.pid = os.fork()
# OSError: [Errno 12] Cannot allocate memory
#
# Problem occurred during compilation with the command line below:
# /usr/bin/g++ -shared -g -O3 -fno-math-errno -Wno-unused-label -Wno-unused-variable -Wno-write-strings -march=broadwell -mmmx -mno-3dnow -msse -msse2 -msse3 -mssse3 -mno-sse4a -mcx16 -msahf -mmovbe -maes -mno-sha -mpclmul -mpopcnt -mabm -mno-lwp -mfma -mno-fma4 -mno-xop -mbmi -mbmi2 -mno-tbm -mavx -mavx2 -msse4.2 -msse4.1 -mlzcnt -mrtm -mhle -mrdrnd -mf16c -mfsgsbase -mno-rdseed -mno-prfchw -mno-adx -mfxsr -mxsave -mxsaveopt -mno-avx512f -mno-avx512er -mno-avx512cd -mno-avx512pf -mno-prefetchwt1 -mno-clflushopt -mno-xsavec -mno-xsaves -mno-avx512dq -mno-avx512bw -mno-avx512vl -mno-avx512ifma -mno-avx512vbmi -mno-clwb -mno-pcommit -mno-mwaitx --param l1-cache-size=32 --param l1-cache-line-size=64 --param l2-cache-size=46080 -mtune=broadwell -DNPY_NO_DEPRECATED_API=NPY_1_7_API_VERSION -m64 -fPIC -I/home/ubuntu/anaconda2/lib/python2.7/site-packages/numpy/core/include -I/home/ubuntu/anaconda2/include/python2.7 -I/home/ubuntu/anaconda2/lib/python2.7/site-packages/theano/gof -fvisibility=hidden -o /home/ubuntu/.theano/compiledir_Linux-4.4--generic-x86_64-with-debian-stretch-sid-x86_64-2.7.12-64/tmpZFYrQq/423b37ed9361000aa5ee9e740468ece6.so /home/ubuntu/.theano/compiledir_Linux-4.4--generic-x86_64-with-debian-stretch-sid-x86_64-2.7.12-64/tmpZFYrQq/mod.cpp -L/home/ubuntu/anaconda2/lib -lpython2.7
# ERROR (theano.gof.cmodule): [Errno 12] Cannot allocate memory
# ERROR (theano.gof.opt): Optimization failure due to: constant_folding
# ERROR (theano.gof.opt): node: DimShuffle{x}(TensorConstant{(1, 1, 1, 1) of 0.5})
# ERROR (theano.gof.opt): TRACEBACK:
# ERROR (theano.gof.opt): Traceback (most recent call last):
#   File "/home/ubuntu/anaconda2/lib/python2.7/site-packages/theano/gof/opt.py", line 1772, in process_node
#     replacements = lopt.transform(node)
#   File "/home/ubuntu/anaconda2/lib/python2.7/site-packages/theano/tensor/opt.py", line 5825, in constant_folding
#     no_recycling=[])
#   File "/home/ubuntu/anaconda2/lib/python2.7/site-packages/theano/gof/op.py", line 970, in make_thunk
#     no_recycling)
#   File "/home/ubuntu/anaconda2/lib/python2.7/site-packages/theano/gof/op.py", line 879, in make_c_thunk
#     output_storage=node_output_storage)
#   File "/home/ubuntu/anaconda2/lib/python2.7/site-packages/theano/gof/cc.py", line 1200, in make_thunk
#     keep_lock=keep_lock)
#   File "/home/ubuntu/anaconda2/lib/python2.7/site-packages/theano/gof/cc.py", line 1143, in __compile__
#     keep_lock=keep_lock)
#   File "/home/ubuntu/anaconda2/lib/python2.7/site-packages/theano/gof/cc.py", line 1595, in cthunk_factory
#     key=key, lnk=self, keep_lock=keep_lock)
#   File "/home/ubuntu/anaconda2/lib/python2.7/site-packages/theano/gof/cmodule.py", line 1142, in module_from_key
#     module = lnk.compile_cmodule(location)
#   File "/home/ubuntu/anaconda2/lib/python2.7/site-packages/theano/gof/cc.py", line 1506, in compile_cmodule
#     preargs=preargs)
#   File "/home/ubuntu/anaconda2/lib/python2.7/site-packages/theano/gof/cmodule.py", line 2182, in compile_str
#     p_out = output_subprocess_Popen(cmd)
#   File "/home/ubuntu/anaconda2/lib/python2.7/site-packages/theano/misc/windows.py", line 75, in output_subprocess_Popen
#     p = subprocess_Popen(command, **params)
#   File "/home/ubuntu/anaconda2/lib/python2.7/site-packages/theano/misc/windows.py", line 36, in subprocess_Popen
#     proc = subprocess.Popen(command, startupinfo=startupinfo, **params)
#   File "/home/ubuntu/anaconda2/lib/python2.7/subprocess.py", line 711, in __init__
#     errread, errwrite)
#   File "/home/ubuntu/anaconda2/lib/python2.7/subprocess.py", line 1235, in _execute_child
#     self.pid = os.fork()
# OSError: [Errno 12] Cannot allocate memory
#
# Problem occurred during compilation with the command line below:
# /usr/bin/g++ -shared -g -O3 -fno-math-errno -Wno-unused-label -Wno-unused-variable -Wno-write-strings -march=broadwell -mmmx -mno-3dnow -msse -msse2 -msse3 -mssse3 -mno-sse4a -mcx16 -msahf -mmovbe -maes -mno-sha -mpclmul -mpopcnt -mabm -mno-lwp -mfma -mno-fma4 -mno-xop -mbmi -mbmi2 -mno-tbm -mavx -mavx2 -msse4.2 -msse4.1 -mlzcnt -mrtm -mhle -mrdrnd -mf16c -mfsgsbase -mno-rdseed -mno-prfchw -mno-adx -mfxsr -mxsave -mxsaveopt -mno-avx512f -mno-avx512er -mno-avx512cd -mno-avx512pf -mno-prefetchwt1 -mno-clflushopt -mno-xsavec -mno-xsaves -mno-avx512dq -mno-avx512bw -mno-avx512vl -mno-avx512ifma -mno-avx512vbmi -mno-clwb -mno-pcommit -mno-mwaitx --param l1-cache-size=32 --param l1-cache-line-size=64 --param l2-cache-size=46080 -mtune=broadwell -DNPY_NO_DEPRECATED_API=NPY_1_7_API_VERSION -m64 -fPIC -I/home/ubuntu/anaconda2/lib/python2.7/site-packages/numpy/core/include -I/home/ubuntu/anaconda2/include/python2.7 -I/home/ubuntu/anaconda2/lib/python2.7/site-packages/theano/gof -fvisibility=hidden -o /home/ubuntu/.theano/compiledir_Linux-4.4--generic-x86_64-with-debian-stretch-sid-x86_64-2.7.12-64/tmpzz96PM/423b37ed9361000aa5ee9e740468ece6.so /home/ubuntu/.theano/compiledir_Linux-4.4--generic-x86_64-with-debian-stretch-sid-x86_64-2.7.12-64/tmpzz96PM/mod.cpp -L/home/ubuntu/anaconda2/lib -lpython2.7
# ERROR (theano.gof.cmodule): [Errno 12] Cannot allocate memory
# ERROR (theano.gof.opt): Optimization failure due to: constant_folding
# ERROR (theano.gof.opt): node: DimShuffle{x}(TensorConstant{(1, 1, 1, 1) of 0.5})
# ERROR (theano.gof.opt): TRACEBACK:
# ERROR (theano.gof.opt): Traceback (most recent call last):
#   File "/home/ubuntu/anaconda2/lib/python2.7/site-packages/theano/gof/opt.py", line 1772, in process_node
#     replacements = lopt.transform(node)
#   File "/home/ubuntu/anaconda2/lib/python2.7/site-packages/theano/tensor/opt.py", line 5825, in constant_folding
#     no_recycling=[])
#   File "/home/ubuntu/anaconda2/lib/python2.7/site-packages/theano/gof/op.py", line 970, in make_thunk
#     no_recycling)
#   File "/home/ubuntu/anaconda2/lib/python2.7/site-packages/theano/gof/op.py", line 879, in make_c_thunk
#     output_storage=node_output_storage)
#   File "/home/ubuntu/anaconda2/lib/python2.7/site-packages/theano/gof/cc.py", line 1200, in make_thunk
#     keep_lock=keep_lock)
#   File "/home/ubuntu/anaconda2/lib/python2.7/site-packages/theano/gof/cc.py", line 1143, in __compile__
#     keep_lock=keep_lock)
#   File "/home/ubuntu/anaconda2/lib/python2.7/site-packages/theano/gof/cc.py", line 1595, in cthunk_factory
#     key=key, lnk=self, keep_lock=keep_lock)
#   File "/home/ubuntu/anaconda2/lib/python2.7/site-packages/theano/gof/cmodule.py", line 1142, in module_from_key
#     module = lnk.compile_cmodule(location)
#   File "/home/ubuntu/anaconda2/lib/python2.7/site-packages/theano/gof/cc.py", line 1506, in compile_cmodule
#     preargs=preargs)
#   File "/home/ubuntu/anaconda2/lib/python2.7/site-packages/theano/gof/cmodule.py", line 2182, in compile_str
#     p_out = output_subprocess_Popen(cmd)
#   File "/home/ubuntu/anaconda2/lib/python2.7/site-packages/theano/misc/windows.py", line 75, in output_subprocess_Popen
#     p = subprocess_Popen(command, **params)
#   File "/home/ubuntu/anaconda2/lib/python2.7/site-packages/theano/misc/windows.py", line 36, in subprocess_Popen
#     proc = subprocess.Popen(command, startupinfo=startupinfo, **params)
#   File "/home/ubuntu/anaconda2/lib/python2.7/subprocess.py", line 711, in __init__
#     errread, errwrite)
#   File "/home/ubuntu/anaconda2/lib/python2.7/subprocess.py", line 1235, in _execute_child
#     self.pid = os.fork()
# OSError: [Errno 12] Cannot allocate memory
#
# Problem occurred during compilation with the command line below:
# ...
#     no_recycling=[])
#   File "/home/ubuntu/anaconda2/lib/python2.7/site-packages/theano/sandbox/cuda/__init__.py", line 256, in make_thunk
#     compute_map, no_recycling)
#   File "/home/ubuntu/anaconda2/lib/python2.7/site-packages/theano/gof/op.py", line 970, in make_thunk
#     no_recycling)
#   File "/home/ubuntu/anaconda2/lib/python2.7/site-packages/theano/gof/op.py", line 879, in make_c_thunk
#     output_storage=node_output_storage)
#   File "/home/ubuntu/anaconda2/lib/python2.7/site-packages/theano/gof/cc.py", line 1200, in make_thunk
#     keep_lock=keep_lock)
#   File "/home/ubuntu/anaconda2/lib/python2.7/site-packages/theano/gof/cc.py", line 1143, in __compile__
#     keep_lock=keep_lock)
#   File "/home/ubuntu/anaconda2/lib/python2.7/site-packages/theano/gof/cc.py", line 1595, in cthunk_factory
#     key=key, lnk=self, keep_lock=keep_lock)
#   File "/home/ubuntu/anaconda2/lib/python2.7/site-packages/theano/gof/cmodule.py", line 1142, in module_from_key
#     module = lnk.compile_cmodule(location)
#   File "/home/ubuntu/anaconda2/lib/python2.7/site-packages/theano/gof/cc.py", line 1506, in compile_cmodule
#     preargs=preargs)
#   File "/home/ubuntu/anaconda2/lib/python2.7/site-packages/theano/sandbox/cuda/nvcc_compiler.py", line 361, in compile_str
#     cmd, stdout=subprocess.PIPE, stderr=subprocess.PIPE)
#   File "/home/ubuntu/anaconda2/lib/python2.7/subprocess.py", line 711, in __init__
#     errread, errwrite)
#   File "/home/ubuntu/anaconda2/lib/python2.7/subprocess.py", line 1235, in _execute_child
#     self.pid = os.fork()
# OSError: [Errno 12] Cannot allocate memory
#
# ERROR (theano.gof.cmodule): [Errno 12] Cannot allocate memory
# ERROR (theano.gof.opt): Optimization failure due to: constant_folding
# ERROR (theano.gof.opt): node: GpuDimShuffle{x}(CudaNdarrayConstant{[[[[ 0.5]]]]})
# ERROR (theano.gof.opt): TRACEBACK:
# ERROR (theano.gof.opt): Traceback (most recent call last):
#   File "/home/ubuntu/anaconda2/lib/python2.7/site-packages/theano/gof/opt.py", line 1772, in process_node
#     replacements = lopt.transform(node)
#   File "/home/ubuntu/anaconda2/lib/python2.7/site-packages/theano/tensor/opt.py", line 5825, in constant_folding
#     no_recycling=[])
#   File "/home/ubuntu/anaconda2/lib/python2.7/site-packages/theano/sandbox/cuda/__init__.py", line 256, in make_thunk
#     compute_map, no_recycling)
#   File "/home/ubuntu/anaconda2/lib/python2.7/site-packages/theano/gof/op.py", line 970, in make_thunk
#     no_recycling)
#   File "/home/ubuntu/anaconda2/lib/python2.7/site-packages/theano/gof/op.py", line 879, in make_c_thunk
#     output_storage=node_output_storage)
#   File "/home/ubuntu/anaconda2/lib/python2.7/site-packages/theano/gof/cc.py", line 1200, in make_thunk
#     keep_lock=keep_lock)
#   File "/home/ubuntu/anaconda2/lib/python2.7/site-packages/theano/gof/cc.py", line 1143, in __compile__
#     keep_lock=keep_lock)
#   File "/home/ubuntu/anaconda2/lib/python2.7/site-packages/theano/gof/cc.py", line 1595, in cthunk_factory
#     key=key, lnk=self, keep_lock=keep_lock)
#   File "/home/ubuntu/anaconda2/lib/python2.7/site-packages/theano/gof/cmodule.py", line 1142, in module_from_key
#     module = lnk.compile_cmodule(location)
#   File "/home/ubuntu/anaconda2/lib/python2.7/site-packages/theano/gof/cc.py", line 1506, in compile_cmodule
#     preargs=preargs)
#   File "/home/ubuntu/anaconda2/lib/python2.7/site-packages/theano/sandbox/cuda/nvcc_compiler.py", line 361, in compile_str
#     cmd, stdout=subprocess.PIPE, stderr=subprocess.PIPE)
#   File "/home/ubuntu/anaconda2/lib/python2.7/subprocess.py", line 711, in __init__
#     errread, errwrite)
#   File "/home/ubuntu/anaconda2/lib/python2.7/subprocess.py", line 1235, in _execute_child
#     self.pid = os.fork()
# OSError: [Errno 12] Cannot allocate memory
#
# ERROR (theano.gof.cmodule): [Errno 12] Cannot allocate memory
# ERROR (theano.gof.opt): Optimization failure due to: constant_folding
# ERROR (theano.gof.opt): node: GpuDimShuffle{x}(CudaNdarrayConstant{[[[[ 0.5]]]]})
# ERROR (theano.gof.opt): TRACEBACK:
# ERROR (theano.gof.opt): Traceback (most recent call last):
#   File "/home/ubuntu/anaconda2/lib/python2.7/site-packages/theano/gof/opt.py", line 1772, in process_node
#     replacements = lopt.transform(node)
#   File "/home/ubuntu/anaconda2/lib/python2.7/site-packages/theano/tensor/opt.py", line 5825, in constant_folding
#     no_recycling=[])
#   File "/home/ubuntu/anaconda2/lib/python2.7/site-packages/theano/sandbox/cuda/__init__.py", line 256, in make_thunk
#     compute_map, no_recycling)
#   File "/home/ubuntu/anaconda2/lib/python2.7/site-packages/theano/gof/op.py", line 970, in make_thunk
#     no_recycling)
#   File "/home/ubuntu/anaconda2/lib/python2.7/site-packages/theano/gof/op.py", line 879, in make_c_thunk
#     output_storage=node_output_storage)
#   File "/home/ubuntu/anaconda2/lib/python2.7/site-packages/theano/gof/cc.py", line 1200, in make_thunk
#     keep_lock=keep_lock)
#   File "/home/ubuntu/anaconda2/lib/python2.7/site-packages/theano/gof/cc.py", line 1143, in __compile__
#     keep_lock=keep_lock)
#   File "/home/ubuntu/anaconda2/lib/python2.7/site-packages/theano/gof/cc.py", line 1595, in cthunk_factory
#     key=key, lnk=self, keep_lock=keep_lock)
#   File "/home/ubuntu/anaconda2/lib/python2.7/site-packages/theano/gof/cmodule.py", line 1142, in module_from_key
#     module = lnk.compile_cmodule(location)
#   File "/home/ubuntu/anaconda2/lib/python2.7/site-packages/theano/gof/cc.py", line 1506, in compile_cmodule
#     preargs=preargs)
#   File "/home/ubuntu/anaconda2/lib/python2.7/site-packages/theano/sandbox/cuda/nvcc_compiler.py", line 361, in compile_str
#     cmd, stdout=subprocess.PIPE, stderr=subprocess.PIPE)
#   File "/home/ubuntu/anaconda2/lib/python2.7/subprocess.py", line 711, in __init__
#     errread, errwrite)
#   File "/home/ubuntu/anaconda2/lib/python2.7/subprocess.py", line 1235, in _execute_child
#     self.pid = os.fork()
# OSError: [Errno 12] Cannot allocate memory
#
# ERROR (theano.gof.cmodule): [Errno 12] Cannot allocate memory
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-140-9df0c296e7e5> in <module>()
#       1 lrg_model.fit(conv_trn_feat, trn_labels, batch_size=batch_size, nb_epoch=2,
# ----> 2              validation_data=(conv_val_feat, val_labels))
#
# /home/ubuntu/anaconda2/lib/python2.7/site-packages/keras/models.pyc in fit(self, x, y, batch_size, nb_epoch, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, **kwargs)
#     618                               shuffle=shuffle,
#     619                               class_weight=class_weight,
# --> 620                               sample_weight=sample_weight)
#     621
#     622     def evaluate(self, x, y, batch_size=32, verbose=1,
#
# /home/ubuntu/anaconda2/lib/python2.7/site-packages/keras/engine/training.pyc in fit(self, x, y, batch_size, nb_epoch, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight)
#    1047                                                                            check_batch_dim=False,
#    1048                                                                            batch_size=batch_size)
# -> 1049             self._make_test_function()
#    1050             val_f = self.test_function
#    1051             if self.uses_learning_phase and type(K.learning_phase()) is not int:
#
# /home/ubuntu/anaconda2/lib/python2.7/site-packages/keras/engine/training.pyc in _make_test_function(self)
#     716                                             [self.total_loss] + self.metrics_tensors,
#     717                                             updates=self.state_updates,
# --> 718                                             **self._function_kwargs)
#     719
#     720     def _make_predict_function(self):
#
# /home/ubuntu/anaconda2/lib/python2.7/site-packages/keras/backend/theano_backend.pyc in function(inputs, outputs, updates, **kwargs)
#     725                 msg = "Invalid argument '%s' passed to K.function" % key
#     726                 raise ValueError(msg)
# --> 727     return Function(inputs, outputs, updates=updates, **kwargs)
#     728
#     729
#
# /home/ubuntu/anaconda2/lib/python2.7/site-packages/keras/backend/theano_backend.pyc in __init__(self, inputs, outputs, updates, **kwargs)
#     711                                         allow_input_downcast=True,
#     712                                         on_unused_input='ignore',
# --> 713                                         **kwargs)
#     714
#     715     def __call__(self, inputs):
#
# /home/ubuntu/anaconda2/lib/python2.7/site-packages/theano/compile/function.pyc in function(inputs, outputs, mode, updates, givens, no_default_updates, accept_inplace, name, rebuild_strict, allow_input_downcast, profile, on_unused_input)
#     318                    on_unused_input=on_unused_input,
#     319                    profile=profile,
# --> 320                    output_keys=output_keys)
#     321     # We need to add the flag check_aliased inputs if we have any mutable or
#     322     # borrowed used defined inputs
#
# /home/ubuntu/anaconda2/lib/python2.7/site-packages/theano/compile/pfunc.pyc in pfunc(params, outputs, mode, updates, givens, no_default_updates, accept_inplace, name, rebuild_strict, allow_input_downcast, profile, on_unused_input, output_keys)
#     477                          accept_inplace=accept_inplace, name=name,
#     478                          profile=profile, on_unused_input=on_unused_input,
# --> 479                          output_keys=output_keys)
#     480
#     481
#
# /home/ubuntu/anaconda2/lib/python2.7/site-packages/theano/compile/function_module.pyc in orig_function(inputs, outputs, mode, accept_inplace, name, profile, on_unused_input, output_keys)
#    1775                    on_unused_input=on_unused_input,
#    1776                    output_keys=output_keys).create(
# -> 1777             defaults)
#    1778
#    1779     t2 = time.time()
#
# /home/ubuntu/anaconda2/lib/python2.7/site-packages/theano/compile/function_module.pyc in create(self, input_storage, trustme, storage_map)
#    1639             theano.config.traceback.limit = 0
#    1640             _fn, _i, _o = self.linker.make_thunk(
# -> 1641                 input_storage=input_storage_lists, storage_map=storage_map)
#    1642         finally:
#    1643             theano.config.traceback.limit = limit_orig
#
# /home/ubuntu/anaconda2/lib/python2.7/site-packages/theano/gof/link.pyc in make_thunk(self, input_storage, output_storage, storage_map)
#     688         return self.make_all(input_storage=input_storage,
#     689                              output_storage=output_storage,
# --> 690                              storage_map=storage_map)[:3]
#     691
#     692     def make_all(self, input_storage, output_storage):
#
# /home/ubuntu/anaconda2/lib/python2.7/site-packages/theano/gof/vm.pyc in make_all(self, profiler, input_storage, output_storage, storage_map)
#    1001                                                  storage_map,
#    1002                                                  compute_map,
# -> 1003                                                  no_recycling))
#    1004                 if not hasattr(thunks[-1], 'lazy'):
#    1005                     # We don't want all ops maker to think about lazy Ops.
#
# /home/ubuntu/anaconda2/lib/python2.7/site-packages/theano/sandbox/cuda/__init__.pyc in make_thunk(self, node, storage_map, compute_map, no_recycling)
#     254                 enable_cuda=False)
#     255         return super(GpuOp, self).make_thunk(node, storage_map,
# --> 256                                              compute_map, no_recycling)
#     257
#     258 theano.compile.debugmode.default_make_thunk.append(
#
# /home/ubuntu/anaconda2/lib/python2.7/site-packages/theano/gof/op.pyc in make_thunk(self, node, storage_map, compute_map, no_recycling)
#     968             try:
#     969                 return self.make_c_thunk(node, storage_map, compute_map,
# --> 970                                          no_recycling)
#     971             except (NotImplementedError, utils.MethodNotDefined):
#     972                 logger.debug('Falling back on perform')
#
# /home/ubuntu/anaconda2/lib/python2.7/site-packages/theano/gof/op.pyc in make_c_thunk(self, node, storage_map, compute_map, no_recycling)
#     877         logger.debug('Trying CLinker.make_thunk')
#     878         outputs = cl.make_thunk(input_storage=node_input_storage,
# --> 879                                 output_storage=node_output_storage)
#     880         fill_storage, node_input_filters, node_output_filters = outputs
#     881
#
# /home/ubuntu/anaconda2/lib/python2.7/site-packages/theano/gof/cc.pyc in make_thunk(self, input_storage, output_storage, storage_map, keep_lock)
#    1198         cthunk, in_storage, out_storage, error_storage = self.__compile__(
#    1199             input_storage, output_storage, storage_map,
# -> 1200             keep_lock=keep_lock)
#    1201
#    1202         res = _CThunk(cthunk, init_tasks, tasks, error_storage)
#
# /home/ubuntu/anaconda2/lib/python2.7/site-packages/theano/gof/cc.pyc in __compile__(self, input_storage, output_storage, storage_map, keep_lock)
#    1141                                     output_storage,
#    1142                                     storage_map,
# -> 1143                                     keep_lock=keep_lock)
#    1144         return (thunk,
#    1145                 [link.Container(input, storage) for input, storage in
#
# /home/ubuntu/anaconda2/lib/python2.7/site-packages/theano/gof/cc.pyc in cthunk_factory(self, error_storage, in_storage, out_storage, storage_map, keep_lock)
#    1593         else:
#    1594             module = get_module_cache().module_from_key(
# -> 1595                 key=key, lnk=self, keep_lock=keep_lock)
#    1596
#    1597         vars = self.inputs + self.outputs + self.orphans
#
# /home/ubuntu/anaconda2/lib/python2.7/site-packages/theano/gof/cmodule.pyc in module_from_key(self, key, lnk, keep_lock)
#    1140             try:
#    1141                 location = dlimport_workdir(self.dirname)
# -> 1142                 module = lnk.compile_cmodule(location)
#    1143                 name = module.__file__
#    1144                 assert name.startswith(location)
#
# /home/ubuntu/anaconda2/lib/python2.7/site-packages/theano/gof/cc.pyc in compile_cmodule(self, location)
#    1504                 lib_dirs=self.lib_dirs(),
#    1505                 libs=libs,
# -> 1506                 preargs=preargs)
#    1507         except Exception as e:
#    1508             e.args += (str(self.fgraph),)
#
# /home/ubuntu/anaconda2/lib/python2.7/site-packages/theano/sandbox/cuda/nvcc_compiler.pyc in compile_str(module_name, src_code, location, include_dirs, lib_dirs, libs, preargs, rpaths, py_module, hide_symbols)
#     359             os.chdir(location)
#     360             p = subprocess.Popen(
# --> 361                     cmd, stdout=subprocess.PIPE, stderr=subprocess.PIPE)
#     362             nvcc_stdout, nvcc_stderr = decode_iter(p.communicate()[:2])
#     363         finally:
#
# /home/ubuntu/anaconda2/lib/python2.7/subprocess.pyc in __init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags)
#     709                                 p2cread, p2cwrite,
#     710                                 c2pread, c2pwrite,
# --> 711                                 errread, errwrite)
#     712         except Exception:
#     713             # Preserve original exception in case os.close raises.
#
# /home/ubuntu/anaconda2/lib/python2.7/subprocess.pyc in _execute_child(self, args, executable, preexec_fn, close_fds, cwd, env, universal_newlines, startupinfo, creationflags, shell, to_close, p2cread, p2cwrite, c2pread, c2pwrite, errread, errwrite)
#    1233                     gc.disable()
#    1234                     try:
# -> 1235                         self.pid = os.fork()
#    1236                     except:
#    1237                         if gc_was_enabled:
#
# OSError: [Errno 12] Cannot allocate memory

# %%
lrg_model.optimizer.lr=1e-5

# %%
lrg_model.fit(conv_trn_feat, trn_labels, batch_size=batch_size, nb_epoch=6, 
             validation_data=(conv_val_feat, val_labels))

# %% [markdown]
# When I submitted the results of this model to Kaggle, I got the best single model results of any shown here (ranked 22nd on the leaderboard as at Dec-6-2016.)

# %%
lrg_model.save_weights(path+'models/lrg_nmp.h5')

# %%
lrg_model.load_weights(path+'models/lrg_nmp.h5')

# %%
lrg_model.evaluate(conv_val_feat, val_labels)

# %% [markdown]
# Another benefit of this kind of model is that the last convolutional layer has to learn to classify each part of the image (since there's only an average pooling layer after). Let's create a function that grabs the output of this layer (which is the 4th-last layer of our model).

# %%
l = lrg_model.layers
conv_fn = K.function([l[0].input, K.learning_phase()], l[-4].output)

# %%
def get_cm(imp, label):
    conv = conv_fn([inp,0])[0, label]
    return scipy.misc.imresize(conv, (360,640), interp='nearest')

# %% [markdown]
# We have to add an extra dimension to our input since the CNN expects a 'batch' (even if it's just a batch of one).

# %%
inp = np.expand_dims(conv_val_feat[0], 0)
np.round(lrg_model.predict(inp)[0],2)

# %%
plt.imshow(to_plot(val[0]))

# %%
cm = get_cm(inp, 0)

# %% [markdown]
# The heatmap shows that (at very low resolution) the model is finding the fish!

# %%
plt.imshow(cm, cmap="cool")

# %% [markdown]
# ### All convolutional net heatmap

# %% [markdown]
# To create a higher resolution heatmap, we'll remove all the max pooling layers, and repeat the previous steps.

# %%
def get_lrg_layers():
    return [
        BatchNormalization(axis=1, input_shape=conv_layers[-1].output_shape[1:]),
        Convolution2D(nf,3,3, activation='relu', border_mode='same'),
        BatchNormalization(axis=1),
        Convolution2D(nf,3,3, activation='relu', border_mode='same'),
        BatchNormalization(axis=1),
        Convolution2D(nf,3,3, activation='relu', border_mode='same'),
        BatchNormalization(axis=1),
        Convolution2D(8,3,3, border_mode='same'),
        GlobalAveragePooling2D(),
        Activation('softmax')
    ]

# %%
lrg_model = Sequential(get_lrg_layers())

# %%
lrg_model.summary()
# Out:
# ____________________________________________________________________________________________________
# Layer (type)                     Output Shape          Param #     Connected to
# ====================================================================================================
# batchnormalization_2 (BatchNorma (None, 512, 22, 40)   1024        batchnormalization_input_1[0][0]
# ____________________________________________________________________________________________________
# convolution2d_14 (Convolution2D) (None, 128, 22, 40)   589952      batchnormalization_2[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_3 (BatchNorma (None, 128, 22, 40)   256         convolution2d_14[0][0]
# ____________________________________________________________________________________________________
# convolution2d_15 (Convolution2D) (None, 128, 22, 40)   147584      batchnormalization_3[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_4 (BatchNorma (None, 128, 22, 40)   256         convolution2d_15[0][0]
# ____________________________________________________________________________________________________
# convolution2d_16 (Convolution2D) (None, 128, 22, 40)   147584      batchnormalization_4[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_5 (BatchNorma (None, 128, 22, 40)   256         convolution2d_16[0][0]
# ____________________________________________________________________________________________________
# convolution2d_17 (Convolution2D) (None, 8, 22, 40)     9224        batchnormalization_5[0][0]
# ____________________________________________________________________________________________________
# globalaveragepooling2d_1 (Global (None, 8)             0           convolution2d_17[0][0]
# ____________________________________________________________________________________________________
# activation_1 (Activation)        (None, 8)             0           globalaveragepooling2d_1[0][0]
# ====================================================================================================
# Total params: 896136
# ____________________________________________________________________________________________________

# %%
lrg_model.compile(Adam(lr=0.001), loss='categorical_crossentropy', metrics=['accuracy'])

# %%
lrg_model.fit(conv_trn_feat, trn_labels, batch_size=batch_size, nb_epoch=2, 
             validation_data=(conv_val_feat, val_labels))
# Out:
# Train on 3277 samples, validate on 500 samples
# Epoch 1/2
# 3277/3277 [==============================] - 11s - loss: 0.9377 - acc: 0.7128 - val_loss: 2.7022 - val_acc: 0.6260
# Epoch 2/2
# 3277/3277 [==============================] - 10s - loss: 0.2603 - acc: 0.9271 - val_loss: 0.4385 - val_acc: 0.9080

# %%
lrg_model.optimizer.lr=1e-5

# %%
lrg_model.fit(conv_trn_feat, trn_labels, batch_size=batch_size, nb_epoch=6, 
             validation_data=(conv_val_feat, val_labels))
# Out:
# Train on 3277 samples, validate on 500 samples
# Epoch 1/6
# 3277/3277 [==============================] - 11s - loss: 0.1027 - acc: 0.9747 - val_loss: 0.3641 - val_acc: 0.9060
# Epoch 2/6
# 3277/3277 [==============================] - 10s - loss: 0.0498 - acc: 0.9844 - val_loss: 0.2743 - val_acc: 0.9200
# Epoch 3/6
# 3277/3277 [==============================] - 10s - loss: 0.0359 - acc: 0.9918 - val_loss: 0.2262 - val_acc: 0.9520
# Epoch 4/6
# 3277/3277 [==============================] - 11s - loss: 0.0339 - acc: 0.9912 - val_loss: 0.1877 - val_acc: 0.9540
# Epoch 5/6
# 3277/3277 [==============================] - 10s - loss: 0.0242 - acc: 0.9945 - val_loss: 0.2320 - val_acc: 0.9460
# Epoch 6/6
# 3277/3277 [==============================] - 10s - loss: 0.0211 - acc: 0.9930 - val_loss: 0.1813 - val_acc: 0.9520

# %%
lrg_model.save_weights(path+'models/lrg_0mp.h5')

# %%
lrg_model.load_weights(path+'models/lrg_0mp.h5')

# %% [markdown]
# #### Create heatmap

# %%
l = lrg_model.layers
conv_fn = K.function([l[0].input, K.learning_phase()], l[-3].output)

# %%
def get_cm2(imp, label):
    conv = conv_fn([inp,0])[0, label]
    return scipy.misc.imresize(conv, (360,640))

# %%
inp = np.expand_dims(conv_val_feat[0], 0)

# %%
plt.imshow(to_plot(val[0]))

# %%
cm = get_cm2(inp, 0)

# %%
cm = get_cm2(inp, 4)

# %%
plt.imshow(cm, cmap="cool")

# %%
plt.figure(figsize=(10,10))
plot(val[0])
plt.imshow(cm, cmap="cool", alpha=0.5)

# %% [markdown]
# ### Inception mini-net

# %% [markdown]
# Here's an example of how to create and use "inception blocks" - as you see, they use multiple different convolution filter sizes and concatenate the results together. We'll talk more about these next year.

# %%
def conv2d_bn(x, nb_filter, nb_row, nb_col, subsample=(1, 1)):
    x = Convolution2D(nb_filter, nb_row, nb_col,
                      subsample=subsample, activation='relu', border_mode='same')(x)
    return BatchNormalization(axis=1)(x)

# %%
def incep_block(x):
    branch1x1 = conv2d_bn(x, 32, 1, 1, subsample=(2, 2))
    branch5x5 = conv2d_bn(x, 24, 1, 1)
    branch5x5 = conv2d_bn(branch5x5, 32, 5, 5, subsample=(2, 2))

    branch3x3dbl = conv2d_bn(x, 32, 1, 1)
    branch3x3dbl = conv2d_bn(branch3x3dbl, 48, 3, 3)
    branch3x3dbl = conv2d_bn(branch3x3dbl, 48, 3, 3, subsample=(2, 2))

    branch_pool = AveragePooling2D(
        (3, 3), strides=(2, 2), border_mode='same')(x)
    branch_pool = conv2d_bn(branch_pool, 16, 1, 1)
    return merge([branch1x1, branch5x5, branch3x3dbl, branch_pool],
              mode='concat', concat_axis=1)

# %%
inp = Input(vgg640.layers[-1].output_shape[1:]) 
x = BatchNormalization(axis=1)(inp)
x = incep_block(x)
x = incep_block(x)
x = incep_block(x)
x = Dropout(0.75)(x)
x = Convolution2D(8,3,3, border_mode='same')(x)
x = GlobalAveragePooling2D()(x)
outp = Activation('softmax')(x)

# %%
lrg_model = Model([inp], outp)

# %%
lrg_model.compile(Adam(lr=0.001), loss='categorical_crossentropy', metrics=['accuracy'])

# %%
lrg_model.fit(conv_trn_feat, trn_labels, batch_size=batch_size, nb_epoch=2, 
             validation_data=(conv_val_feat, val_labels))
# Out:
# Train on 3277 samples, validate on 500 samples
# Epoch 1/2
# 3277/3277 [==============================] - 6s - loss: 1.3251 - acc: 0.5536 - val_loss: 1.4769 - val_acc: 0.5080
# Epoch 2/2
# 3277/3277 [==============================] - 6s - loss: 0.4601 - acc: 0.8691 - val_loss: 0.9860 - val_acc: 0.7460

# %%
lrg_model.optimizer.lr=1e-5

# %%
lrg_model.fit(conv_trn_feat, trn_labels, batch_size=batch_size, nb_epoch=6, 
             validation_data=(conv_val_feat, val_labels))
# Out:
# Train on 3277 samples, validate on 500 samples
# Epoch 1/6
# 3277/3277 [==============================] - 6s - loss: 0.0260 - acc: 0.9945 - val_loss: 0.2117 - val_acc: 0.9480
# Epoch 2/6
# 3277/3277 [==============================] - 6s - loss: 0.0240 - acc: 0.9957 - val_loss: 0.3007 - val_acc: 0.9280
# Epoch 3/6
# 3277/3277 [==============================] - 6s - loss: 0.0120 - acc: 0.9976 - val_loss: 0.2506 - val_acc: 0.9500
# Epoch 4/6
# 3277/3277 [==============================] - 6s - loss: 0.0060 - acc: 0.9991 - val_loss: 0.2389 - val_acc: 0.9480
# Epoch 5/6
# 3277/3277 [==============================] - 6s - loss: 0.0029 - acc: 1.0000 - val_loss: 0.2160 - val_acc: 0.9580
# Epoch 6/6
# 3277/3277 [==============================] - 6s - loss: 0.0028 - acc: 0.9991 - val_loss: 0.2116 - val_acc: 0.9580

# %%
lrg_model.fit(conv_trn_feat, trn_labels, batch_size=batch_size, nb_epoch=10, 
             validation_data=(conv_val_feat, val_labels))
# Out:
# Train on 3277 samples, validate on 500 samples
# Epoch 1/10
# 3277/3277 [==============================] - 6s - loss: 0.0029 - acc: 1.0000 - val_loss: 0.1610 - val_acc: 0.9540
# Epoch 2/10
# 3277/3277 [==============================] - 6s - loss: 0.0016 - acc: 1.0000 - val_loss: 0.1313 - val_acc: 0.9540
# Epoch 3/10
# 3277/3277 [==============================] - 6s - loss: 0.0995 - acc: 0.9707 - val_loss: 0.4845 - val_acc: 0.8760
# Epoch 4/10
# 3277/3277 [==============================] - 6s - loss: 0.1335 - acc: 0.9551 - val_loss: 0.3103 - val_acc: 0.9300
# Epoch 5/10
# 3277/3277 [==============================] - 6s - loss: 0.0634 - acc: 0.9780 - val_loss: 0.2923 - val_acc: 0.9340
# Epoch 6/10
# 3277/3277 [==============================] - 6s - loss: 0.0205 - acc: 0.9930 - val_loss: 0.2316 - val_acc: 0.9500
# Epoch 7/10
# 3277/3277 [==============================] - 6s - loss: 0.0049 - acc: 0.9997 - val_loss: 0.2048 - val_acc: 0.9660
# Epoch 8/10
# 3277/3277 [==============================] - 6s - loss: 0.0016 - acc: 1.0000 - val_loss: 0.1842 - val_acc: 0.9680
# Epoch 9/10
# 3277/3277 [==============================] - 6s - loss: 0.0011 - acc: 1.0000 - val_loss: 0.1799 - val_acc: 0.9660
# Epoch 10/10
# 3277/3277 [==============================] - 6s - loss: 7.4032e-04 - acc: 1.0000 - val_loss: 0.1740 - val_acc: 0.9640

# %%
lrg_model.save_weights(path+'models/lrg_nmp.h5')

# %%
lrg_model.load_weights(path+'models/lrg_nmp.h5')

# %% [markdown]
# ## Pseudo-labeling

# %%
preds = model.predict([conv_test_feat, test_sizes], batch_size=batch_size*2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-4fe766611599> in <module>()
# ----> 1 preds = model.predict([conv_test_feat, test_sizes], batch_size=batch_size*2)
#
# NameError: name 'test_sizes' is not defined

# %%
gen = image.ImageDataGenerator()

# %%
test_batches = gen.flow(conv_test_feat, preds, batch_size=16)

# %%
val_batches = gen.flow(conv_val_feat, val_labels, batch_size=4)

# %%
batches = gen.flow(conv_feat, trn_labels, batch_size=44)

# %%
mi = MixIterator([batches, test_batches, val_batches)

# %%
bn_model.fit_generator(mi, mi.N, nb_epoch=8, validation_data=(conv_val_feat, val_labels))
# Out:
# Epoch 1/8
# 4833/4777 [==============================] - 4s - loss: 0.2538 - acc: 0.9462 - val_loss: 0.1313 - val_acc: 0.9700
# Epoch 2/8
#  192/4777 [>.............................] - ETA: 2s - loss: 0.1972 - acc: 0.9635
# /usr/local/lib/python2.7/dist-packages/keras/engine/training.py:1494: UserWarning: Epoch comprised more than `samples_per_epoch` samples, which might affect learning results. Set `samples_per_epoch` correctly to avoid this warning.
#   warnings.warn('Epoch comprised more than '
# 4833/4777 [==============================] - 4s - loss: 0.2231 - acc: 0.9491 - val_loss: 0.0820 - val_acc: 0.9820
# Epoch 3/8
# 4833/4777 [==============================] - 3s - loss: 0.1860 - acc: 0.9545 - val_loss: 0.0580 - val_acc: 0.9840
# Epoch 4/8
# 4833/4777 [==============================] - 3s - loss: 0.1559 - acc: 0.9663 - val_loss: 0.0521 - val_acc: 0.9840
# Epoch 5/8
# 4825/4777 [==============================] - 3s - loss: 0.1366 - acc: 0.9693 - val_loss: 0.0422 - val_acc: 0.9840
# Epoch 6/8
# 4833/4777 [==============================] - 3s - loss: 0.1303 - acc: 0.9704 - val_loss: 0.0195 - val_acc: 0.9940
# Epoch 7/8
# 4833/4777 [==============================] - 3s - loss: 0.1283 - acc: 0.9708 - val_loss: 0.0133 - val_acc: 0.9940
# Epoch 8/8
# 4833/4777 [==============================] - 4s - loss: 0.1199 - acc: 0.9752 - val_loss: 0.0247 - val_acc: 0.9900

# %% [markdown]
# ## Resnet

# %%
from resnet50 import Resnet50
rs_model = Resnet50(include_top=False)

# %%
trn_features = rs_model.model.predict_generator(batches, batches.nb_sample)

# %%
val_features = rs_model.model.predict_generator(val_batches, val_batches.nb_sample)

# %%
test_features = rs_model.model.predict_generator(test_batches, test_batches.nb_sample)

# %%
save_array(path+'results/trn_features.dat', trn_features)
save_array(path+'results/val_features.dat', val_features)

# %%
save_array(path+'results/test_features.dat', test_features)

# %%
def get_fc_layers(p):
    return [
        BatchNormalization(axis=1, input_shape=rs_model.model.output_shape[1:]),
        Flatten(),
        Dropout(p/2),
        Dense(1024, activation='relu'),
        BatchNormalization(),
        Dropout(p),
        Dense(1024, activation='relu'),
        BatchNormalization(),
        Dropout(p/2),
        Dense(8, activation='softmax')
        ]

# %%
fc_model = Sequential(get_fc_layers(0.7))

# %%
fc_model.compile(optimizer=Adam(), loss='categorical_crossentropy', metrics=['accuracy'])

# %%
fc_model.fit(trn_features, trn_labels, validation_data=(val_features, val_labels), nb_epoch=2, batch_size=batch_size)
# Out:
# Train on 3277 samples, validate on 500 samples
# Epoch 1/2
# 3277/3277 [==============================] - 6s - loss: 0.2379 - acc: 0.9326 - val_loss: 0.2685 - val_acc: 0.9400
# Epoch 2/2
# 3277/3277 [==============================] - 6s - loss: 0.1313 - acc: 0.9582 - val_loss: 0.3035 - val_acc: 0.9420

# %%
fc_model.optimizer.lr = 0.000001

# %%
fc_model.save_weights(path+'results/resnet_0.3035_loss.h5')

# %%
fc_model.fit(trn_features, trn_labels, validation_data=(val_features, val_labels), nb_epoch=2, batch_size=batch_size)
# Out:
# Train on 3277 samples, validate on 500 samples
# Epoch 1/2
# 3277/3277 [==============================] - 6s - loss: 0.0581 - acc: 0.9826 - val_loss: 0.2624 - val_acc: 0.9580
# Epoch 2/2
# 3277/3277 [==============================] - 6s - loss: 0.0432 - acc: 0.9863 - val_loss: 0.2513 - val_acc: 0.9580

# %%
fc_model.save_weights(path+'results/resnet_0.2513_loss.h5')

# %%
fc_model.fit(trn_features, trn_labels, validation_data=(val_features, val_labels), nb_epoch=2, batch_size=batch_size)
# Out:
# Train on 3277 samples, validate on 500 samples
# Epoch 1/2
# 3277/3277 [==============================] - 6s - loss: 0.0346 - acc: 0.9927 - val_loss: 0.2721 - val_acc: 0.9600
# Epoch 2/2
# 3277/3277 [==============================] - 6s - loss: 0.0264 - acc: 0.9939 - val_loss: 0.2708 - val_acc: 0.9540

# %%
fc_model.save_weights(path+'results/resnet_0.2708_loss.h5')

# %%
fc_model.load_weights(path+'results/resnet_1_3860.h5')

# %%
fc_model.fit(trn_features, trn_labels, validation_data=(val_features, val_labels), nb_epoch=2, batch_size=batch_size)
# Out:
# Train on 3277 samples, validate on 500 samples
# Epoch 1/2
# 3277/3277 [==============================] - 6s - loss: 1.6383 - acc: 0.4764 - val_loss: 2.3331 - val_acc: 0.3520
# Epoch 2/2
# 3277/3277 [==============================] - 6s - loss: 1.2720 - acc: 0.5810 - val_loss: 2.3038 - val_acc: 0.3860

# %%
def get_ap_layers(p):
    return [
        GlobalAveragePooling2D(input_shape=rs_model.model.output_shape[1:]),
        Dropout(p),
        Dense(8, activation='softmax')
    ]

# %%
ap_model = Sequential(get_ap_layers(0.15))
ap_model.compile(optimizer=Adam(), loss='categorical_crossentropy', metrics=['accuracy'])
# Out:
# th

# %%
ap_model.fit(trn_features, trn_labels, validation_data=(val_features, val_labels), nb_epoch=3, batch_size=batch_size)
# Out:
# Train on 3277 samples, validate on 500 samples
# Epoch 1/3
# 3277/3277 [==============================] - 0s - loss: 0.3814 - acc: 0.8847 - val_loss: 0.4077 - val_acc: 0.8700
# Epoch 2/3
# 3277/3277 [==============================] - 0s - loss: 0.3608 - acc: 0.8859 - val_loss: 0.3980 - val_acc: 0.8740
# Epoch 3/3
# 3277/3277 [==============================] - 0s - loss: 0.3327 - acc: 0.8972 - val_loss: 0.4330 - val_acc: 0.8240

# %%
ap_model.fit(trn_features, trn_labels, validation_data=(val_features, val_labels), nb_epoch=3, batch_size=batch_size)
# Out:
# Train on 3277 samples, validate on 500 samples
# Epoch 1/3
# 3277/3277 [==============================] - 0s - loss: 0.5772 - acc: 0.8004 - val_loss: 0.5256 - val_acc: 0.8240
# Epoch 2/3
# 3277/3277 [==============================] - 0s - loss: 0.4865 - acc: 0.8367 - val_loss: 0.4806 - val_acc: 0.8320
# Epoch 3/3
# 3277/3277 [==============================] - 0s - loss: 0.4406 - acc: 0.8575 - val_loss: 0.4222 - val_acc: 0.8760

# %%
ap_model.save_weights(path+'results/resnet_ap_1.7030.h5')

# %%
preds = fc_model.predict(test_features)

# %%
batches = get_batches(path+'train', batch_size=batch_size, target_size=(360,640))
val_batches = get_batches(path+'valid', batch_size=batch_size*2, shuffle=False, target_size=(360,640))
test_batches = get_batches(path+'test', batch_size=batch_size*2, shuffle=False, target_size=(360,640))
# Out:
# Found 3277 images belonging to 8 classes.
# Found 500 images belonging to 8 classes.
# Found 1000 images belonging to 1 classes.

# %%
trn_features = rs_model.model.predict_generator(batches, batches.nb_sample)
val_features = rs_model.model.predict_generator(val_batches, val_batches.nb_sample)
test_features = rs_model.model.predict_generator(test_batches, test_batches.nb_sample)
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-66-236f14156d10> in <module>()
#       1 trn_features = rs_model.model.predict_generator(batches, batches.nb_sample)
# ----> 2 val_features = rs_model.model.predict_generator(val_batches, val_batches.nb_sample)
#       3 test_features = rs_model.model.predict_generator(test_batches, test_batches.nb_sample)
#
# /home/ubuntu/anaconda2/lib/python2.7/site-packages/keras/engine/training.pyc in predict_generator(self, generator, val_samples, max_q_size, nb_worker, pickle_safe)
#    1632
#    1633             try:
# -> 1634                 outs = self.predict_on_batch(x)
#    1635             except:
#    1636                 _stop.set()
#
# /home/ubuntu/anaconda2/lib/python2.7/site-packages/keras/engine/training.pyc in predict_on_batch(self, x)
#    1272             ins = x
#    1273         self._make_predict_function()
# -> 1274         outputs = self.predict_function(ins)
#    1275         if len(outputs) == 1:
#    1276             return outputs[0]
#
# /home/ubuntu/anaconda2/lib/python2.7/site-packages/keras/backend/theano_backend.pyc in __call__(self, inputs)
#     715     def __call__(self, inputs):
#     716         assert type(inputs) in {list, tuple}
# --> 717         return self.function(*inputs)
#     718
#     719
#
# /home/ubuntu/anaconda2/lib/python2.7/site-packages/theano/compile/function_module.pyc in __call__(self, *args, **kwargs)
#     869                     node=self.fn.nodes[self.fn.position_of_error],
#     870                     thunk=thunk,
# --> 871                     storage_map=getattr(self.fn, 'storage_map', None))
#     872             else:
#     873                 # old-style linkers raise their own exceptions
#
# /home/ubuntu/anaconda2/lib/python2.7/site-packages/theano/gof/link.pyc in raise_with_op(node, thunk, exc_info, storage_map)
#     312         # extra long error message in that case.
#     313         pass
# --> 314     reraise(exc_type, exc_value, exc_trace)
#     315
#     316
#
# /home/ubuntu/anaconda2/lib/python2.7/site-packages/theano/compile/function_module.pyc in __call__(self, *args, **kwargs)
#     857         t0_fn = time.time()
#     858         try:
# --> 859             outputs = self.fn()
#     860         except Exception:
#     861             if hasattr(self.fn, 'position_of_error'):
#
# MemoryError: Error allocating 1854799872 bytes of device memory (out of memory).
# Apply node that caused the error: GpuElemwise{Composite{((i0 - i1) * i2)},no_inplace}(GpuElemwise{add,no_inplace}.0, GpuReshape{4}.0, GpuElemwise{Composite{(i0 / sqrt(clip((i1 + i2), i3, i4)))},no_inplace}.0)
# Toposort index: 1025
# Inputs types: [CudaNdarrayType(float32, 4D), CudaNdarrayType(float32, (True, False, True, True)), CudaNdarrayType(float32, (True, False, True, True))]
# Inputs shapes: [(128, 256, 89, 159), (1, 256, 1, 1), (1, 256, 1, 1)]
# Inputs strides: [(3622656, 14151, 159, 1), (0, 1, 0, 0), (0, 1, 0, 0)]
# Inputs values: ['not shown', 'not shown', 'not shown']
# Outputs clients: [[GpuElemwise{Composite{(Switch(i0, (i1 + i2), (i3 + i2)) + Switch(i0, (i4 + i5), (i6 + i5)))}}[(0, 3)](GpuFromHost.0, GpuElemwise{Composite{((i0 - i1) * i2)},no_inplace}.0, GpuReshape{4}.0, GpuElemwise{Composite{((i0 - i1) * i2)},no_inplace}.0, GpuElemwise{Composite{((i0 - i1) * i2)},no_inplace}.0, GpuReshape{4}.0, GpuElemwise{Composite{((i0 - i1) * i2)},no_inplace}.0)]]
#
# HINT: Re-running with most Theano optimization disabled could give you a back-trace of when this node was created. This can be done with by setting the Theano flag 'optimizer=fast_compile'. If that does not work, Theano optimizations can be disabled with 'optimizer=None'.
# HINT: Use the Theano flag 'exception_verbosity=high' for a debugprint and storage map footprint of this apply node.

# %% [markdown]
# ## Submit

# %%
def do_clip(arr, mx): return np.clip(arr, (1-mx)/7, mx)

# %%
lrg_model.evaluate(conv_val_feat, val_labels, batch_size*2)
# Out:
# 500/500 [==============================] - 0s
# [0.11417267167568207, 0.97199999332427978]

# %%
preds = ap_model.predict(conv_test_feat, batch_size=batch_size)
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# <ipython-input-53-10c480de20c7> in <module>()
# ----> 1 preds = ap_model.predict(conv_test_feat, batch_size=batch_size)
#
# /home/ubuntu/anaconda2/lib/python2.7/site-packages/keras/models.pyc in predict(self, x, batch_size, verbose)
#     669         if self.model is None:
#     670             self.build()
# --> 671         return self.model.predict(x, batch_size=batch_size, verbose=verbose)
#     672
#     673     def predict_on_batch(self, x):
#
# /home/ubuntu/anaconda2/lib/python2.7/site-packages/keras/engine/training.pyc in predict(self, x, batch_size, verbose)
#    1159         x = standardize_input_data(x, self.input_names,
#    1160                                    self.internal_input_shapes,
# -> 1161                                    check_batch_dim=False)
#    1162         if self.stateful:
#    1163             if x[0].shape[0] > batch_size and x[0].shape[0] % batch_size != 0:
#
# /home/ubuntu/anaconda2/lib/python2.7/site-packages/keras/engine/training.pyc in standardize_input_data(data, names, shapes, check_batch_dim, exception_prefix)
#     106                                         ' to have shape ' + str(shapes[i]) +
#     107                                         ' but got array with shape ' +
# --> 108                                         str(array.shape))
#     109     return arrays
#     110
#
# Exception: Error when checking : expected globalaveragepooling2d_input_6 to have shape (None, 2048, 7, 7) but got array with shape (1000, 512, 14, 14)

# %%
preds = fc_model.predict(conv_test_feat, batch_size=batch_size)
# Out:
# 500/500 [==============================] - 0s

# %%
preds = preds[1]

# %%
test = load_array(path+'results/test_640.dat')

# %%
test = load_array(path+'results/test.dat')

# %%
preds = conv_model.predict(test, batch_size=32)

# %%
subm = do_clip(preds,0.80)

# %%
subm_name = path+'results/subm_rs_learning_rate_clip80.gz'

# %%
# classes = sorted(batches.class_indices, key=batches.class_indices.get)
classes = ['ALB', 'BET', 'DOL', 'LAG', 'NoF', 'OTHER', 'SHARK', 'YFT']

# %%
submission = pd.DataFrame(subm, columns=classes)
submission.insert(0, 'image', raw_test_filenames)
submission.head()
# Out:
#            image       ALB       BET       DOL       LAG       NoF     OTHER  \
# 0  img_06237.jpg  0.793981  0.203020  0.028571  0.028571  0.028571  0.028571
# 1  img_06893.jpg  0.800000  0.028571  0.028571  0.028571  0.028571  0.028571
# 2  img_02082.jpg  0.800000  0.028571  0.028571  0.028571  0.028571  0.028571
# 3  img_06261.jpg  0.800000  0.028571  0.028571  0.028571  0.028571  0.028571
# 4  img_03628.jpg  0.800000  0.028571  0.028571  0.028571  0.028571  0.028571
#
#       SHARK       YFT
# 0  0.028571  0.028571
# 1  0.028571  0.140181
# 2  0.028571  0.028571
# 3  0.028571  0.028571
# 4  0.028571  0.028571

# %%
submission.to_csv(subm_name, index=False, compression='gzip')

# %%
FileLink(subm_name)
# Out:
# /home/ubuntu/data/fisheries/results/subm_rs_learning_rate_clip80.gz

# %% [markdown]
# ## Full Resnet

# %%
from resnet50 import Resnet50
rs_model = Resnet50(include_top=True)
# Out:
# Downloading data from http://www.platform.ai/models/resnet50.h5
# 102309888/102853280 [============================>.] - ETA: 0s

# %%
model = rs_model.model

# %%
model.layers.pop()

# %%
model.summary()
# Out:
# ____________________________________________________________________________________________________
# Layer (type)                     Output Shape          Param #     Connected to
# ====================================================================================================
# input_2 (InputLayer)             (None, 3, 224, 224)   0
# ____________________________________________________________________________________________________
# lambda_2 (Lambda)                (None, 3, 224, 224)   0           input_2[0][0]
# ____________________________________________________________________________________________________
# zeropadding2d_2 (ZeroPadding2D)  (None, 3, 230, 230)   0           lambda_2[0][0]
# ____________________________________________________________________________________________________
# conv1 (Convolution2D)            (None, 64, 112, 112)  9472        zeropadding2d_2[0][0]
# ____________________________________________________________________________________________________
# bn_conv1 (BatchNormalization)    (None, 64, 112, 112)  128         conv1[0][0]
# ____________________________________________________________________________________________________
# activation_50 (Activation)       (None, 64, 112, 112)  0           bn_conv1[0][0]
# ____________________________________________________________________________________________________
# maxpooling2d_2 (MaxPooling2D)    (None, 64, 55, 55)    0           activation_50[0][0]
# ____________________________________________________________________________________________________
# res2a_branch2a (Convolution2D)   (None, 64, 55, 55)    4160        maxpooling2d_2[0][0]
# ____________________________________________________________________________________________________
# bn2a_branch2a (BatchNormalization(None, 64, 55, 55)    128         res2a_branch2a[0][0]
# ____________________________________________________________________________________________________
# activation_51 (Activation)       (None, 64, 55, 55)    0           bn2a_branch2a[0][0]
# ____________________________________________________________________________________________________
# res2a_branch2b (Convolution2D)   (None, 64, 55, 55)    36928       activation_51[0][0]
# ____________________________________________________________________________________________________
# bn2a_branch2b (BatchNormalization(None, 64, 55, 55)    128         res2a_branch2b[0][0]
# ____________________________________________________________________________________________________
# activation_52 (Activation)       (None, 64, 55, 55)    0           bn2a_branch2b[0][0]
# ____________________________________________________________________________________________________
# res2a_branch2c (Convolution2D)   (None, 256, 55, 55)   16640       activation_52[0][0]
# ____________________________________________________________________________________________________
# res2a_branch1 (Convolution2D)    (None, 256, 55, 55)   16640       maxpooling2d_2[0][0]
# ____________________________________________________________________________________________________
# bn2a_branch2c (BatchNormalization(None, 256, 55, 55)   512         res2a_branch2c[0][0]
# ____________________________________________________________________________________________________
# bn2a_branch1 (BatchNormalization)(None, 256, 55, 55)   512         res2a_branch1[0][0]
# ____________________________________________________________________________________________________
# merge_17 (Merge)                 (None, 256, 55, 55)   0           bn2a_branch2c[0][0]
#                                                                    bn2a_branch1[0][0]
# ____________________________________________________________________________________________________
# activation_53 (Activation)       (None, 256, 55, 55)   0           merge_17[0][0]
# ____________________________________________________________________________________________________
# res2b_branch2a (Convolution2D)   (None, 64, 55, 55)    16448       activation_53[0][0]
# ____________________________________________________________________________________________________
# bn2b_branch2a (BatchNormalization(None, 64, 55, 55)    128         res2b_branch2a[0][0]
# ____________________________________________________________________________________________________
# activation_54 (Activation)       (None, 64, 55, 55)    0           bn2b_branch2a[0][0]
# ____________________________________________________________________________________________________
# res2b_branch2b (Convolution2D)   (None, 64, 55, 55)    36928       activation_54[0][0]
# ____________________________________________________________________________________________________
# bn2b_branch2b (BatchNormalization(None, 64, 55, 55)    128         res2b_branch2b[0][0]
# ____________________________________________________________________________________________________
# activation_55 (Activation)       (None, 64, 55, 55)    0           bn2b_branch2b[0][0]
# ____________________________________________________________________________________________________
# res2b_branch2c (Convolution2D)   (None, 256, 55, 55)   16640       activation_55[0][0]
# ____________________________________________________________________________________________________
# bn2b_branch2c (BatchNormalization(None, 256, 55, 55)   512         res2b_branch2c[0][0]
# ____________________________________________________________________________________________________
# merge_18 (Merge)                 (None, 256, 55, 55)   0           bn2b_branch2c[0][0]
#                                                                    activation_53[0][0]
# ____________________________________________________________________________________________________
# activation_56 (Activation)       (None, 256, 55, 55)   0           merge_18[0][0]
# ____________________________________________________________________________________________________
# res2c_branch2a (Convolution2D)   (None, 64, 55, 55)    16448       activation_56[0][0]
# ____________________________________________________________________________________________________
# bn2c_branch2a (BatchNormalization(None, 64, 55, 55)    128         res2c_branch2a[0][0]
# ____________________________________________________________________________________________________
# activation_57 (Activation)       (None, 64, 55, 55)    0           bn2c_branch2a[0][0]
# ____________________________________________________________________________________________________
# res2c_branch2b (Convolution2D)   (None, 64, 55, 55)    36928       activation_57[0][0]
# ____________________________________________________________________________________________________
# bn2c_branch2b (BatchNormalization(None, 64, 55, 55)    128         res2c_branch2b[0][0]
# ____________________________________________________________________________________________________
# activation_58 (Activation)       (None, 64, 55, 55)    0           bn2c_branch2b[0][0]
# ____________________________________________________________________________________________________
# res2c_branch2c (Convolution2D)   (None, 256, 55, 55)   16640       activation_58[0][0]
# ____________________________________________________________________________________________________
# bn2c_branch2c (BatchNormalization(None, 256, 55, 55)   512         res2c_branch2c[0][0]
# ____________________________________________________________________________________________________
# merge_19 (Merge)                 (None, 256, 55, 55)   0           bn2c_branch2c[0][0]
#                                                                    activation_56[0][0]
# ____________________________________________________________________________________________________
# activation_59 (Activation)       (None, 256, 55, 55)   0           merge_19[0][0]
# ____________________________________________________________________________________________________
# res3a_branch2a (Convolution2D)   (None, 128, 28, 28)   32896       activation_59[0][0]
# ____________________________________________________________________________________________________
# bn3a_branch2a (BatchNormalization(None, 128, 28, 28)   256         res3a_branch2a[0][0]
# ____________________________________________________________________________________________________
# activation_60 (Activation)       (None, 128, 28, 28)   0           bn3a_branch2a[0][0]
# ____________________________________________________________________________________________________
# res3a_branch2b (Convolution2D)   (None, 128, 28, 28)   147584      activation_60[0][0]
# ____________________________________________________________________________________________________
# bn3a_branch2b (BatchNormalization(None, 128, 28, 28)   256         res3a_branch2b[0][0]
# ____________________________________________________________________________________________________
# activation_61 (Activation)       (None, 128, 28, 28)   0           bn3a_branch2b[0][0]
# ____________________________________________________________________________________________________
# res3a_branch2c (Convolution2D)   (None, 512, 28, 28)   66048       activation_61[0][0]
# ____________________________________________________________________________________________________
# res3a_branch1 (Convolution2D)    (None, 512, 28, 28)   131584      activation_59[0][0]
# ____________________________________________________________________________________________________
# bn3a_branch2c (BatchNormalization(None, 512, 28, 28)   1024        res3a_branch2c[0][0]
# ____________________________________________________________________________________________________
# bn3a_branch1 (BatchNormalization)(None, 512, 28, 28)   1024        res3a_branch1[0][0]
# ____________________________________________________________________________________________________
# merge_20 (Merge)                 (None, 512, 28, 28)   0           bn3a_branch2c[0][0]
#                                                                    bn3a_branch1[0][0]
# ____________________________________________________________________________________________________
# activation_62 (Activation)       (None, 512, 28, 28)   0           merge_20[0][0]
# ____________________________________________________________________________________________________
# res3b_branch2a (Convolution2D)   (None, 128, 28, 28)   65664       activation_62[0][0]
# ____________________________________________________________________________________________________
# bn3b_branch2a (BatchNormalization(None, 128, 28, 28)   256         res3b_branch2a[0][0]
# ____________________________________________________________________________________________________
# activation_63 (Activation)       (None, 128, 28, 28)   0           bn3b_branch2a[0][0]
# ____________________________________________________________________________________________________
# res3b_branch2b (Convolution2D)   (None, 128, 28, 28)   147584      activation_63[0][0]
# ____________________________________________________________________________________________________
# bn3b_branch2b (BatchNormalization(None, 128, 28, 28)   256         res3b_branch2b[0][0]
# ____________________________________________________________________________________________________
# activation_64 (Activation)       (None, 128, 28, 28)   0           bn3b_branch2b[0][0]
# ____________________________________________________________________________________________________
# res3b_branch2c (Convolution2D)   (None, 512, 28, 28)   66048       activation_64[0][0]
# ____________________________________________________________________________________________________
# bn3b_branch2c (BatchNormalization(None, 512, 28, 28)   1024        res3b_branch2c[0][0]
# ____________________________________________________________________________________________________
# merge_21 (Merge)                 (None, 512, 28, 28)   0           bn3b_branch2c[0][0]
#                                                                    activation_62[0][0]
# ____________________________________________________________________________________________________
# activation_65 (Activation)       (None, 512, 28, 28)   0           merge_21[0][0]
# ____________________________________________________________________________________________________
# res3c_branch2a (Convolution2D)   (None, 128, 28, 28)   65664       activation_65[0][0]
# ____________________________________________________________________________________________________
# bn3c_branch2a (BatchNormalization(None, 128, 28, 28)   256         res3c_branch2a[0][0]
# ____________________________________________________________________________________________________
# activation_66 (Activation)       (None, 128, 28, 28)   0           bn3c_branch2a[0][0]
# ____________________________________________________________________________________________________
# res3c_branch2b (Convolution2D)   (None, 128, 28, 28)   147584      activation_66[0][0]
# ____________________________________________________________________________________________________
# bn3c_branch2b (BatchNormalization(None, 128, 28, 28)   256         res3c_branch2b[0][0]
# ____________________________________________________________________________________________________
# activation_67 (Activation)       (None, 128, 28, 28)   0           bn3c_branch2b[0][0]
# ____________________________________________________________________________________________________
# res3c_branch2c (Convolution2D)   (None, 512, 28, 28)   66048       activation_67[0][0]
# ____________________________________________________________________________________________________
# bn3c_branch2c (BatchNormalization(None, 512, 28, 28)   1024        res3c_branch2c[0][0]
# ____________________________________________________________________________________________________
# merge_22 (Merge)                 (None, 512, 28, 28)   0           bn3c_branch2c[0][0]
#                                                                    activation_65[0][0]
# ____________________________________________________________________________________________________
# activation_68 (Activation)       (None, 512, 28, 28)   0           merge_22[0][0]
# ____________________________________________________________________________________________________
# res3d_branch2a (Convolution2D)   (None, 128, 28, 28)   65664       activation_68[0][0]
# ____________________________________________________________________________________________________
# bn3d_branch2a (BatchNormalization(None, 128, 28, 28)   256         res3d_branch2a[0][0]
# ____________________________________________________________________________________________________
# activation_69 (Activation)       (None, 128, 28, 28)   0           bn3d_branch2a[0][0]
# ____________________________________________________________________________________________________
# res3d_branch2b (Convolution2D)   (None, 128, 28, 28)   147584      activation_69[0][0]
# ____________________________________________________________________________________________________
# bn3d_branch2b (BatchNormalization(None, 128, 28, 28)   256         res3d_branch2b[0][0]
# ____________________________________________________________________________________________________
# activation_70 (Activation)       (None, 128, 28, 28)   0           bn3d_branch2b[0][0]
# ____________________________________________________________________________________________________
# res3d_branch2c (Convolution2D)   (None, 512, 28, 28)   66048       activation_70[0][0]
# ____________________________________________________________________________________________________
# bn3d_branch2c (BatchNormalization(None, 512, 28, 28)   1024        res3d_branch2c[0][0]
# ____________________________________________________________________________________________________
# merge_23 (Merge)                 (None, 512, 28, 28)   0           bn3d_branch2c[0][0]
#                                                                    activation_68[0][0]
# ____________________________________________________________________________________________________
# activation_71 (Activation)       (None, 512, 28, 28)   0           merge_23[0][0]
# ____________________________________________________________________________________________________
# res4a_branch2a (Convolution2D)   (None, 256, 14, 14)   131328      activation_71[0][0]
# ____________________________________________________________________________________________________
# bn4a_branch2a (BatchNormalization(None, 256, 14, 14)   512         res4a_branch2a[0][0]
# ____________________________________________________________________________________________________
# activation_72 (Activation)       (None, 256, 14, 14)   0           bn4a_branch2a[0][0]
# ____________________________________________________________________________________________________
# res4a_branch2b (Convolution2D)   (None, 256, 14, 14)   590080      activation_72[0][0]
# ____________________________________________________________________________________________________
# bn4a_branch2b (BatchNormalization(None, 256, 14, 14)   512         res4a_branch2b[0][0]
# ____________________________________________________________________________________________________
# activation_73 (Activation)       (None, 256, 14, 14)   0           bn4a_branch2b[0][0]
# ____________________________________________________________________________________________________
# res4a_branch2c (Convolution2D)   (None, 1024, 14, 14)  263168      activation_73[0][0]
# ____________________________________________________________________________________________________
# res4a_branch1 (Convolution2D)    (None, 1024, 14, 14)  525312      activation_71[0][0]
# ____________________________________________________________________________________________________
# bn4a_branch2c (BatchNormalization(None, 1024, 14, 14)  2048        res4a_branch2c[0][0]
# ____________________________________________________________________________________________________
# bn4a_branch1 (BatchNormalization)(None, 1024, 14, 14)  2048        res4a_branch1[0][0]
# ____________________________________________________________________________________________________
# merge_24 (Merge)                 (None, 1024, 14, 14)  0           bn4a_branch2c[0][0]
#                                                                    bn4a_branch1[0][0]
# ____________________________________________________________________________________________________
# activation_74 (Activation)       (None, 1024, 14, 14)  0           merge_24[0][0]
# ____________________________________________________________________________________________________
# res4b_branch2a (Convolution2D)   (None, 256, 14, 14)   262400      activation_74[0][0]
# ____________________________________________________________________________________________________
# bn4b_branch2a (BatchNormalization(None, 256, 14, 14)   512         res4b_branch2a[0][0]
# ____________________________________________________________________________________________________
# activation_75 (Activation)       (None, 256, 14, 14)   0           bn4b_branch2a[0][0]
# ____________________________________________________________________________________________________
# res4b_branch2b (Convolution2D)   (None, 256, 14, 14)   590080      activation_75[0][0]
# ____________________________________________________________________________________________________
# bn4b_branch2b (BatchNormalization(None, 256, 14, 14)   512         res4b_branch2b[0][0]
# ____________________________________________________________________________________________________
# activation_76 (Activation)       (None, 256, 14, 14)   0           bn4b_branch2b[0][0]
# ____________________________________________________________________________________________________
# res4b_branch2c (Convolution2D)   (None, 1024, 14, 14)  263168      activation_76[0][0]
# ____________________________________________________________________________________________________
# bn4b_branch2c (BatchNormalization(None, 1024, 14, 14)  2048        res4b_branch2c[0][0]
# ____________________________________________________________________________________________________
# merge_25 (Merge)                 (None, 1024, 14, 14)  0           bn4b_branch2c[0][0]
#                                                                    activation_74[0][0]
# ____________________________________________________________________________________________________
# activation_77 (Activation)       (None, 1024, 14, 14)  0           merge_25[0][0]
# ____________________________________________________________________________________________________
# res4c_branch2a (Convolution2D)   (None, 256, 14, 14)   262400      activation_77[0][0]
# ____________________________________________________________________________________________________
# bn4c_branch2a (BatchNormalization(None, 256, 14, 14)   512         res4c_branch2a[0][0]
# ____________________________________________________________________________________________________
# activation_78 (Activation)       (None, 256, 14, 14)   0           bn4c_branch2a[0][0]
# ____________________________________________________________________________________________________
# res4c_branch2b (Convolution2D)   (None, 256, 14, 14)   590080      activation_78[0][0]
# ____________________________________________________________________________________________________
# bn4c_branch2b (BatchNormalization(None, 256, 14, 14)   512         res4c_branch2b[0][0]
# ____________________________________________________________________________________________________
# activation_79 (Activation)       (None, 256, 14, 14)   0           bn4c_branch2b[0][0]
# ____________________________________________________________________________________________________
# res4c_branch2c (Convolution2D)   (None, 1024, 14, 14)  263168      activation_79[0][0]
# ____________________________________________________________________________________________________
# bn4c_branch2c (BatchNormalization(None, 1024, 14, 14)  2048        res4c_branch2c[0][0]
# ____________________________________________________________________________________________________
# merge_26 (Merge)                 (None, 1024, 14, 14)  0           bn4c_branch2c[0][0]
#                                                                    activation_77[0][0]
# ____________________________________________________________________________________________________
# activation_80 (Activation)       (None, 1024, 14, 14)  0           merge_26[0][0]
# ____________________________________________________________________________________________________
# res4d_branch2a (Convolution2D)   (None, 256, 14, 14)   262400      activation_80[0][0]
# ____________________________________________________________________________________________________
# bn4d_branch2a (BatchNormalization(None, 256, 14, 14)   512         res4d_branch2a[0][0]
# ____________________________________________________________________________________________________
# activation_81 (Activation)       (None, 256, 14, 14)   0           bn4d_branch2a[0][0]
# ____________________________________________________________________________________________________
# res4d_branch2b (Convolution2D)   (None, 256, 14, 14)   590080      activation_81[0][0]
# ____________________________________________________________________________________________________
# bn4d_branch2b (BatchNormalization(None, 256, 14, 14)   512         res4d_branch2b[0][0]
# ____________________________________________________________________________________________________
# activation_82 (Activation)       (None, 256, 14, 14)   0           bn4d_branch2b[0][0]
# ____________________________________________________________________________________________________
# res4d_branch2c (Convolution2D)   (None, 1024, 14, 14)  263168      activation_82[0][0]
# ____________________________________________________________________________________________________
# bn4d_branch2c (BatchNormalization(None, 1024, 14, 14)  2048        res4d_branch2c[0][0]
# ____________________________________________________________________________________________________
# merge_27 (Merge)                 (None, 1024, 14, 14)  0           bn4d_branch2c[0][0]
#                                                                    activation_80[0][0]
# ____________________________________________________________________________________________________
# activation_83 (Activation)       (None, 1024, 14, 14)  0           merge_27[0][0]
# ____________________________________________________________________________________________________
# res4e_branch2a (Convolution2D)   (None, 256, 14, 14)   262400      activation_83[0][0]
# ____________________________________________________________________________________________________
# bn4e_branch2a (BatchNormalization(None, 256, 14, 14)   512         res4e_branch2a[0][0]
# ____________________________________________________________________________________________________
# activation_84 (Activation)       (None, 256, 14, 14)   0           bn4e_branch2a[0][0]
# ____________________________________________________________________________________________________
# res4e_branch2b (Convolution2D)   (None, 256, 14, 14)   590080      activation_84[0][0]
# ____________________________________________________________________________________________________
# bn4e_branch2b (BatchNormalization(None, 256, 14, 14)   512         res4e_branch2b[0][0]
# ____________________________________________________________________________________________________
# activation_85 (Activation)       (None, 256, 14, 14)   0           bn4e_branch2b[0][0]
# ____________________________________________________________________________________________________
# res4e_branch2c (Convolution2D)   (None, 1024, 14, 14)  263168      activation_85[0][0]
# ____________________________________________________________________________________________________
# bn4e_branch2c (BatchNormalization(None, 1024, 14, 14)  2048        res4e_branch2c[0][0]
# ____________________________________________________________________________________________________
# merge_28 (Merge)                 (None, 1024, 14, 14)  0           bn4e_branch2c[0][0]
#                                                                    activation_83[0][0]
# ____________________________________________________________________________________________________
# activation_86 (Activation)       (None, 1024, 14, 14)  0           merge_28[0][0]
# ____________________________________________________________________________________________________
# res4f_branch2a (Convolution2D)   (None, 256, 14, 14)   262400      activation_86[0][0]
# ____________________________________________________________________________________________________
# bn4f_branch2a (BatchNormalization(None, 256, 14, 14)   512         res4f_branch2a[0][0]
# ____________________________________________________________________________________________________
# activation_87 (Activation)       (None, 256, 14, 14)   0           bn4f_branch2a[0][0]
# ____________________________________________________________________________________________________
# res4f_branch2b (Convolution2D)   (None, 256, 14, 14)   590080      activation_87[0][0]
# ____________________________________________________________________________________________________
# bn4f_branch2b (BatchNormalization(None, 256, 14, 14)   512         res4f_branch2b[0][0]
# ____________________________________________________________________________________________________
# activation_88 (Activation)       (None, 256, 14, 14)   0           bn4f_branch2b[0][0]
# ____________________________________________________________________________________________________
# res4f_branch2c (Convolution2D)   (None, 1024, 14, 14)  263168      activation_88[0][0]
# ____________________________________________________________________________________________________
# bn4f_branch2c (BatchNormalization(None, 1024, 14, 14)  2048        res4f_branch2c[0][0]
# ____________________________________________________________________________________________________
# merge_29 (Merge)                 (None, 1024, 14, 14)  0           bn4f_branch2c[0][0]
#                                                                    activation_86[0][0]
# ____________________________________________________________________________________________________
# activation_89 (Activation)       (None, 1024, 14, 14)  0           merge_29[0][0]
# ____________________________________________________________________________________________________
# res5a_branch2a (Convolution2D)   (None, 512, 7, 7)     524800      activation_89[0][0]
# ____________________________________________________________________________________________________
# bn5a_branch2a (BatchNormalization(None, 512, 7, 7)     1024        res5a_branch2a[0][0]
# ____________________________________________________________________________________________________
# activation_90 (Activation)       (None, 512, 7, 7)     0           bn5a_branch2a[0][0]
# ____________________________________________________________________________________________________
# res5a_branch2b (Convolution2D)   (None, 512, 7, 7)     2359808     activation_90[0][0]
# ____________________________________________________________________________________________________
# bn5a_branch2b (BatchNormalization(None, 512, 7, 7)     1024        res5a_branch2b[0][0]
# ____________________________________________________________________________________________________
# activation_91 (Activation)       (None, 512, 7, 7)     0           bn5a_branch2b[0][0]
# ____________________________________________________________________________________________________
# res5a_branch2c (Convolution2D)   (None, 2048, 7, 7)    1050624     activation_91[0][0]
# ____________________________________________________________________________________________________
# res5a_branch1 (Convolution2D)    (None, 2048, 7, 7)    2099200     activation_89[0][0]
# ____________________________________________________________________________________________________
# bn5a_branch2c (BatchNormalization(None, 2048, 7, 7)    4096        res5a_branch2c[0][0]
# ____________________________________________________________________________________________________
# bn5a_branch1 (BatchNormalization)(None, 2048, 7, 7)    4096        res5a_branch1[0][0]
# ____________________________________________________________________________________________________
# merge_30 (Merge)                 (None, 2048, 7, 7)    0           bn5a_branch2c[0][0]
#                                                                    bn5a_branch1[0][0]
# ____________________________________________________________________________________________________
# activation_92 (Activation)       (None, 2048, 7, 7)    0           merge_30[0][0]
# ____________________________________________________________________________________________________
# res5b_branch2a (Convolution2D)   (None, 512, 7, 7)     1049088     activation_92[0][0]
# ____________________________________________________________________________________________________
# bn5b_branch2a (BatchNormalization(None, 512, 7, 7)     1024        res5b_branch2a[0][0]
# ____________________________________________________________________________________________________
# activation_93 (Activation)       (None, 512, 7, 7)     0           bn5b_branch2a[0][0]
# ____________________________________________________________________________________________________
# res5b_branch2b (Convolution2D)   (None, 512, 7, 7)     2359808     activation_93[0][0]
# ____________________________________________________________________________________________________
# bn5b_branch2b (BatchNormalization(None, 512, 7, 7)     1024        res5b_branch2b[0][0]
# ____________________________________________________________________________________________________
# activation_94 (Activation)       (None, 512, 7, 7)     0           bn5b_branch2b[0][0]
# ____________________________________________________________________________________________________
# res5b_branch2c (Convolution2D)   (None, 2048, 7, 7)    1050624     activation_94[0][0]
# ____________________________________________________________________________________________________
# bn5b_branch2c (BatchNormalization(None, 2048, 7, 7)    4096        res5b_branch2c[0][0]
# ____________________________________________________________________________________________________
# merge_31 (Merge)                 (None, 2048, 7, 7)    0           bn5b_branch2c[0][0]
#                                                                    activation_92[0][0]
# ____________________________________________________________________________________________________
# activation_95 (Activation)       (None, 2048, 7, 7)    0           merge_31[0][0]
# ____________________________________________________________________________________________________
# res5c_branch2a (Convolution2D)   (None, 512, 7, 7)     1049088     activation_95[0][0]
# ____________________________________________________________________________________________________
# bn5c_branch2a (BatchNormalization(None, 512, 7, 7)     1024        res5c_branch2a[0][0]
# ____________________________________________________________________________________________________
# activation_96 (Activation)       (None, 512, 7, 7)     0           bn5c_branch2a[0][0]
# ____________________________________________________________________________________________________
# res5c_branch2b (Convolution2D)   (None, 512, 7, 7)     2359808     activation_96[0][0]
# ____________________________________________________________________________________________________
# bn5c_branch2b (BatchNormalization(None, 512, 7, 7)     1024        res5c_branch2b[0][0]
# ____________________________________________________________________________________________________
# activation_97 (Activation)       (None, 512, 7, 7)     0           bn5c_branch2b[0][0]
# ____________________________________________________________________________________________________
# res5c_branch2c (Convolution2D)   (None, 2048, 7, 7)    1050624     activation_97[0][0]
# ____________________________________________________________________________________________________
# bn5c_branch2c (BatchNormalization(None, 2048, 7, 7)    4096        res5c_branch2c[0][0]
# ____________________________________________________________________________________________________
# merge_32 (Merge)                 (None, 2048, 7, 7)    0           bn5c_branch2c[0][0]
#                                                                    activation_95[0][0]
# ____________________________________________________________________________________________________
# activation_98 (Activation)       (None, 2048, 7, 7)    0           merge_32[0][0]
# ____________________________________________________________________________________________________
# avg_pool (AveragePooling2D)      (None, 2048, 1, 1)    0           activation_98[0][0]
# ____________________________________________________________________________________________________
# flatten_3 (Flatten)              (None, 2048)          0           avg_pool[0][0]
# ====================================================================================================
# Total params: 23534592
# ____________________________________________________________________________________________________

# %%
m = Dense(8, activation='softmax')(model.layers[-1].output)

# %%
model = Model(model.input, m)

# %%
model.summary()
# Out:
# ____________________________________________________________________________________________________
# Layer (type)                     Output Shape          Param #     Connected to
# ====================================================================================================
# input_2 (InputLayer)             (None, 3, 224, 224)   0
# ____________________________________________________________________________________________________
# lambda_2 (Lambda)                (None, 3, 224, 224)   0           input_2[0][0]
# ____________________________________________________________________________________________________
# zeropadding2d_2 (ZeroPadding2D)  (None, 3, 230, 230)   0           lambda_2[0][0]
# ____________________________________________________________________________________________________
# conv1 (Convolution2D)            (None, 64, 112, 112)  9472        zeropadding2d_2[0][0]
# ____________________________________________________________________________________________________
# bn_conv1 (BatchNormalization)    (None, 64, 112, 112)  128         conv1[0][0]
# ____________________________________________________________________________________________________
# activation_50 (Activation)       (None, 64, 112, 112)  0           bn_conv1[0][0]
# ____________________________________________________________________________________________________
# maxpooling2d_2 (MaxPooling2D)    (None, 64, 55, 55)    0           activation_50[0][0]
# ____________________________________________________________________________________________________
# res2a_branch2a (Convolution2D)   (None, 64, 55, 55)    4160        maxpooling2d_2[0][0]
# ____________________________________________________________________________________________________
# bn2a_branch2a (BatchNormalization(None, 64, 55, 55)    128         res2a_branch2a[0][0]
# ____________________________________________________________________________________________________
# activation_51 (Activation)       (None, 64, 55, 55)    0           bn2a_branch2a[0][0]
# ____________________________________________________________________________________________________
# res2a_branch2b (Convolution2D)   (None, 64, 55, 55)    36928       activation_51[0][0]
# ____________________________________________________________________________________________________
# bn2a_branch2b (BatchNormalization(None, 64, 55, 55)    128         res2a_branch2b[0][0]
# ____________________________________________________________________________________________________
# activation_52 (Activation)       (None, 64, 55, 55)    0           bn2a_branch2b[0][0]
# ____________________________________________________________________________________________________
# res2a_branch2c (Convolution2D)   (None, 256, 55, 55)   16640       activation_52[0][0]
# ____________________________________________________________________________________________________
# res2a_branch1 (Convolution2D)    (None, 256, 55, 55)   16640       maxpooling2d_2[0][0]
# ____________________________________________________________________________________________________
# bn2a_branch2c (BatchNormalization(None, 256, 55, 55)   512         res2a_branch2c[0][0]
# ____________________________________________________________________________________________________
# bn2a_branch1 (BatchNormalization)(None, 256, 55, 55)   512         res2a_branch1[0][0]
# ____________________________________________________________________________________________________
# merge_17 (Merge)                 (None, 256, 55, 55)   0           bn2a_branch2c[0][0]
#                                                                    bn2a_branch1[0][0]
# ____________________________________________________________________________________________________
# activation_53 (Activation)       (None, 256, 55, 55)   0           merge_17[0][0]
# ____________________________________________________________________________________________________
# res2b_branch2a (Convolution2D)   (None, 64, 55, 55)    16448       activation_53[0][0]
# ____________________________________________________________________________________________________
# bn2b_branch2a (BatchNormalization(None, 64, 55, 55)    128         res2b_branch2a[0][0]
# ____________________________________________________________________________________________________
# activation_54 (Activation)       (None, 64, 55, 55)    0           bn2b_branch2a[0][0]
# ____________________________________________________________________________________________________
# res2b_branch2b (Convolution2D)   (None, 64, 55, 55)    36928       activation_54[0][0]
# ____________________________________________________________________________________________________
# bn2b_branch2b (BatchNormalization(None, 64, 55, 55)    128         res2b_branch2b[0][0]
# ____________________________________________________________________________________________________
# activation_55 (Activation)       (None, 64, 55, 55)    0           bn2b_branch2b[0][0]
# ____________________________________________________________________________________________________
# res2b_branch2c (Convolution2D)   (None, 256, 55, 55)   16640       activation_55[0][0]
# ____________________________________________________________________________________________________
# bn2b_branch2c (BatchNormalization(None, 256, 55, 55)   512         res2b_branch2c[0][0]
# ____________________________________________________________________________________________________
# merge_18 (Merge)                 (None, 256, 55, 55)   0           bn2b_branch2c[0][0]
#                                                                    activation_53[0][0]
# ____________________________________________________________________________________________________
# activation_56 (Activation)       (None, 256, 55, 55)   0           merge_18[0][0]
# ____________________________________________________________________________________________________
# res2c_branch2a (Convolution2D)   (None, 64, 55, 55)    16448       activation_56[0][0]
# ____________________________________________________________________________________________________
# bn2c_branch2a (BatchNormalization(None, 64, 55, 55)    128         res2c_branch2a[0][0]
# ____________________________________________________________________________________________________
# activation_57 (Activation)       (None, 64, 55, 55)    0           bn2c_branch2a[0][0]
# ____________________________________________________________________________________________________
# res2c_branch2b (Convolution2D)   (None, 64, 55, 55)    36928       activation_57[0][0]
# ____________________________________________________________________________________________________
# bn2c_branch2b (BatchNormalization(None, 64, 55, 55)    128         res2c_branch2b[0][0]
# ____________________________________________________________________________________________________
# activation_58 (Activation)       (None, 64, 55, 55)    0           bn2c_branch2b[0][0]
# ____________________________________________________________________________________________________
# res2c_branch2c (Convolution2D)   (None, 256, 55, 55)   16640       activation_58[0][0]
# ____________________________________________________________________________________________________
# bn2c_branch2c (BatchNormalization(None, 256, 55, 55)   512         res2c_branch2c[0][0]
# ____________________________________________________________________________________________________
# merge_19 (Merge)                 (None, 256, 55, 55)   0           bn2c_branch2c[0][0]
#                                                                    activation_56[0][0]
# ____________________________________________________________________________________________________
# activation_59 (Activation)       (None, 256, 55, 55)   0           merge_19[0][0]
# ____________________________________________________________________________________________________
# res3a_branch2a (Convolution2D)   (None, 128, 28, 28)   32896       activation_59[0][0]
# ____________________________________________________________________________________________________
# bn3a_branch2a (BatchNormalization(None, 128, 28, 28)   256         res3a_branch2a[0][0]
# ____________________________________________________________________________________________________
# activation_60 (Activation)       (None, 128, 28, 28)   0           bn3a_branch2a[0][0]
# ____________________________________________________________________________________________________
# res3a_branch2b (Convolution2D)   (None, 128, 28, 28)   147584      activation_60[0][0]
# ____________________________________________________________________________________________________
# bn3a_branch2b (BatchNormalization(None, 128, 28, 28)   256         res3a_branch2b[0][0]
# ____________________________________________________________________________________________________
# activation_61 (Activation)       (None, 128, 28, 28)   0           bn3a_branch2b[0][0]
# ____________________________________________________________________________________________________
# res3a_branch2c (Convolution2D)   (None, 512, 28, 28)   66048       activation_61[0][0]
# ____________________________________________________________________________________________________
# res3a_branch1 (Convolution2D)    (None, 512, 28, 28)   131584      activation_59[0][0]
# ____________________________________________________________________________________________________
# bn3a_branch2c (BatchNormalization(None, 512, 28, 28)   1024        res3a_branch2c[0][0]
# ____________________________________________________________________________________________________
# bn3a_branch1 (BatchNormalization)(None, 512, 28, 28)   1024        res3a_branch1[0][0]
# ____________________________________________________________________________________________________
# merge_20 (Merge)                 (None, 512, 28, 28)   0           bn3a_branch2c[0][0]
#                                                                    bn3a_branch1[0][0]
# ____________________________________________________________________________________________________
# activation_62 (Activation)       (None, 512, 28, 28)   0           merge_20[0][0]
# ____________________________________________________________________________________________________
# res3b_branch2a (Convolution2D)   (None, 128, 28, 28)   65664       activation_62[0][0]
# ____________________________________________________________________________________________________
# bn3b_branch2a (BatchNormalization(None, 128, 28, 28)   256         res3b_branch2a[0][0]
# ____________________________________________________________________________________________________
# activation_63 (Activation)       (None, 128, 28, 28)   0           bn3b_branch2a[0][0]
# ____________________________________________________________________________________________________
# res3b_branch2b (Convolution2D)   (None, 128, 28, 28)   147584      activation_63[0][0]
# ____________________________________________________________________________________________________
# bn3b_branch2b (BatchNormalization(None, 128, 28, 28)   256         res3b_branch2b[0][0]
# ____________________________________________________________________________________________________
# activation_64 (Activation)       (None, 128, 28, 28)   0           bn3b_branch2b[0][0]
# ____________________________________________________________________________________________________
# res3b_branch2c (Convolution2D)   (None, 512, 28, 28)   66048       activation_64[0][0]
# ____________________________________________________________________________________________________
# bn3b_branch2c (BatchNormalization(None, 512, 28, 28)   1024        res3b_branch2c[0][0]
# ____________________________________________________________________________________________________
# merge_21 (Merge)                 (None, 512, 28, 28)   0           bn3b_branch2c[0][0]
#                                                                    activation_62[0][0]
# ____________________________________________________________________________________________________
# activation_65 (Activation)       (None, 512, 28, 28)   0           merge_21[0][0]
# ____________________________________________________________________________________________________
# res3c_branch2a (Convolution2D)   (None, 128, 28, 28)   65664       activation_65[0][0]
# ____________________________________________________________________________________________________
# bn3c_branch2a (BatchNormalization(None, 128, 28, 28)   256         res3c_branch2a[0][0]
# ____________________________________________________________________________________________________
# activation_66 (Activation)       (None, 128, 28, 28)   0           bn3c_branch2a[0][0]
# ____________________________________________________________________________________________________
# res3c_branch2b (Convolution2D)   (None, 128, 28, 28)   147584      activation_66[0][0]
# ____________________________________________________________________________________________________
# bn3c_branch2b (BatchNormalization(None, 128, 28, 28)   256         res3c_branch2b[0][0]
# ____________________________________________________________________________________________________
# activation_67 (Activation)       (None, 128, 28, 28)   0           bn3c_branch2b[0][0]
# ____________________________________________________________________________________________________
# res3c_branch2c (Convolution2D)   (None, 512, 28, 28)   66048       activation_67[0][0]
# ____________________________________________________________________________________________________
# bn3c_branch2c (BatchNormalization(None, 512, 28, 28)   1024        res3c_branch2c[0][0]
# ____________________________________________________________________________________________________
# merge_22 (Merge)                 (None, 512, 28, 28)   0           bn3c_branch2c[0][0]
#                                                                    activation_65[0][0]
# ____________________________________________________________________________________________________
# activation_68 (Activation)       (None, 512, 28, 28)   0           merge_22[0][0]
# ____________________________________________________________________________________________________
# res3d_branch2a (Convolution2D)   (None, 128, 28, 28)   65664       activation_68[0][0]
# ____________________________________________________________________________________________________
# bn3d_branch2a (BatchNormalization(None, 128, 28, 28)   256         res3d_branch2a[0][0]
# ____________________________________________________________________________________________________
# activation_69 (Activation)       (None, 128, 28, 28)   0           bn3d_branch2a[0][0]
# ____________________________________________________________________________________________________
# res3d_branch2b (Convolution2D)   (None, 128, 28, 28)   147584      activation_69[0][0]
# ____________________________________________________________________________________________________
# bn3d_branch2b (BatchNormalization(None, 128, 28, 28)   256         res3d_branch2b[0][0]
# ____________________________________________________________________________________________________
# activation_70 (Activation)       (None, 128, 28, 28)   0           bn3d_branch2b[0][0]
# ____________________________________________________________________________________________________
# res3d_branch2c (Convolution2D)   (None, 512, 28, 28)   66048       activation_70[0][0]
# ____________________________________________________________________________________________________
# bn3d_branch2c (BatchNormalization(None, 512, 28, 28)   1024        res3d_branch2c[0][0]
# ____________________________________________________________________________________________________
# merge_23 (Merge)                 (None, 512, 28, 28)   0           bn3d_branch2c[0][0]
#                                                                    activation_68[0][0]
# ____________________________________________________________________________________________________
# activation_71 (Activation)       (None, 512, 28, 28)   0           merge_23[0][0]
# ____________________________________________________________________________________________________
# res4a_branch2a (Convolution2D)   (None, 256, 14, 14)   131328      activation_71[0][0]
# ____________________________________________________________________________________________________
# bn4a_branch2a (BatchNormalization(None, 256, 14, 14)   512         res4a_branch2a[0][0]
# ____________________________________________________________________________________________________
# activation_72 (Activation)       (None, 256, 14, 14)   0           bn4a_branch2a[0][0]
# ____________________________________________________________________________________________________
# res4a_branch2b (Convolution2D)   (None, 256, 14, 14)   590080      activation_72[0][0]
# ____________________________________________________________________________________________________
# bn4a_branch2b (BatchNormalization(None, 256, 14, 14)   512         res4a_branch2b[0][0]
# ____________________________________________________________________________________________________
# activation_73 (Activation)       (None, 256, 14, 14)   0           bn4a_branch2b[0][0]
# ____________________________________________________________________________________________________
# res4a_branch2c (Convolution2D)   (None, 1024, 14, 14)  263168      activation_73[0][0]
# ____________________________________________________________________________________________________
# res4a_branch1 (Convolution2D)    (None, 1024, 14, 14)  525312      activation_71[0][0]
# ____________________________________________________________________________________________________
# bn4a_branch2c (BatchNormalization(None, 1024, 14, 14)  2048        res4a_branch2c[0][0]
# ____________________________________________________________________________________________________
# bn4a_branch1 (BatchNormalization)(None, 1024, 14, 14)  2048        res4a_branch1[0][0]
# ____________________________________________________________________________________________________
# merge_24 (Merge)                 (None, 1024, 14, 14)  0           bn4a_branch2c[0][0]
#                                                                    bn4a_branch1[0][0]
# ____________________________________________________________________________________________________
# activation_74 (Activation)       (None, 1024, 14, 14)  0           merge_24[0][0]
# ____________________________________________________________________________________________________
# res4b_branch2a (Convolution2D)   (None, 256, 14, 14)   262400      activation_74[0][0]
# ____________________________________________________________________________________________________
# bn4b_branch2a (BatchNormalization(None, 256, 14, 14)   512         res4b_branch2a[0][0]
# ____________________________________________________________________________________________________
# activation_75 (Activation)       (None, 256, 14, 14)   0           bn4b_branch2a[0][0]
# ____________________________________________________________________________________________________
# res4b_branch2b (Convolution2D)   (None, 256, 14, 14)   590080      activation_75[0][0]
# ____________________________________________________________________________________________________
# bn4b_branch2b (BatchNormalization(None, 256, 14, 14)   512         res4b_branch2b[0][0]
# ____________________________________________________________________________________________________
# activation_76 (Activation)       (None, 256, 14, 14)   0           bn4b_branch2b[0][0]
# ____________________________________________________________________________________________________
# res4b_branch2c (Convolution2D)   (None, 1024, 14, 14)  263168      activation_76[0][0]
# ____________________________________________________________________________________________________
# bn4b_branch2c (BatchNormalization(None, 1024, 14, 14)  2048        res4b_branch2c[0][0]
# ____________________________________________________________________________________________________
# merge_25 (Merge)                 (None, 1024, 14, 14)  0           bn4b_branch2c[0][0]
#                                                                    activation_74[0][0]
# ____________________________________________________________________________________________________
# activation_77 (Activation)       (None, 1024, 14, 14)  0           merge_25[0][0]
# ____________________________________________________________________________________________________
# res4c_branch2a (Convolution2D)   (None, 256, 14, 14)   262400      activation_77[0][0]
# ____________________________________________________________________________________________________
# bn4c_branch2a (BatchNormalization(None, 256, 14, 14)   512         res4c_branch2a[0][0]
# ____________________________________________________________________________________________________
# activation_78 (Activation)       (None, 256, 14, 14)   0           bn4c_branch2a[0][0]
# ____________________________________________________________________________________________________
# res4c_branch2b (Convolution2D)   (None, 256, 14, 14)   590080      activation_78[0][0]
# ____________________________________________________________________________________________________
# bn4c_branch2b (BatchNormalization(None, 256, 14, 14)   512         res4c_branch2b[0][0]
# ____________________________________________________________________________________________________
# activation_79 (Activation)       (None, 256, 14, 14)   0           bn4c_branch2b[0][0]
# ____________________________________________________________________________________________________
# res4c_branch2c (Convolution2D)   (None, 1024, 14, 14)  263168      activation_79[0][0]
# ____________________________________________________________________________________________________
# bn4c_branch2c (BatchNormalization(None, 1024, 14, 14)  2048        res4c_branch2c[0][0]
# ____________________________________________________________________________________________________
# merge_26 (Merge)                 (None, 1024, 14, 14)  0           bn4c_branch2c[0][0]
#                                                                    activation_77[0][0]
# ____________________________________________________________________________________________________
# activation_80 (Activation)       (None, 1024, 14, 14)  0           merge_26[0][0]
# ____________________________________________________________________________________________________
# res4d_branch2a (Convolution2D)   (None, 256, 14, 14)   262400      activation_80[0][0]
# ____________________________________________________________________________________________________
# bn4d_branch2a (BatchNormalization(None, 256, 14, 14)   512         res4d_branch2a[0][0]
# ____________________________________________________________________________________________________
# activation_81 (Activation)       (None, 256, 14, 14)   0           bn4d_branch2a[0][0]
# ____________________________________________________________________________________________________
# res4d_branch2b (Convolution2D)   (None, 256, 14, 14)   590080      activation_81[0][0]
# ____________________________________________________________________________________________________
# bn4d_branch2b (BatchNormalization(None, 256, 14, 14)   512         res4d_branch2b[0][0]
# ____________________________________________________________________________________________________
# activation_82 (Activation)       (None, 256, 14, 14)   0           bn4d_branch2b[0][0]
# ____________________________________________________________________________________________________
# res4d_branch2c (Convolution2D)   (None, 1024, 14, 14)  263168      activation_82[0][0]
# ____________________________________________________________________________________________________
# bn4d_branch2c (BatchNormalization(None, 1024, 14, 14)  2048        res4d_branch2c[0][0]
# ____________________________________________________________________________________________________
# merge_27 (Merge)                 (None, 1024, 14, 14)  0           bn4d_branch2c[0][0]
#                                                                    activation_80[0][0]
# ____________________________________________________________________________________________________
# activation_83 (Activation)       (None, 1024, 14, 14)  0           merge_27[0][0]
# ____________________________________________________________________________________________________
# res4e_branch2a (Convolution2D)   (None, 256, 14, 14)   262400      activation_83[0][0]
# ____________________________________________________________________________________________________
# bn4e_branch2a (BatchNormalization(None, 256, 14, 14)   512         res4e_branch2a[0][0]
# ____________________________________________________________________________________________________
# activation_84 (Activation)       (None, 256, 14, 14)   0           bn4e_branch2a[0][0]
# ____________________________________________________________________________________________________
# res4e_branch2b (Convolution2D)   (None, 256, 14, 14)   590080      activation_84[0][0]
# ____________________________________________________________________________________________________
# bn4e_branch2b (BatchNormalization(None, 256, 14, 14)   512         res4e_branch2b[0][0]
# ____________________________________________________________________________________________________
# activation_85 (Activation)       (None, 256, 14, 14)   0           bn4e_branch2b[0][0]
# ____________________________________________________________________________________________________
# res4e_branch2c (Convolution2D)   (None, 1024, 14, 14)  263168      activation_85[0][0]
# ____________________________________________________________________________________________________
# bn4e_branch2c (BatchNormalization(None, 1024, 14, 14)  2048        res4e_branch2c[0][0]
# ____________________________________________________________________________________________________
# merge_28 (Merge)                 (None, 1024, 14, 14)  0           bn4e_branch2c[0][0]
#                                                                    activation_83[0][0]
# ____________________________________________________________________________________________________
# activation_86 (Activation)       (None, 1024, 14, 14)  0           merge_28[0][0]
# ____________________________________________________________________________________________________
# res4f_branch2a (Convolution2D)   (None, 256, 14, 14)   262400      activation_86[0][0]
# ____________________________________________________________________________________________________
# bn4f_branch2a (BatchNormalization(None, 256, 14, 14)   512         res4f_branch2a[0][0]
# ____________________________________________________________________________________________________
# activation_87 (Activation)       (None, 256, 14, 14)   0           bn4f_branch2a[0][0]
# ____________________________________________________________________________________________________
# res4f_branch2b (Convolution2D)   (None, 256, 14, 14)   590080      activation_87[0][0]
# ____________________________________________________________________________________________________
# bn4f_branch2b (BatchNormalization(None, 256, 14, 14)   512         res4f_branch2b[0][0]
# ____________________________________________________________________________________________________
# activation_88 (Activation)       (None, 256, 14, 14)   0           bn4f_branch2b[0][0]
# ____________________________________________________________________________________________________
# res4f_branch2c (Convolution2D)   (None, 1024, 14, 14)  263168      activation_88[0][0]
# ____________________________________________________________________________________________________
# bn4f_branch2c (BatchNormalization(None, 1024, 14, 14)  2048        res4f_branch2c[0][0]
# ____________________________________________________________________________________________________
# merge_29 (Merge)                 (None, 1024, 14, 14)  0           bn4f_branch2c[0][0]
#                                                                    activation_86[0][0]
# ____________________________________________________________________________________________________
# activation_89 (Activation)       (None, 1024, 14, 14)  0           merge_29[0][0]
# ____________________________________________________________________________________________________
# res5a_branch2a (Convolution2D)   (None, 512, 7, 7)     524800      activation_89[0][0]
# ____________________________________________________________________________________________________
# bn5a_branch2a (BatchNormalization(None, 512, 7, 7)     1024        res5a_branch2a[0][0]
# ____________________________________________________________________________________________________
# activation_90 (Activation)       (None, 512, 7, 7)     0           bn5a_branch2a[0][0]
# ____________________________________________________________________________________________________
# res5a_branch2b (Convolution2D)   (None, 512, 7, 7)     2359808     activation_90[0][0]
# ____________________________________________________________________________________________________
# bn5a_branch2b (BatchNormalization(None, 512, 7, 7)     1024        res5a_branch2b[0][0]
# ____________________________________________________________________________________________________
# activation_91 (Activation)       (None, 512, 7, 7)     0           bn5a_branch2b[0][0]
# ____________________________________________________________________________________________________
# res5a_branch2c (Convolution2D)   (None, 2048, 7, 7)    1050624     activation_91[0][0]
# ____________________________________________________________________________________________________
# res5a_branch1 (Convolution2D)    (None, 2048, 7, 7)    2099200     activation_89[0][0]
# ____________________________________________________________________________________________________
# bn5a_branch2c (BatchNormalization(None, 2048, 7, 7)    4096        res5a_branch2c[0][0]
# ____________________________________________________________________________________________________
# bn5a_branch1 (BatchNormalization)(None, 2048, 7, 7)    4096        res5a_branch1[0][0]
# ____________________________________________________________________________________________________
# merge_30 (Merge)                 (None, 2048, 7, 7)    0           bn5a_branch2c[0][0]
#                                                                    bn5a_branch1[0][0]
# ____________________________________________________________________________________________________
# activation_92 (Activation)       (None, 2048, 7, 7)    0           merge_30[0][0]
# ____________________________________________________________________________________________________
# res5b_branch2a (Convolution2D)   (None, 512, 7, 7)     1049088     activation_92[0][0]
# ____________________________________________________________________________________________________
# bn5b_branch2a (BatchNormalization(None, 512, 7, 7)     1024        res5b_branch2a[0][0]
# ____________________________________________________________________________________________________
# activation_93 (Activation)       (None, 512, 7, 7)     0           bn5b_branch2a[0][0]
# ____________________________________________________________________________________________________
# res5b_branch2b (Convolution2D)   (None, 512, 7, 7)     2359808     activation_93[0][0]
# ____________________________________________________________________________________________________
# bn5b_branch2b (BatchNormalization(None, 512, 7, 7)     1024        res5b_branch2b[0][0]
# ____________________________________________________________________________________________________
# activation_94 (Activation)       (None, 512, 7, 7)     0           bn5b_branch2b[0][0]
# ____________________________________________________________________________________________________
# res5b_branch2c (Convolution2D)   (None, 2048, 7, 7)    1050624     activation_94[0][0]
# ____________________________________________________________________________________________________
# bn5b_branch2c (BatchNormalization(None, 2048, 7, 7)    4096        res5b_branch2c[0][0]
# ____________________________________________________________________________________________________
# merge_31 (Merge)                 (None, 2048, 7, 7)    0           bn5b_branch2c[0][0]
#                                                                    activation_92[0][0]
# ____________________________________________________________________________________________________
# activation_95 (Activation)       (None, 2048, 7, 7)    0           merge_31[0][0]
# ____________________________________________________________________________________________________
# res5c_branch2a (Convolution2D)   (None, 512, 7, 7)     1049088     activation_95[0][0]
# ____________________________________________________________________________________________________
# bn5c_branch2a (BatchNormalization(None, 512, 7, 7)     1024        res5c_branch2a[0][0]
# ____________________________________________________________________________________________________
# activation_96 (Activation)       (None, 512, 7, 7)     0           bn5c_branch2a[0][0]
# ____________________________________________________________________________________________________
# res5c_branch2b (Convolution2D)   (None, 512, 7, 7)     2359808     activation_96[0][0]
# ____________________________________________________________________________________________________
# bn5c_branch2b (BatchNormalization(None, 512, 7, 7)     1024        res5c_branch2b[0][0]
# ____________________________________________________________________________________________________
# activation_97 (Activation)       (None, 512, 7, 7)     0           bn5c_branch2b[0][0]
# ____________________________________________________________________________________________________
# res5c_branch2c (Convolution2D)   (None, 2048, 7, 7)    1050624     activation_97[0][0]
# ____________________________________________________________________________________________________
# bn5c_branch2c (BatchNormalization(None, 2048, 7, 7)    4096        res5c_branch2c[0][0]
# ____________________________________________________________________________________________________
# merge_32 (Merge)                 (None, 2048, 7, 7)    0           bn5c_branch2c[0][0]
#                                                                    activation_95[0][0]
# ____________________________________________________________________________________________________
# activation_98 (Activation)       (None, 2048, 7, 7)    0           merge_32[0][0]
# ____________________________________________________________________________________________________
# avg_pool (AveragePooling2D)      (None, 2048, 1, 1)    0           activation_98[0][0]
# ____________________________________________________________________________________________________
# flatten_3 (Flatten)              (None, 2048)          0           avg_pool[0][0]
# ____________________________________________________________________________________________________
# dense_8 (Dense)                  (None, 8)             16392       flatten_3[0][0]
# ====================================================================================================
# Total params: 23550984
# ____________________________________________________________________________________________________

# %%
model.compile(optimizer=Adam(1e-3),
       loss='categorical_crossentropy', metrics=['accuracy'])

# %%
batch_size=8
model.fit(trn, trn_labels, batch_size=batch_size, nb_epoch=3, validation_data=(val, val_labels))
# Out:
# Train on 3277 samples, validate on 500 samples
# Epoch 1/3
# 3277/3277 [==============================] - 327s - loss: nan - acc: 0.4525 - val_loss: nan - val_acc: 0.4720
# Epoch 2/3
# 3277/3277 [==============================] - 327s - loss: nan - acc: 0.4525 - val_loss: nan - val_acc: 0.4720
# Epoch 3/3
# 3277/3277 [==============================] - 327s - loss: nan - acc: 0.4525 - val_loss: nan - val_acc: 0.4720

# %%
model.optimizer.lr = 0.0000001
model.fit(trn, trn_labels, batch_size=batch_size, nb_epoch=3, validation_data=(val, val_labels))
# Out:
# Train on 3277 samples, validate on 500 samples
# Epoch 1/3
# 3277/3277 [==============================] - 330s - loss: nan - acc: 0.4525 - val_loss: nan - val_acc: 0.4720
# Epoch 2/3
# 3277/3277 [==============================] - 329s - loss: nan - acc: 0.4525 - val_loss: nan - val_acc: 0.4720
# Epoch 3/3
# 3277/3277 [==============================] - 327s - loss: nan - acc: 0.4525 - val_loss: nan - val_acc: 0.4720

# %%
model.evaluate(val, val_labels, batch_size=16)
# Out:
# 500/500 [==============================] - 9s
# [nan, 0.47199999999999998]

# %%
layers = model.layers
# Get the index of the first dense layer...
last_merge_idx = [index for index,layer in enumerate(layers) if type(layer) is BatchNormalization][-1]

# %%
last_merge_idx
# Out:
# 172

# %%
for layer in layers[164:]: layer.trainable=True

# %%
for layer in layers[:163]: layer.trainable=False

# %%
layers[164]

# %%
layers[163]
